# %% [markdown]
# Progetto di Linguistica Computazionale II
#
# [Vincenzo Sammartino](https://www.linkedin.com/in/vincenzo-sammartino-0339191a1/ "Vincenzo Sammartino") - matricola 599203
#
# Corso di Laurea Magistrale in Informatica Umanistica

# %% [markdown]
# # Lettura e preprocessing dei dataset

# %%
#Import delle librerie necessarie
import pandas as pd
import re
import conllu
from conllu import parse

import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

from sklearn.preprocessing import MaxAbsScaler

from sklearn.dummy import DummyClassifier

from collections import Counter

from sklearn.model_selection import GridSearchCV
from sklearn.model_selection import RandomizedSearchCV
from sklearn.model_selection import RepeatedStratifiedKFold
from sklearn.metrics import classification_report, confusion_matrix, accuracy_score
from sklearn.model_selection import cross_val_score

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction import DictVectorizer

from sklearn.svm import LinearSVC
from sklearn.multiclass import OneVsRestClassifier


import sqlite3

# Libreria transformers per utilizzare i Transformer models
from transformers import AutoTokenizer
from transformers import AutoModelForSequenceClassification, TrainingArguments, Trainer

# Librerie per le metriche
from sklearn.metrics import classification_report
from sklearn.metrics import ConfusionMatrixDisplay

from datasets import Dataset

import evaluate

# %% [markdown]
# Trasformo il file in modo da poter fare l'analisi con ProfilingUD

# %%
# Leggi il file TSV
file_tsv = "dati/haspeede2_dev_taskAB.tsv"
df = pd.read_csv(file_tsv, sep='\t', 
                 header=0, encoding='utf-8')
df.columns
# Out:
# Index(['id', 'text ', 'hs', 'stereotype'], dtype='object')

# %%
# Estrai la colonna 'text'
text_column = df['text ']
text_column
# Out:
# 0       È terrorismo anche questo, per mettere in uno ...
# 1       @user @user infatti finché ci hanno guadagnato...
# 2       Corriere: Tangenti, Mafia Capitale dimenticata...
# 3       @user ad uno ad uno, perché quando i migranti ...
# 4       Il divertimento del giorno? Trovare i patrioti...
#                               ...
# 6832    Gli stati nazionali devono essere pronti a rin...
# 6833    Il ministro dell'interno della Germania #Horst...
# 6834    #Salvini: In Italia troppi si sono montati la ...
# 6835    @user @user Chi giubila in buona fede non ha c...
# 6836    I giovani cristiani in #Etiopia sono indotti d...
# Name: text , Length: 6837, dtype: object

# %%
output_file = "output_train.txt"
with open(output_file, 'w', encoding='utf-8') as f:
    for text in text_column:
        f.write(text + '\n')

# %% [markdown]
# Leggo ora il file in formato ConLL

# %%
with open("output_train.conllu", "r", encoding="utf-8") as f:
    text = f.read()

# Rimuovi URL
text = re.sub(r'URL', '', text)

# Rimuovi @user
text = re.sub(r'@user', '', text)

sentences_train = conllu.parse(text)

# %%
with open("output_test_news.conllu", "r", encoding="utf-8") as f:
    text = f.read()

# Rimuovi URL
text = re.sub(r'URL', '', text)

# Rimuovi @user
text = re.sub(r'@user', '', text)

sentences_test = conllu.parse(text)

#Unisco i due array per fare i dizionari successivamente
sentences = sentences_train + sentences_test

# %%
#Controllo che il numero di frasi sia uguale al numero di etichette
len(sentences_test)
# Out:
# 500

# %% [markdown]
# Leggo il file TSV di test

# %%
# Leggi il file TSV
file_tsv = "dati/haspeede2-test_taskAB-news.tsv"
df = pd.read_csv(file_tsv, sep='\t', encoding='utf-8',
                 names=["id", "testo"])
testo_test = df['testo']


file_tsv = "dati/haspeede2_reference_taskAB-news.tsv"
df = pd.read_csv(file_tsv, sep='\t', encoding='utf-8',
                 names=["id", "testo", "hs", "stereotype"])

y_test_hs = df['hs'].values #etichette per il test (hate speech)

# etichette per il test (stereotype)
y_test_stereotypes = df['stereotype'].values

testo_test
# Out:
# 0      Andate pure là, tanto quei fessi degli italian...
# 1      Che fine spero che faccia il killer nigeriano ...
# 2       Così i profughi ci svuotano i negozi a Pordenone
# 3      Così umiliano gli italiani e coccolano i cland...
# 4      Danno soldi ai clandestini, ma ai disabili inv...
#                              ...
# 495    Sea Watch, il pm fa sbarcare i migranti. Salvi...
# 496    Il pm fa sbarcare i migranti Il capo leghista ...
# 497    Pisa, il poster di Salvini con i migranti fatt...
# 498    Sea Watch e lo sbarco del migrante con una sol...
# 499    Decreto Sicurezza Bis, multe più salate per ch...
# Name: testo, Length: 500, dtype: object

# %%
output_file = "output_test_news.txt"
with open(output_file, 'w', encoding='utf-8') as f:
    for testo in testo_test:
        f.write(testo + '\n')

# %%
import numpy as np

with open('dati/haspeede2_dev_taskAB.tsv', 'r', encoding='utf-8') as file:
    # Salta la prima riga (header)
    file.readline()

    # Leggo le righe rimanenti
    lines = file.readlines()

    text = []
    hs = []
    stereotypes = []

    for line in lines:
        elements = line.split('\t')
        text.append(elements[1])
        hs.append(int(elements[2]))
        stereotypes.append(int(elements[3]))

    file.close()

text = np.array(text)
y_train_hs = np.array(hs)  # etichette per hate speech
y_train_stereotypes = np.array(stereotypes)  # etichette per stereotypes
np.unique(y_test_stereotypes,return_counts=True)
# Out:
# (array([0, 1], dtype=int64), array([325, 175], dtype=int64))

# %% [markdown]
# # Classificazione con le informazioni lessicali

# %%
# Leggi il file TSV di train
file_tsv = "dati/info_lessicali_train.csv"
df_train = pd.read_csv(file_tsv, sep='\t', encoding='utf-8')
#Rimuovo le colonne non necessarie
df_train = df_train.drop(['Filename', 'n_sentences'], axis=1)
df_train
# Out:
#       n_tokens  tokens_per_sent  char_per_tok  upos_dist_ADJ  upos_dist_ADP
# 0           22             22.0      4.950000       0.000000      13.636364  \
# 1           18             18.0      4.882353       0.000000      11.111111
# 2           14             14.0      6.000000       0.000000       7.142857
# 3           22             22.0      4.800000       4.545455      22.727273
# 4           26             26.0      5.181818      11.538462      11.538462
# ...        ...              ...           ...            ...            ...
# 6834        50             50.0      5.108696       6.000000       8.000000
# 6835        55             55.0      4.288462       0.000000      14.545455
# 6836        42             42.0      5.305556       2.380952       4.761905
# 6837        40             40.0      4.368421       7.500000       7.500000
# 6838        52             52.0      5.130435       9.615385      19.230769
#
#       upos_dist_ADV  upos_dist_AUX  upos_dist_CCONJ  upos_dist_DET
# 0          4.545455       4.545455         4.545455      13.636364  \
# 1          5.555556      16.666667         0.000000       5.555556
# 2          7.142857       0.000000         7.142857       0.000000
# 3          4.545455       0.000000         0.000000      13.636364
# 4          0.000000       0.000000         0.000000      23.076923
# ...             ...            ...              ...            ...
# 6834       4.000000      10.000000         2.000000      16.000000
# 6835       0.000000       1.818182         9.090909      21.818182
# 6836       2.380952       9.523810         4.761905       7.142857
# 6837      15.000000      12.500000         2.500000      10.000000
# 6838       1.923077       1.923077         1.923077       9.615385
#
#       upos_dist_INTJ  ...  principal_proposition_dist
# 0                0.0  ...                   50.000000  \
# 1                0.0  ...                   33.333333
# 2                0.0  ...                    0.000000
# 3                0.0  ...                    0.000000
# 4                0.0  ...                   33.333333
# ...              ...  ...                         ...
# 6834             0.0  ...                   16.666667
# 6835             0.0  ...                   25.000000
# 6836             0.0  ...                   25.000000
# 6837             0.0  ...                   25.000000
# 6838             0.0  ...                   33.333333
#
#       subordinate_proposition_dist  subordinate_post  subordinate_pre
# 0                        50.000000        100.000000         0.000000  \
# 1                        66.666667        100.000000         0.000000
# 2                       100.000000        100.000000         0.000000
# 3                       100.000000        100.000000         0.000000
# 4                        66.666667        100.000000         0.000000
# ...                            ...               ...              ...
# 6834                     83.333333        100.000000         0.000000
# 6835                     75.000000        100.000000         0.000000
# 6836                     75.000000          0.000000       100.000000
# 6837                     75.000000         66.666667        33.333333
# 6838                     66.666667        100.000000         0.000000
#
#       avg_subordinate_chain_len  subordinate_dist_1  subordinate_dist_2
# 0                      1.000000          100.000000                 0.0  \
# 1                      2.000000            0.000000               100.0
# 2                      1.000000          100.000000                 0.0
# 3                      1.000000          100.000000                 0.0
# 4                      2.000000            0.000000               100.0
# ...                         ...                 ...                 ...
# 6834                   1.666667           66.666667                 0.0
# 6835                   1.000000          100.000000                 0.0
# 6836                   1.000000          100.000000                 0.0
# 6837                   1.500000           50.000000                50.0
# 6838                   1.000000          100.000000                 0.0
#
#       subordinate_dist_3  subordinate_dist_4  subordinate_dist_5
# 0               0.000000                 0.0                 0.0
# 1               0.000000                 0.0                 0.0
# 2               0.000000                 0.0                 0.0
# 3               0.000000                 0.0                 0.0
# 4               0.000000                 0.0                 0.0
# ...                  ...                 ...                 ...
# 6834           33.333333                 0.0                 0.0
# 6835            0.000000                 0.0                 0.0
# 6836            0.000000                 0.0                 0.0
# 6837            0.000000                 0.0                 0.0
# 6838            0.000000                 0.0                 0.0
#
# [6839 rows x 133 columns]

# %%
# Leggi il file TSV di test
file_tsv = "dati/info_lessicali_test_news.csv"
df_test = pd.read_csv(file_tsv, sep='\t', encoding='utf-8')
# Rimuovo le colonne non necessarie
df_test = df_test.drop(['Filename', 'n_sentences'], axis=1)
df_test
# Out:
#      n_tokens  tokens_per_sent  char_per_tok  upos_dist_ADJ  upos_dist_ADP
# 0          19             19.0      5.312500       0.000000       5.263158  \
# 1          23             23.0      4.095238      13.043478       8.695652
# 2           9              9.0      4.444444       0.000000      11.111111
# 3          24             24.0      4.789474       0.000000       8.333333
# 4          25             25.0      4.750000      12.000000      12.000000
# ..        ...              ...           ...            ...            ...
# 495        18             18.0      4.200000       0.000000       0.000000
# 496        12             12.0      4.083333       8.333333       8.333333
# 497        20             20.0      4.533333       0.000000      15.000000
# 498        22             22.0      4.000000       4.545455       9.090909
# 499        12             12.0      5.090909      16.666667       8.333333
#
#      upos_dist_ADV  upos_dist_AUX  upos_dist_CCONJ  upos_dist_DET
# 0        15.789474       0.000000         0.000000      15.789474  \
# 1         4.347826       0.000000         0.000000      26.086957
# 2        11.111111       0.000000         0.000000      22.222222
# 3         4.166667       0.000000         8.333333      20.833333
# 4         0.000000       0.000000         8.000000      16.000000
# ..             ...            ...              ...            ...
# 495       0.000000       5.555556         0.000000      16.666667
# 496       0.000000       0.000000         0.000000      25.000000
# 497       0.000000       5.000000         0.000000      15.000000
# 498       0.000000       4.545455         4.545455      22.727273
# 499       8.333333       0.000000         0.000000       8.333333
#
#      upos_dist_INTJ  ...  dep_dist_root  dep_dist_xcomp
# 0               0.0  ...       5.263158        0.000000  \
# 1               0.0  ...       4.347826        0.000000
# 2               0.0  ...      11.111111        0.000000
# 3               0.0  ...       4.166667        0.000000
# 4               0.0  ...       4.000000        0.000000
# ..              ...  ...            ...             ...
# 495             0.0  ...       5.555556        5.555556
# 496             0.0  ...       8.333333        8.333333
# 497             0.0  ...       5.000000        0.000000
# 498             0.0  ...       4.545455        0.000000
# 499             0.0  ...       8.333333        0.000000
#
#      principal_proposition_dist  subordinate_proposition_dist
# 0                     33.333333                     66.666667  \
# 1                     50.000000                     50.000000
# 2                    100.000000                      0.000000
# 3                     50.000000                     50.000000
# 4                    100.000000                      0.000000
# ..                          ...                           ...
# 495                   33.333333                     66.666667
# 496                   33.333333                     66.666667
# 497                    0.000000                    100.000000
# 498                  100.000000                      0.000000
# 499                    0.000000                    100.000000
#
#      subordinate_post  subordinate_pre  avg_subordinate_chain_len
# 0                 0.0            100.0                        2.0  \
# 1               100.0              0.0                        1.0
# 2                 0.0              0.0                        0.0
# 3                 0.0            100.0                        1.0
# 4                 0.0              0.0                        0.0
# ..                ...              ...                        ...
# 495             100.0              0.0                        1.0
# 496             100.0              0.0                        1.0
# 497             100.0              0.0                        2.0
# 498               0.0              0.0                        0.0
# 499             100.0              0.0                        1.0
#
#      subordinate_dist_1  subordinate_dist_2  subordinate_dist_3
# 0                   0.0               100.0                 0.0
# 1                 100.0                 0.0                 0.0
# 2                   0.0                 0.0                 0.0
# 3                 100.0                 0.0                 0.0
# 4                   0.0                 0.0                 0.0
# ..                  ...                 ...                 ...
# 495               100.0                 0.0                 0.0
# 496               100.0                 0.0                 0.0
# 497                 0.0               100.0                 0.0
# 498                 0.0                 0.0                 0.0
# 499               100.0                 0.0                 0.0
#
# [500 rows x 124 columns]

# %%
# Prendo i due dataframe con diverso numero di colonne e trovo le colonne comuni
common_columns = list(set(df_train.columns) & set(df_test.columns))

# Seleziona solo le colonne comuni per entrambi i dataframe
X_train = df_train[common_columns]
X_test = df_test[common_columns]

# %% [markdown]
# ## Normalizzazione

# %%
scaler = MaxAbsScaler()
X_train = scaler.fit_transform(X_train)
X_test = scaler.transform(X_test)

# %% [markdown]
# # Baseline (Dummy Classifier)

# %%
dummy_clf = DummyClassifier(strategy='prior', random_state=42)
dummy_clf.fit(X_train, y_train_hs)
y_pred = dummy_clf.predict(X_test)

print(classification_report(y_test_hs, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      1.00      0.78       319
#            1       0.00      0.00      0.00       181
#
#     accuracy                           0.64       500
#    macro avg       0.32      0.50      0.39       500
# weighted avg       0.41      0.64      0.50       500
# c:\Users\vince\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\vince\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\vince\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
dummy_clf = DummyClassifier(strategy='prior', random_state=42)
dummy_clf.fit(X_train, y_train_stereotypes)
y_pred = dummy_clf.predict(X_test)

print(classification_report(y_test_stereotypes, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.65      1.00      0.79       325
#            1       0.00      0.00      0.00       175
#
#     accuracy                           0.65       500
#    macro avg       0.33      0.50      0.39       500
# weighted avg       0.42      0.65      0.51       500
# c:\Users\vince\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\vince\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# c:\Users\vince\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\metrics\_classification.py:1344: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# ## HyperParameters Tuning

# %%
# Inizializzo LinearSVC
clf = LinearSVC(max_iter=10000)

# defining parameter range
# Regularization parameter. The strength of the regularization is inversely proportional to C. Must be strictly positive
param_grid = {
    "C": [0.001, 0.01, 0.1, 1, 10],
    "dual": [True, False]
}

RSKF = RepeatedStratifiedKFold(
    n_splits=20,
    n_repeats=3,
    random_state=0
)

grid = RandomizedSearchCV(
    clf,
    n_iter=1500,
    param_distributions=param_grid,
    cv=RSKF,
    n_jobs=-1,
    refit=True,
    verbose=2,
    random_state=0
)

# fitting the model for grid search
grid.fit(X_train, y_train_hs)

# %%
# print best parameter after tuning
print(grid.best_params_)
# print how our model looks after hyper-parameter tuning
print(grid.best_estimator_)
print(grid.best_score_)
# Out:
# {'dual': False, 'C': 0.001}
# LinearSVC(C=0.001, dual=False)
# 0.6715403897492181

# %%
grid_scores = pd.DataFrame(grid.cv_results_)
grid_scores
# Out:
#    mean_fit_time  std_fit_time  mean_score_time  std_score_time param_dual
# 0       7.510889      1.112450         0.011216        0.009616       True  \
# 1       1.586073      0.280870         0.006024        0.005603      False
# 2       4.569698      0.314598         0.006001        0.005979       True
# 3       3.907625      0.662284         0.007078        0.007003      False
# 4       4.877979      0.345286         0.006409        0.004558       True
# 5       8.379198      2.028444         0.017707        0.041889      False
# 6       4.927716      0.385973         0.008924        0.010148       True
# 7      13.539431      3.743628         0.006862        0.005662      False
# 8       4.653882      0.308634         0.007547        0.007975       True
# 9      17.537802      5.430435         0.007641        0.009495      False
#
#   param_C                       params  split0_test_score  split1_test_score
# 0   0.001   {'dual': True, 'C': 0.001}           0.640351           0.675439  \
# 1   0.001  {'dual': False, 'C': 0.001}           0.640351           0.669591
# 2    0.01    {'dual': True, 'C': 0.01}           0.602339           0.614035
# 3    0.01   {'dual': False, 'C': 0.01}           0.649123           0.675439
# 4     0.1     {'dual': True, 'C': 0.1}           0.564327           0.657895
# 5     0.1    {'dual': False, 'C': 0.1}           0.657895           0.681287
# 6       1       {'dual': True, 'C': 1}           0.552632           0.573099
# 7       1      {'dual': False, 'C': 1}           0.660819           0.675439
# 8      10      {'dual': True, 'C': 10}           0.526316           0.590643
# 9      10     {'dual': False, 'C': 10}           0.654971           0.672515
#
#    split2_test_score  ...  split53_test_score  split54_test_score
# 0           0.713450  ...            0.657895            0.710526  \
# 1           0.710526  ...            0.657895            0.704678
# 2           0.543860  ...            0.590643            0.646199
# 3           0.710526  ...            0.654971            0.716374
# 4           0.564327  ...            0.628655            0.581871
# 5           0.707602  ...            0.654971            0.716374
# 6           0.558480  ...            0.523392            0.640351
# 7           0.707602  ...            0.654971            0.719298
# 8           0.538012  ...            0.584795            0.672515
# 9           0.707602  ...            0.654971            0.719298
#
#    split55_test_score  split56_test_score  split57_test_score
# 0            0.631579            0.649123            0.660819  \
# 1            0.643275            0.652047            0.660819
# 2            0.538012            0.564327            0.608187
# 3            0.652047            0.643275            0.660819
# 4            0.622807            0.599415            0.578947
# 5            0.652047            0.640351            0.663743
# 6            0.447368            0.599415            0.602339
# 7            0.652047            0.637427            0.663743
# 8            0.543860            0.549708            0.605263
# 9            0.652047            0.640351            0.660819
#
#    split58_test_score  split59_test_score  mean_test_score  std_test_score
# 0            0.663743            0.648094         0.669786        0.023362  \
# 1            0.663743            0.648094         0.671540        0.022302
# 2            0.602339            0.551320         0.617386        0.034593
# 3            0.654971            0.648094         0.670273        0.022484
# 4            0.605263            0.627566         0.583225        0.038268
# 5            0.652047            0.648094         0.670760        0.022933
# 6            0.640351            0.612903         0.583419        0.044203
# 7            0.649123            0.648094         0.671345        0.023158
# 8            0.459064            0.565982         0.576689        0.045528
# 9            0.649123            0.651026         0.671102        0.023261
#
#    rank_test_score
# 0                6
# 1                1
# 2                7
# 3                5
# 4                9
# 5                4
# 6                8
# 7                2
# 8               10
# 9                3
#
# [10 rows x 70 columns]

# %%
sns.set(rc={'figure.figsize': (9, 5)})
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1.3)

sns.pointplot(
    data=grid_scores,
    x="param_C",
    y="mean_test_score",
    hue="param_dual"
)

plt.savefig("linearSVC_C_param.svg")

# %%
clf = LinearSVC(max_iter=10000, C=0.001, dual=False)
clf.fit(X_train, y_train_hs)

y_pred = clf.predict(X_test)
print(classification_report(y_test_hs, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.61      0.60      0.60       641
#            1       0.59      0.61      0.60       622
#
#     accuracy                           0.60      1263
#    macro avg       0.60      0.60      0.60      1263
# weighted avg       0.60      0.60      0.60      1263

# %%
scores = cross_val_score(clf, X_test, y_test_hs, cv=5)
print(scores)
print('media:', np.mean(scores))
# Out:
# [0.63636364 0.59288538 0.54545455 0.56746032 0.6031746 ]
# media: 0.5890676955894347

# %% [markdown]
# Estrazione delle features più importanti ai fini della classificazione per il modello LinearSVM

# %%
feat_imp = abs(clf.coef_).transpose()
feat_imp = np.mean(feat_imp, axis=1)

df_feat_imp = pd.DataFrame(
    feat_imp, index=X_train.columns, columns=["% importanza"])
df_feat_imp = df_feat_imp.sort_values("% importanza", ascending=False)
df_feat_imp[:15]
# Out:
#                             % importanza
# dep_dist_nmod                   0.181395
# aux_tense_dist_Pres             0.128296
# dep_dist_det                    0.111437
# upos_dist_PRON                  0.107588
# lexical_density                 0.102331
# dep_dist_punct                  0.100536
# upos_dist_PUNCT                 0.100488
# aux_num_pers_dist_Plur+1        0.100472
# dep_dist_det:poss               0.096897
# verbs_num_pers_dist_Sing+3      0.095696
# upos_dist_NOUN                  0.094643
# upos_dist_NUM                   0.091603
# aux_num_pers_dist_Sing+3        0.088446
# upos_dist_ADP                   0.086711
# verbal_head_per_sent            0.086617

# %%
sns.set(rc={'figure.figsize': (9, 5)})
sns.set_style("whitegrid")
sns.set_context("notebook", font_scale=1.3)

sns.barplot(
    data=df_feat_imp[:15],
    x="% importanza",
    y=df_feat_imp.index[:15],
    orient='h',
    palette="deep"
)

plt.savefig("linearSVC_features.svg")

# %% [markdown]
# # Rappresentazione esplicita del testo - Bag of Words (forme)

# %%
# Creazione dei dizionari di conteggio delle parole
# Creazione dei dizionari di conteggio delle parole
dict_list = [dict   (Counter([token["form"] for token in sentence]))
             for sentence in sentences]

# %%
# Funzioni per filtrare le parole poco frequenti e separare i dati di training e test
def compute_word_frequency(dict_list):
    word_frequency = {}
    for d in dict_list:
        for word, count in d.items():
            word_frequency[word] = word_frequency.get(word, 0) + count
    return word_frequency


def split_and_remove_infrequent_words(dict_list, train_size, min_frequency):
    word_frequency = compute_word_frequency(dict_list)
    train_dict_list = []
    test_dict_list = []

    for i, d in enumerate(dict_list):
        filtered_dict = {word: count for word, count in d.items(
        ) if word_frequency[word] >= min_frequency}
        if i < train_size:
            train_dict_list.append(filtered_dict)
        else:
            test_dict_list.append(filtered_dict)

    return {"train": train_dict_list, "test": test_dict_list}

# %%
# Filtraggio delle parole e separazione dei dati di training e test
train_size = 6839
filtered_data = split_and_remove_infrequent_words(dict_list, train_size, 5)

train_data = filtered_data["train"]
test_data = filtered_data["test"]

# Creazione del vettorizzatore e trasformazione dei dati
vectorizer = DictVectorizer(sparse=True)
X_train = vectorizer.fit_transform(train_data)
X_test = vectorizer.transform(test_data)

# %%
clf = LinearSVC(max_iter=10000, C=0.001, dual=False)
clf.fit(X_train, y_train_hs)
y_pred = clf.predict(X_test)
print(classification_report(y_test_hs, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      1.00      0.79       319
#            1       0.93      0.08      0.14       181
#
#     accuracy                           0.66       500
#    macro avg       0.79      0.54      0.47       500
# weighted avg       0.76      0.66      0.56       500

# %%
features_names = vectorizer.get_feature_names_out(X_train).tolist()

# %%
coefs = clf.coef_
coefs.shape
# Out:
# (1, 3750)

# %%
idx = 0
class_coefs = coefs[idx]

feature_importances = {feature_name: coef for feature_name,
                       coef in zip(features_names, class_coefs)}
sorted_feature_importances = dict(
    sorted(feature_importances.items(), key=lambda item: item[1], reverse=True))

# importances, names = zip(*sorted(zip(feature_importance, features)))

num_to_plot = 15
print(f'Feature importance classe {clf.classes_[idx]}')
plt.barh(range(num_to_plot), list(sorted_feature_importances.values())
         [:num_to_plot], align='center')
plt.yticks(range(num_to_plot), list(
    sorted_feature_importances.keys())[:num_to_plot])
plt.gca().invert_yaxis()

plt.savefig('coefs_bow.svg')
# Out:
# Feature importance classe 0

# %%
scores = cross_val_score(clf, X_test, y_test_hs, cv=5)
print(scores)
print('media:', np.mean(scores))
# Out:
# [0.67 0.73 0.74 0.67 0.66]
# media: 0.694

# %% [markdown]
# # Bag of Words (lemmi)

# %%
# Creazione dei dizionari di conteggio delle parole
# Creazione dei dizionari di conteggio delle parole
dict_list = [dict   (Counter([token["lemma"] for token in sentence]))
             for sentence in sentences]

# %%
# Funzioni per filtrare le parole poco frequenti e separare i dati di training e test
def compute_word_frequency(dict_list):
    word_frequency = {}
    for d in dict_list:
        for word, count in d.items():
            word_frequency[word] = word_frequency.get(word, 0) + count
    return word_frequency


def split_and_remove_infrequent_words(dict_list, train_size, min_frequency):
    word_frequency = compute_word_frequency(dict_list)
    train_dict_list = []
    test_dict_list = []

    for i, d in enumerate(dict_list):
        filtered_dict = {word: count for word, count in d.items(
        ) if word_frequency[word] >= min_frequency}
        if i < train_size:
            train_dict_list.append(filtered_dict)
        else:
            test_dict_list.append(filtered_dict)

    return {"train": train_dict_list, "test": test_dict_list}

# %%
# Filtraggio delle parole e separazione dei dati di training e test
train_size = 6839
filtered_data = split_and_remove_infrequent_words(dict_list, train_size, 5)

train_data = filtered_data["train"]
test_data = filtered_data["test"]

# Creazione del vettorizzatore e trasformazione dei dati
vectorizer = DictVectorizer(sparse=True)
X_train = vectorizer.fit_transform(train_data)
X_test = vectorizer.transform(test_data)

# %%
clf = LinearSVC(max_iter=10000, C=0.001, dual=False)
clf.fit(X_train, y_train_hs)
y_pred = clf.predict(X_test)
print(classification_report(y_test_hs, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.99      0.79       319
#            1       0.80      0.09      0.16       181
#
#     accuracy                           0.66       500
#    macro avg       0.73      0.54      0.47       500
# weighted avg       0.71      0.66      0.56       500

# %%
features_names = vectorizer.get_feature_names_out(X_train).tolist()

# %%
coefs = clf.coef_
coefs.shape
# Out:
# (1, 2929)

# %%
idx = 0
class_coefs = coefs[idx]

feature_importances = {feature_name: coef for feature_name,
                       coef in zip(features_names, class_coefs)}
sorted_feature_importances = dict(
    sorted(feature_importances.items(), key=lambda item: item[1], reverse=True))

# importances, names = zip(*sorted(zip(feature_importance, features)))

num_to_plot = 15
print(f'Feature importance classe {clf.classes_[idx]}')
plt.barh(range(num_to_plot), list(sorted_feature_importances.values())
         [:num_to_plot], align='center')
plt.yticks(range(num_to_plot), list(
    sorted_feature_importances.keys())[:num_to_plot])
plt.gca().invert_yaxis()

plt.savefig('coefs_bow_lemmi.svg')
# Out:
# Feature importance classe 0

# %%
scores = cross_val_score(clf, X_test, y_test_hs, cv=5)
print(scores)
print('media:', np.mean(scores))
# Out:
# [0.65 0.69 0.67 0.64 0.66]
# media: 0.662

# %% [markdown]
# # N-grammi di caratteri

# %%
def conllu_sentences_to_strings(sentences):
    return [' '.join([token["form"] for token in sentence]) for sentence in sentences]


def extract_char_ngrams(sentences, n):
    # Join the words in the sentences with spaces
    all_words = ' '.join(sentences)

    # Extract n-grams of characters
    ngram_chars = [all_words[i:i + n] for i in range(len(all_words) - n + 1)]

    # Add the prefix 'CHAR_n_' to each n-gram and count their frequencies
    char_ngrams = Counter(
        {f'CHAR_{n}_{ngram}': count for ngram, count in Counter(ngram_chars).items()})

    return char_ngrams


sentence_strings = conllu_sentences_to_strings(sentences)

# Dopo 6 caratteri non si ottengono miglioramenti
char_ngrams = extract_char_ngrams(sentence_strings, 6)

train_size = 6839
test_size = 500

train_sentences = sentence_strings[:train_size]
test_sentences = sentence_strings[train_size:train_size + test_size]

# %%
len(char_ngrams)
# Out:
# 277416

# %%
# Convertire le frasi CoNLL-U in una lista di stringhe
train_strings = conllu_sentences_to_strings(sentences_train)
test_strings = conllu_sentences_to_strings(sentences_test)

# Creare un CountVectorizer per gli n-grammi di caratteri
vectorizer = CountVectorizer(analyzer='char', ngram_range=(1, 6))

# Trasformare le frasi in una matrice delle feature
X_train = vectorizer.fit_transform(train_strings)
X_test = vectorizer.transform(test_strings)

# Addestrare e valutare il modello LinearSVC
clf = LinearSVC(max_iter=10000, C=0.001, dual=False)
clf.fit(X_train, y_train_hs)
y_pred = clf.predict(X_test)

print(classification_report(y_test_hs, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.97      0.81       319
#            1       0.82      0.25      0.38       181
#
#     accuracy                           0.71       500
#    macro avg       0.76      0.61      0.60       500
# weighted avg       0.74      0.71      0.65       500

# %%
features_names = vectorizer.get_feature_names_out(X_train).tolist()
features_names
# Out:
# [' ',
#  ' !',
#  ' ! ',
#  ' ! !',
#  ' ! ! ',
#  ' ! ! !',
#  ' ! ! #',
#  ' ! ! ,',
#  ' ! ! a',
#  ' ! ! b',
#  ' ! ! c',
#  ' ! ! d',
#  ' ! ! e',
#  ' ! ! f',
#  ' ! ! g',
#  ' ! ! i',
#  ' ! ! m',
#  ' ! ! n',
#  ' ! ! o',
#  ' ! ! p',
#  ' ! ! q',
#  ' ! ! r',
#  ' ! ! s',
#  ' ! ! t',
#  ' ! ! v',
#  ' ! ! x',
#  ' ! ! è',
#  ' ! ! �',
#  ' ! ! 😂',
#  ' ! ! 😤',
#  ' ! ! 😲',
#  ' ! !!',
#  ' ! !! ',
#  ' ! !!!',
#  ' ! !!.',
#  ' ! !!1',
#  ' ! !!i',
#  ' ! !!m',
#  ' ! !!s',
#  ' ! !!u',
#  ' ! !!👎',
#  ' ! !!😡',
#  ' ! !b',
#  ' ! !bi',
#  ' ! !c',
#  ' ! !ca',
#  ' ! !ce',
#  ' ! !d',
#  ' ! !di',
#  ' ! !e',
#  ' ! !e ',
#  ' ! !f',
#  ' ! !fo',
#  ' ! !m',
#  ' ! !ma',
#  ' ! !n',
#  ' ! !no',
#  ' ! !q',
#  ' ! !qu',
#  ' ! !r',
#  ' ! !ri',
#  ' ! !s',
#  ' ! !sc',
#  ' ! !so',
#  ' ! !v',
#  ' ! !vo',
#  ' ! !🇮',
#  ' ! !🇮🇹',
#  ' ! !👍',
#  ' ! !👍👍',
#  ' ! !👿',
#  ' ! !😀',
#  ' ! !😀👍',
#  ' ! "',
#  ' ! " ',
#  ' ! " "',
#  ' ! " (',
#  ' ! " ,',
#  ' ! " -',
#  ' ! " 2',
#  ' ! " i',
#  ' ! " n',
#  ' ! " u',
#  ' ! #',
#  ' ! # ',
#  ' ! # a',
#  ' ! # d',
#  ' ! # i',
#  ' ! # m',
#  ' ! # r',
#  ' ! # s',
#  ' ! #1',
#  ' ! #15',
#  ' ! #2',
#  ' ! #24',
#  ' ! #b',
#  ' ! #be',
#  ' ! #c',
#  ' ! #co',
#  ' ! #d',
#  ' ! #da',
#  ' ! #f',
#  ' ! #fa',
#  ' ! #i',
#  ' ! #il',
#  ' ! #im',
#  ' ! #io',
#  ' ! #is',
#  ' ! #it',
#  ' ! #l',
#  ' ! #la',
#  ' ! #li',
#  ' ! #m',
#  ' ! #ma',
#  ' ! #me',
#  ' ! #mi',
#  ' ! #mo',
#  ' ! #n',
#  ' ! #na',
#  ' ! #no',
#  ' ! #o',
#  ' ! #om',
#  ' ! #or',
#  ' ! #ot',
#  ' ! #p',
#  ' ! #pa',
#  ' ! #pd',
#  ' ! #pi',
#  ' ! #pr',
#  ' ! #q',
#  ' ! #qa',
#  ' ! #qu',
#  ' ! #r',
#  ' ! #re',
#  ' ! #ro',
#  ' ! #s',
#  ' ! #sa',
#  ' ! #sc',
#  ' ! #sf',
#  ' ! #sk',
#  ' ! #st',
#  ' ! #t',
#  ' ! #te',
#  ' ! #to',
#  ' ! #v',
#  ' ! #ve',
#  ' ! #vi',
#  ' ! #vo',
#  ' ! $',
#  ' ! $ ',
#  ' ! $ #',
#  ' ! (',
#  ' ! ( ',
#  ' ! ( c',
#  ' ! ( l',
#  ' ! )',
#  ' ! ) ',
#  ' ! ) #',
#  ' ! ) -',
#  ' ! ) r',
#  ' ! )p',
#  ' ! )po',
#  ' ! )pu',
#  ' ! ,',
#  ' ! , ',
#  ' ! , e',
#  ' ! , m',
#  ' ! , p',
#  ' ! , u',
#  ' ! -',
#  ' ! - ',
#  ' ! - e',
#  ' ! - f',
#  ' ! - s',
#  ' ! -c',
#  ' ! -ci',
#  ' ! .',
#  ' ! . ',
#  ' ! . r',
#  ' ! ..',
#  ' ! ...',
#  ' ! 1',
#  ' ! 14',
#  ' ! 14 ',
#  ' ! 15',
#  ' ! 15 ',
#  ' ! 4',
#  ' ! 40',
#  ' ! 400',
#  ' ! :',
#  ' ! :…',
#  ' ! ?',
#  ' ! ? ',
#  ' ! ? 5',
#  ' ! ? ?',
#  ' ! ? b',
#  ' ! ? c',
#  ' ! ? e',
#  ' ! ? f',
#  ' ! ? i',
#  ' ! ? m',
#  ' ! [',
#  ' ! [ ',
#  ' ! [ s',
#  ' ! a',
#  ' ! a ',
#  ' ! a c',
#  ' ! a l',
#  ' ! a m',
#  ' ! a p',
#  ' ! a r',
#  ' ! a v',
#  ' ! ab',
#  ' ! abb',
#  ' ! ac',
#  ' ! acc',
#  ' ! ad',
#  ' ! ad ',
#  ' ! ade',
#  ' ! ag',
#  ' ! agg',
#  ' ! agl',
#  ' ! ah',
#  ' ! ah ',
#  ' ! ai',
#  ' ! ai ',
#  ' ! aiu',
#  ' ! al',
#  ' ! alf',
#  ' ! all',
#  ' ! alm',
#  ' ! alt',
#  ' ! an',
#  ' ! anc',
#  ' ! and',
#  ' ! anz',
#  ' ! ap',
#  ' ! app',
#  ' ! ar',
#  ' ! arr',
#  ' ! au',
#  ' ! aut',
#  ' ! av',
#  ' ! ava',
#  ' ! ave',
#  ' ! b',
#  ' ! ba',
#  ' ! bao',
#  ' ! bas',
#  ' ! be',
#  ' ! beh',
#  ' ! ber',
#  ' ! bi',
#  ' ! bis',
#  ' ! bo',
#  ' ! bol',
#  ' ! br',
#  ' ! bra',
#  ' ! bu',
#  ' ! buo',
#  ' ! c',
#  " ! c'",
#  " ! c' ",
#  ' ! ce',
#  ' ! cer',
#  ' ! ch',
#  ' ! che',
#  ' ! chi',
#  ' ! ci',
#  ' ! ci ',
#  ' ! cit',
#  ' ! cl',
#  ' ! cla',
#  ' ! cm',
#  ' ! cmq',
#  ' ! co',
#  ' ! com',
#  ' ! con',
#  ' ! cor',
#  ' ! cos',
#  ' ! cr',
#  ' ! cre',
#  ' ! d',
#  ' ! da',
#  ' ! da ',
#  ' ! dat',
#  ' ! dav',
#  ' ! de',
#  ' ! del',
#  ' ! det',
#  ' ! dev',
#  ' ! di',
#  ' ! di ',
#  ' ! dif',
#  ' ! do',
#  ' ! dom',
#  ' ! don',
#  ' ! dop',
#  ' ! dov',
#  ' ! du',
#  ' ! dun',
#  ' ! e',
#  ' ! e ',
#  ' ! e b',
#  ' ! e c',
#  ' ! e d',
#  ' ! e i',
#  ' ! e l',
#  ' ! e n',
#  ' ! e p',
#  ' ! e q',
#  ' ! e s',
#  ' ! e t',
#  ' ! e v',
#  " ! e'",
#  " ! e' ",
#  ' ! ec',
#  ' ! ecc',
#  ' ! el',
#  ' ! ele',
#  ' ! es',
#  ' ! esc',
#  ' ! ese',
#  ' ! esp',
#  ' ! ess',
#  ' ! eu',
#  ' ! eur',
#  ' ! ev',
#  ' ! evv',
#  ' ! e’',
#  ' ! e’ ',
#  ' ! f',
#  ' ! fa',
#  ' ! fac',
#  ' ! fal',
#  ' ! fan',
#  ' ! fat',
#  ' ! fi',
#  ' ! fig',
#  ' ! fin',
#  ' ! fu',
#  ' ! fuc',
#  ' ! fuo',
#  ' ! g',
#  ' ! ge',
#  ' ! ges',
#  ' ! gl',
#  ' ! gli',
#  ' ! go',
#  ' ! gov',
#  ' ! gr',
#  ' ! gra',
#  ' ! gu',
#  ' ! gua',
#  ' ! h',
#  ' ! ha',
#  ' ! ha ',
#  ' ! han',
#  ' ! i',
#  ' ! i ',
#  ' ! i 3',
#  ' ! i b',
#  ' ! i c',
#  ' ! i d',
#  ' ! i l',
#  ' ! i m',
#  ' ! i p',
#  ' ! i r',
#  ' ! i s',
#  ' ! i t',
#  ' ! i z',
#  ' ! id',
#  ' ! idi',
#  ' ! il',
#  ' ! il ',
#  ' ! ili',
#  ' ! im',
#  ' ! imm',
#  ' ! in',
#  ' ! in ',
#  ' ! ind',
#  ' ! inf',
#  ' ! inu',
#  ' ! inv',
#  ' ! io',
#  ' ! io ',
#  ' ! is',
#  ' ! isc',
#  ' ! isl',
#  ' ! it',
#  ' ! ita',
#  ' ! l',
#  " ! l'",
#  " ! l' ",
#  ' ! l`',
#  ' ! l`i',
#  ' ! la',
#  ' ! la ',
#  ' ! le',
#  ' ! le ',
#  ' ! leg',
#  ' ! li',
#  ' ! li ',
#  ' ! lib',
#  ' ! lit',
#  ' ! liv',
#  ' ! lo',
#  ' ! lo ',
#  ' ! lor',
#  ' ! lu',
#  ' ! lui',
#  ' ! l’',
#  ' ! l’ ',
#  ' ! m',
#  ' ! ma',
#  ' ! ma ',
#  ' ! mag',
#  ' ! mah',
#  ' ! mai',
#  ' ! man',
#  ' ! me',
#  ' ! men',
#  ' ! mer',
#  ' ! met',
#  ' ! mi',
#  ' ! mi ',
#  ' ! mig',
#  ' ! mil',
#  ' ! min',
#  ' ! mo',
#  " ! mo'",
#  ' ! mu',
#  ' ! muo',
#  ' ! n',
#  ' ! ne',
#  ' ! nes',
#  ' ! ni',
#  ' ! nie',
#  ' ! nn',
#  ' ! nn ',
#  ' ! no',
#  ' ! no ',
#  ' ! no,',
#  ' ! noi',
#  ' ! non',
#  ' ! nu',
#  ' ! nuo',
#  ' ! o',
#  ' ! o ',
#  ' ! o n',
#  ' ! o q',
#  ' ! od',
#  ' ! odi',
#  ' ! og',
#  ' ! ogg',
#  ' ! on',
#  ' ! ono',
#  ' ! or',
#  ' ! ora',
#  ' ! orm',
#  ' ! p',
#  ' ! pa',
#  ' ! par',
#  ' ! pe',
#  ' ! pec',
#  ' ! per',
#  ' ! pi',
#  ' ! pia',
#  ' ! piu',
#  ' ! più',
#  ' ! po',
#  ' ! poc',
#  ' ! poi',
#  ' ! pol',
#  ' ! por',
#  ' ! pov',
#  ' ! pr',
#  ' ! pre',
#  ' ! pri',
#  ' ! pro',
#  ' ! pu',
#  ' ! pug',
#  ' ! pur',
#  ' ! q',
#  ' ! qa',
#  ' ! qar',
#  ' ! qu',
#  ' ! qua',
#  ' ! que',
#  ' ! qui',
#  ' ! r',
#  ' ! ra',
#  ' ! rag',
#  ' ! ri',
#  ' ! rid',
#  ' ! rie',
#  ' ! rim',
#  ' ! ro',
#  ' ! rob',
#  ' ! rom',
#  ' ! ru',
#  ' ! rub',
#  ' ! rus',
#  ' ! s',
#  ' ! sa',
#  ' ! sai',
#  ' ! sal',
#  ' ! sar',
#  ' ! sc',
#  ' ! sce',
#  ' ! sch',
#  ' ! scr',
#  ' ! se',
#  ' ! se ',
#  ' ! sei',
#  ' ! sem',
#  ' ! sen',
#  ' ! sep',
#  ' ! ser',
#  ' ! sf',
#  ' ! sfa',
#  ' ! si',
#  ' ! si ',
#  ' ! sia',
#  ' ! sin',
#  ' ! so',
#  ' ! sol',
#  ' ! son',
#  ' ! sov',
#  ' ! sp',
#  ' ! spe',
#  ' ! spi',
#  ' ! st',
#  ' ! sta',
#  ' ! sti',
#  ' ! sto',
#  ' ! str',
#  ' ! t',
#  ' ! ta',
#  ' ! tan',
#  ' ! tb',
#  ' ! tbc',
#  ' ! te',
#  ' ! te ',
#  ' ! th',
#  ' ! thi',
#  ' ! ti',
#  ' ! ti ',
#  ' ! tie',
#  ' ! to',
#  ' ! tog',
#  ' ! tor',
#  ' ! tr',
#  ' ! tra',
#  ' ! tri',
#  ' ! tro',
#  ' ! tu',
#  ' ! tu ',
#  ' ! tut',
#  ' ! u',
#  ' ! uc',
#  ' ! ucc',
#  ' ! un',
#  ' ! un ',
#  ' ! una',
#  ' ! uno',
#  ' ! un’',
#  ' ! v',
#  ' ! va',
#  ' ! va ',
#  ' ! val',
#  ' ! ve',
#  ' ! ve ',
#  ' ! ven',
#  ' ! ver',
#  ' ! vi',
#  ' ! vi ',
#  ' ! via',
#  ' ! vis',
#  ' ! vo',
#  ' ! vog',
#  ' ! voi',
#  ' ! vot',
#  ' ! vu',
#  ' ! vuo',
#  ' ! w',
#  ' ! w ',
#  ' ! w l',
#  ' ! x',
#  ' ! x ',
#  ' ! x l',
#  ' ! x q',
#  ' ! x1',
#  ' ! x1v',
#  ' ! «',
#  ' ! « ',
#  ' ! « t',
#  ' ! è',
#  ' ! è ',
#  ' ! è a',
#  ' ! è l',
#  ' ! è p',
#  ' ! è s',
#  ' ! ”',
#  ' ! ” ',
#  ' ! ” #',
#  ' ! ” m',
#  ' ! ” u',
#  ' ! ”,',
#  ' ! ”,p',
#  ' ! ”d',
#  ' ! ”do',
#  ' ! �',
#  ' ! ��',
#  ' ! ���',
#  ' ! 👍',
#  ' ! 👍😄',
#  ' ! 👍😄🇮',
#  ' ! 💩',
#  ' ! 💩🤢',
#  ' ! 💩🤢🤮',
#  ' ! 😂',
#  ' ! 😂#',
#  ' ! 😂#m',
#  ' ! 😂😂',
#  ' ! 😂😂😂',
#  ' ! 😉',
#  ' ! 😉#',
#  ' ! 😉#p',
#  ' ! 😎',
#  ' ! 😎 ',
#  ' ! 😑',
#  ' ! 😑😒',
#  ' ! 😡',
#  ' ! 😡😡',
#  ' ! 😡😡😡',
#  ' ! 😤',
#  ' ! 😤😤',
#  ' ! 😤😤😤',
#  ' ! 😲',
#  ' ! 😲 ',
#  ' ! 😲 i',
#  ' ! 🤬',
#  ' ! 🤬🤦',
#  ' ! 🤬🤦\u200d',
#  ' !!',
#  ' !! ',
#  ' !! !',
#  ' !! ! ',
#  ' !! !!',
#  ' !! !\\',
#  ' !! !p',
#  ' !! !è',
#  ' !! #',
#  ' !! # ',
#  ' !! #2',
#  ' !! #b',
#  ' !! #m',
#  ' !! #p',
#  ' !! #s',
#  ' !! .',
#  ' !! ..',
#  ' !! 9',
#  ' !! 9 ',
#  ' !! ?',
#  ' !! ? ',
#  ' !! b',
#  ' !! be',
#  ' !! c',
#  ' !! cl',
#  ' !! e',
#  ' !! e ',
#  ' !! f',
#  ' !! fa',
#  ' !! fi',
#  ' !! fu',
#  ' !! i',
#  ' !! id',
#  ' !! it',
#  ' !! k',
#  ' !! ko',
#  ' !! n',
#  ' !! no',
#  ' !! r',
#  ' !! ri',
#  ' !! s',
#  ' !! si',
#  ' !! 😡',
#  ' !! 😡😡',
#  ' !!!',
#  ' !!! ',
#  ' !!! !',
#  ' !!! #',
#  ' !!! ?',
#  ' !!! c',
#  ' !!! d',
#  ' !!! e',
#  ' !!! i',
#  ' !!! l',
#  ' !!! m',
#  ' !!! p',
#  ' !!! r',
#  ' !!! s',
#  ' !!! v',
#  ' !!! 😂',
#  ' !!!!',
#  ' !!!! ',
#  ' !!!!!',
#  ' !!!!?',
#  ' !!!!b',
#  ' !!!!h',
#  ' !!!!s',
#  ' !!!)',
#  ' !!!) ',
#  ' !!!:',
#  ' !!!: ',
#  ' !!!?',
#  ' !!!?p',
#  ' !!!a',
#  ' !!!a ',
#  ' !!!e',
#  ' !!!es',
#  ' !!!l',
#  ' !!!la',
#  ' !!!p',
#  ' !!!po',
#  ' !!!v',
#  ' !!!ve',
#  ' !!!⚡',
#  ' !!!⚡⛅',
#  ' !!.',
#  ' !!..',
#  ' !!..v',
#  ' !!1',
#  ' !!1 ',
#  ' !!1 #',
#  ' !!d',
#  ' !!da',
#  ' !!dai',
#  ' !!i',
#  ' !!il',
#  ' !!il ',
#  ' !!in',
#  ' !!in ',
#  ' !!l',
#  ' !!lo',
#  ' !!lo ',
#  ' !!m',
#  ' !!ma',
#  ' !!ma ',
#  ' !!mai',
#  ' !!mi',
#  ' !!mi ',
#  ' !!mo',
#  ' !!mol',
#  ' !!p',
#  ' !!pe',
#  ' !!pez',
#  ' !!s',
#  ' !!se',
#  ' !!se ',
#  ' !!sv',
#  ' !!sve',
#  ' !!u',
#  ' !!un',
#  ' !!una',
#  ' !!👎',
#  ' !!👎👎',
#  ' !!👎👎😠',
#  ' !!😡',
#  ' !!😡👿',
#  ' !"',
#  ' !" ',
#  ' !" .',
#  ' !" .u',
#  ' !#',
#  ' !#m',
#  ' !#mi',
#  ' !#mig',
#  ' !#mo',
#  ' !#mov',
#  ' !#n',
#  ' !#no',
#  ' !#non',
#  ' !#p',
#  ' !#pr',
#  ' !#pri',
#  ' !.',
#  ' !.c',
#  ' !.co',
#  ' !.com',
#  ' !1',
#  ' !1 ',
#  ' !1 !',
#  ' !1 ! ',
#  ' !?',
#  ' !? ',
#  ' !? e',
#  ' !? eh',
#  ' !? r',
#  ' !? ra',
#  ' !\\',
#  ' !\\ ',
#  ' !\\ "',
#  ' !\\ " ',
#  ' !a',
#  ' !a ',
#  ' !a i',
#  ' !a in',
#  ' !ab',
#  ' !abb',
#  ' !abbi',
#  ' !ac',
#  ' !acc',
#  ' !acco',
#  ' !av',
#  ' !ave',
#  ' !avet',
#  ' !avr',
#  ' !avre',
#  ' !b',
#  ' !bi',
#  ' !bis',
#  ' !biso',
#  ' !br',
#  ' !bra',
#  ' !brav',
#  ' !c',
#  ' !ca',
#  ' !cap',
#  ' !capi',
#  ' !ce',
#  ' !cer',
#  ' !cert',
#  ' !ch',
#  ' !che',
#  ' !che ',
#  ' !co',
#  ' !cos',
#  ' !così',
#  ' !d',
#  ' !di',
#  ' !div',
#  ' !dive',
#  ' !do',
#  ' !dov',
#  ' !dovr',
#  ' !e',
#  ' !e ',
#  ' !e g',
#  ' !e gl',
#  ' !e l',
#  ' !e lu',
#  ' !e n',
#  ' !e no',
#  ' !e q',
#  ' !e qu',
#  ' !e v',
#  ' !e vo',
#  ' !es',
#  ' !ess',
#  ' !esse',
#  ' !f',
#  ' !fi',
#  ' !fin',
#  ' !fine',
#  ' !fo',
#  ' !for',
#  ' !fors',
#  ' !fos',
#  ' !foss',
#  ' !g',
#  ' !gl',
#  ' !gli',
#  ' !gli ',
#  ' !i',
#  ' !im',
#  ' !imp',
#  ' !impa',
#  ' !in',
#  ' !in ',
#  ' !in q',
#  ' !inc',
#  ' !inci',
#  ' !l',
#  ' !le',
#  ' !leg',
#  ' !legg',
#  ' !m',
#  ' !ma',
#  ' !ma ',
#  ' !ma c',
#  ' !ma i',
#  ' !n',
#  ' !ne',
#  ' !nem',
#  ' !nemi',
#  ' !no',
#  ' !no ',
#  ' !no s',
#  ' !non',
#  ' !non ',
#  ' !o',
#  ' !or',
#  ' !orm',
#  ' !orma',
#  ' !p',
#  ' !pa',
#  ' !par',
#  ' !para',
#  ' !pe',
#  ' !pen',
#  ' !pens',
#  ' !per',
#  ' !per ',
#  ' !perc',
#  ' !po',
#  ' !pov',
#  ' !pove',
#  ' !q',
#  ' !qu',
#  ' !que',
#  ' !ques',
#  ' !r',
#  ' !ra',
#  ' !ras',
#  ' !rast',
#  ' !ri',
#  ' !rin',
#  ' !ring',
#  ' !s',
#  ' !sc',
#  ' !sco',
#  ' !scop',
#  ' !si',
#  ' !sia',
#  ' !siam',
#  ' !sie',
#  ' !siet',
#  ' !so',
#  ' !sol',
#  ' !sold',
#  ' !t',
#  ' !to',
#  ' !tor',
#  ' !torn',
#  ' !v',
#  ' !vo',
#  ' !vog',
#  ' !vogl',
#  ' !w',
#  ' !w ',
#  ' !w #',
#  ' !w # ',
#  ' !|',
#  ' !|!',
#  ' !|! ',
#  ' !|! !',
#  ' !è',
#  ' !è ',
#  ' !è p',
#  ' !è pe',
#  ' !…',
#  ' !… ',
#  ' !🇮',
#  ' !🇮🇹',
#  ' !🇮🇹👕',
#  ' !👍',
#  ' !👍👍',
#  ' !👍👍👏',
#  ' !👍👍👏👏',
#  ' !👿',
#  ' !😀',
#  ' !😀👍',
#  ' !😀👍✌',
#  ' !😀👍✌️',
#  ' !😡',
#  ' !😡1',
#  ' !😡1 ',
#  ' !😡1 )',
#  ' !😡😡',
#  ' !😡😡😡',
#  ' "',
#  ' " ',
#  ' " !',
#  ' " ! ',
#  ' " ! !',
#  ' " ! #',
#  ' " ! i',
#  ' " ! l',
#  ' " ! è',
#  ' " !!',
#  ' " !!!',
#  ' " "',
#  ' " " ',
#  ' " " "',
#  ' " " b',
#  ' " " c',
#  ' " " i',
#  ' " " n',
#  ...]

# %%
coefs = clf.coef_
coefs.shape
# Out:
# (1, 368097)

# %%
idx = 0
class_coefs = coefs[idx]

feature_importances = {feature_name: coef for feature_name,
                       coef in zip(features_names, class_coefs)}
sorted_feature_importances = dict(
    sorted(feature_importances.items(), key=lambda item: item[1], reverse=True))

# importances, names = zip(*sorted(zip(feature_importance, features)))

num_to_plot = 15
print(f'Feature importance classe {clf.classes_[idx]}')
plt.barh(range(num_to_plot), list(sorted_feature_importances.values())
         [:num_to_plot], align='center')
plt.yticks(range(num_to_plot), list(
    sorted_feature_importances.keys())[:num_to_plot])
plt.gca().invert_yaxis()
plt.savefig("coefs_n_grammi_caratteri.svg")
# Out:
# Feature importance classe 0

# %%
scores = cross_val_score(clf, X_test, y_test_hs, cv=5)
print(scores)
print('media:', np.mean(scores))
# Out:
# [0.84 0.78 0.9  0.73 0.85]
# media: 0.82

# %% [markdown]
# # N-grammi di parole

# %%
# Convertire le frasi CoNLL-U in una lista di stringhe
train_strings = conllu_sentences_to_strings(sentences_train)
test_strings = conllu_sentences_to_strings(sentences_test)

# Creare un CountVectorizer per gli n-grammi di parole (fino a 6)
vectorizer = CountVectorizer(analyzer='word', ngram_range=(1, 6))

# Trasformare le frasi in una matrice delle feature
X_train = vectorizer.fit_transform(train_strings)
X_test = vectorizer.transform(test_strings)

# Addestrare e valutare il modello LinearSVC
clf = LinearSVC(max_iter=10000, C=0.001, dual=False)
clf.fit(X_train, y_train_hs)
y_pred = clf.predict(X_test)

print(classification_report(y_test_hs, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.67      0.99      0.80       319
#            1       0.93      0.15      0.27       181
#
#     accuracy                           0.69       500
#    macro avg       0.80      0.57      0.53       500
# weighted avg       0.77      0.69      0.61       500

# %%
features_names = vectorizer.get_feature_names_out(X_train).tolist()
features_names
# Out:
# ['00',
#  '00 come',
#  '00 come in',
#  '00 come in altre',
#  '00 come in altre città',
#  '00 come in altre città italiane',
#  '00 dica',
#  '00 dica una',
#  '00 dica una parola',
#  '00 dica una parola per',
#  '00 dica una parola per le',
#  '00 euro',
#  '00 euro ma',
#  '00 euro ma dove',
#  '00 euro ma dove cazzo',
#  '00 euro ma dove cazzo vogliamo',
#  '00 per',
#  '00 per lo',
#  '00 per lo smantellamento',
#  '00 per lo smantellamento del',
#  '00 per lo smantellamento del di',
#  '00 unità',
#  '000',
#  '000 00',
#  '000 00 per',
#  '000 00 per lo',
#  '000 00 per lo smantellamento',
#  '000 00 per lo smantellamento del',
#  '000 000',
#  '000 000 000',
#  '000 000 000 trentasei',
#  '000 000 000 trentasei miliardi',
#  '000 000 000 trentasei miliardi in',
#  '000 000 di',
#  '000 000 di molto',
#  '000 000 di molto poveri',
#  '000 000 di persone',
#  '000 000 di poveri',
#  '000 000 di poveri centinaia',
#  '000 000 di poveri centinaia di',
#  '000 000 di stranieri',
#  '000 000 di stranieri residenti',
#  '000 000 di stranieri residenti in',
#  '000 000 ovvero',
#  '000 000 ovvero il',
#  '000 000 ovvero il piagnoni',
#  '000 000 ovvero il piagnoni dallavostraparte',
#  '000 000 ovvero lo',
#  '000 000 ovvero lo 002',
#  '000 000 ovvero lo 002 piagnoni',
#  '000 000 trentasei',
#  '000 000 trentasei miliardi',
#  '000 000 trentasei miliardi in',
#  '000 000 trentasei miliardi in più',
#  '000 abusivi',
#  '000 abusivi migranti',
#  '000 abusivi migranti clandestini',
#  '000 abusivi migranti clandestini soonooo',
#  '000 abusivi migranti clandestini soonooo pooochiiìi',
#  '000 almeno',
#  '000 almeno sono',
#  '000 almeno sono senza',
#  '000 almeno sono senza luce',
#  '000 almeno sono senza luce acqua',
#  '000 arrivati',
#  '000 arrivati nel',
#  '000 arrivati nel in',
#  '000 arrivati nel in il',
#  '000 arrivati nel in il 2016',
#  '000 cittadini',
#  '000 cittadini del',
#  '000 cittadini del di',
#  '000 cittadini del di il',
#  '000 cittadini del di il lazio',
#  '000 dei',
#  '000 dei di',
#  '000 dei di ragazzi',
#  '000 dei di ragazzi compresi',
#  '000 dei di ragazzi compresi tra',
#  '000 di',
#  '000 di molto',
#  '000 di molto poveri',
#  '000 di persone',
#  '000 di poveri',
#  '000 di poveri centinaia',
#  '000 di poveri centinaia di',
#  '000 di poveri centinaia di migliaia',
#  '000 di stranieri',
#  '000 di stranieri residenti',
#  '000 di stranieri residenti in',
#  '000 di stranieri residenti in italia',
#  '000 di troppo',
#  '000 di troppo se',
#  '000 di troppo se ci',
#  '000 di troppo se ci fa',
#  '000 difendiamo',
#  '000 difendiamo il',
#  '000 difendiamo il diritto',
#  '000 difendiamo il diritto di',
#  '000 difendiamo il diritto di essere',
#  '000 euro',
#  '000 euro come',
#  '000 euro come una',
#  '000 euro come una rolls',
#  '000 euro come una rolls royce',
#  '000 euro dal',
#  '000 euro dal da',
#  '000 euro dal da il',
#  '000 euro dal da il comune',
#  '000 euro insediamento',
#  '000 euro insediamento per',
#  '000 euro insediamento per soli',
#  '000 euro insediamento per soli rom',
#  '000 euro per',
#  '000 euro per terrorista',
#  '000 euro per terrorista ucciso',
#  '000 euro per terrorista ucciso la',
#  '000 gestiscono',
#  '000 gestiscono spaccio',
#  '000 gestiscono spaccio prostituzione',
#  '000 gestiscono spaccio prostituzione accattonaggio',
#  '000 gestiscono spaccio prostituzione accattonaggio potenza',
#  '000 gli',
#  '000 gli immigrati',
#  '000 gli immigrati giunti',
#  '000 gli immigrati giunti in',
#  '000 gli immigrati giunti in italia',
#  '000 glieli',
#  '000 glieli glie',
#  '000 glieli glie li',
#  '000 glieli glie li mandi',
#  '000 glieli glie li mandi volentieri',
#  '000 immigrati',
#  '000 immigrati illegali',
#  '000 immigrati illegali dall',
#  '000 immigrati illegali dall italia',
#  '000 immigrati illegali dall italia aiutoamoli',
#  '000 immigrati illegali senza',
#  '000 immigrati illegali senza nessuna',
#  '000 immigrati illegali senza nessuna possibilità',
#  '000 immigrati illegali tra',
#  '000 immigrati illegali tra quali',
#  '000 immigrati illegali tra quali molti',
#  '000 immigrati irregolari',
#  '000 immigrati irregolari chi',
#  '000 immigrati irregolari chi ha',
#  '000 immigrati irregolari chi ha sostenuto',
#  '000 in',
#  '000 in italia',
#  '000 in italia nel',
#  '000 in italia nel in',
#  '000 in italia nel in il',
#  '000 in paesi',
#  '000 in paesi dove',
#  '000 in paesi dove lo',
#  '000 in paesi dove lo stipendio',
#  '000 italiani',
#  '000 italiani emigrati',
#  '000 italiani emigrati xché',
#  '000 italiani emigrati xché disoccupati',
#  '000 italiani emigrati xché disoccupati 181',
#  '000 le',
#  '000 le 180',
#  '000 le 180 00',
#  '000 le 180 00 unità',
#  '000 migrante',
#  '000 migrante del',
#  '000 migrante del di',
#  '000 migrante del di il',
#  '000 migrante del di il 2016',
#  '000 migranti',
#  '000 migranti ammassati',
#  '000 migranti ammassati in',
#  '000 migranti ammassati in croazia',
#  '000 migranti ammassati in croazia pronti',
#  '000 migranti che',
#  '000 migranti che erano',
#  '000 migranti che erano seguiti',
#  '000 migranti che erano seguiti verso',
#  '000 migranti ogni',
#  '000 migranti ogni anno',
#  '000 minori',
#  '000 minori rom',
#  '000 minori rom vivono',
#  '000 minori rom vivono in',
#  '000 minori rom vivono in povertà',
#  '000 noi',
#  '000 noi siamo',
#  '000 noi siamo 60',
#  '000 noi siamo 60 000',
#  '000 noi siamo 60 000 000',
#  '000 ovvero',
#  '000 ovvero il',
#  '000 ovvero il piagnoni',
#  '000 ovvero il piagnoni dallavostraparte',
#  '000 ovvero lo',
#  '000 ovvero lo 002',
#  '000 ovvero lo 002 piagnoni',
#  '000 ovvero lo 002 piagnoni dallavostraparte',
#  '000 pensioni',
#  '000 per',
#  '000 per il',
#  '000 per il battesimo',
#  '000 per il battesimo del',
#  '000 per il battesimo del di',
#  '000 per lo',
#  '000 per lo più',
#  '000 per lo più clandestini',
#  '000 persone',
#  '000 persone di',
#  '000 persone di cui',
#  '000 persone di cui un',
#  '000 persone di cui un terzo',
#  '000 persone ris',
#  '000 persone sono',
#  '000 persone sono morte',
#  '000 persone sono morte in',
#  '000 persone sono morte in mare',
#  '000 procedure',
#  '000 procedure relative',
#  '000 procedure relative ai',
#  '000 procedure relative ai presunti',
#  '000 procedure relative ai presunti profughi',
#  '000 profughi',
#  '000 profughi siriani',
#  '000 profughi siriani sono',
#  '000 profughi siriani sono ritornati',
#  '000 profughi siriani sono ritornati nella',
#  '000 pseudo',
#  '000 pseudo profughi',
#  '000 pseudo profughi vediamo',
#  '000 pseudo profughi vediamo se',
#  '000 pseudo profughi vediamo se gli',
#  '000 richiedenti',
#  '000 richiedenti asilo',
#  '000 richiedenti asilo ciò',
#  '000 richiedenti asilo ciò che',
#  '000 richiedenti asilo ciò che dovrebbe',
#  '000 rom',
#  '000 rom che',
#  '000 rom che sono',
#  '000 rom che sono italiani',
#  '000 rom che sono italiani con',
#  '000 rom in',
#  '000 rom in emergenza',
#  '000 rom in emergenza abitativa',
#  '000 rom in emergenza abitativa in',
#  '000 rom italiani',
#  '000 rom italiani ora',
#  '000 rom italiani ora chi',
#  '000 rom italiani ora chi glielo',
#  '000 sbarchi',
#  '000 sbarchi ma',
#  '000 sbarchi ma vorrei',
#  '000 sbarchi ma vorrei far',
#  '000 sbarchi ma vorrei far osservare',
#  '000 sbarchi sino',
#  '000 sbarchi sino quando',
#  '000 somali',
#  '000 somali cui',
#  '000 somali cui stato',
#  '000 somali cui stato tolto',
#  '000 somali cui stato tolto lo',
#  '000 trentasei',
#  '000 trentasei miliardi',
#  '000 trentasei miliardi in',
#  '000 trentasei miliardi in più',
#  '000 trentasei miliardi in più il',
#  '000 volte',
#  '000 volte la',
#  '000 volte la loro',
#  '000 volte la loro presenza',
#  '000 volte la loro presenza senza',
#  '002',
#  '002 piagnoni',
#  '002 piagnoni dallavostraparte',
#  '007',
#  '03',
#  '03 41',
#  '03 41 la',
#  '03 41 la maggior',
#  '03 41 la maggior parte',
#  '03 41 la maggior parte dei',
#  '04',
#  '04 h11',
#  '04 h11 lancio',
#  '04 h11 lancio prima',
#  '04 h11 lancio prima app',
#  '04 h11 lancio prima app per',
#  '04 marzo',
#  '04 marzo 2017',
#  '04 marzo 2017 03',
#  '04 marzo 2017 03 41',
#  '04 marzo 2017 03 41 la',
#  '04 roba',
#  '04 roba da',
#  '04 roba da paraculo',
#  '04 roba da paraculo piddini',
#  '05',
#  '05 della',
#  '05 della di',
#  '05 della di la',
#  '05 della di la popolazione',
#  '05 della di la popolazione italiana',
#  '06',
#  '06 18',
#  '06 18 macron',
#  '06 18 macron linea',
#  '06 18 macron linea del',
#  '06 18 macron linea del di',
#  '08',
#  '08 di',
#  '08 di radio',
#  '08 di radio voce',
#  '08 di radio voce della',
#  '08 di radio voce della di',
#  '085',
#  '085 al',
#  '085 al il',
#  '085 al il mese',
#  '085 al il mese europa',
#  '085 al il mese europa ok',
#  '088',
#  '088 immigrati',
#  '088 immigrati affetti',
#  '088 immigrati affetti da',
#  '088 immigrati affetti da malattie',
#  '088 immigrati affetti da malattie infettive',
#  '09',
#  '09 18',
#  '09 18 macron',
#  '09 18 macron chiude',
#  '09 18 macron chiude porti',
#  '09 18 macron chiude porti 58',
#  '09 2018',
#  '09 2018 dalle',
#  '09 2018 dalle da',
#  '09 2018 dalle da le',
#  '09 2018 dalle da le 30',
#  '10',
#  '10 100',
#  '10 100 1000',
#  '10 100 1000 rivolte',
#  '10 100 1000 rivolte come',
#  '10 100 1000 rivolte come cona',
#  '10 anni',
#  '10 anni di',
#  '10 anni di governi',
#  '10 anni di governi di',
#  '10 anni di governi di merda',
#  '10 anni di questa',
#  '10 anni di questa importazione',
#  '10 anni di questa importazione scellerata',
#  '10 anni ed',
#  '10 anni ed esclude',
#  '10 anni ed esclude disoccupati',
#  '10 anni ed esclude disoccupati italiani',
#  '10 anni europa',
#  '10 anni europa sarà',
#  '10 anni europa sarà islamica',
#  '10 anni europa sarà islamica grazie',
#  '10 anni fa',
#  '10 anni fa non',
#  '10 anni fa non esisteva',
#  '10 anni fa non esisteva quasi',
#  '10 anni hanno',
#  '10 anni hanno la',
#  '10 anni hanno la cittadinanza',
#  '10 anni hanno la cittadinanza italiana',
#  '10 anni il',
#  '10 anni il vicepremier',
#  '10 anni il vicepremier dimaio',
#  '10 anni il vicepremier dimaio che',
#  '10 anni impugniamo',
#  '10 anni impugniamo la',
#  '10 anni impugniamo la spada',
#  '10 anni impugniamo la spada della',
#  '10 anni le',
#  '10 anni le nostre',
#  '10 anni le nostre donne',
#  '10 anni le nostre donne gireranno',
#  '10 anni maledetti',
#  '10 anni maledetti accoglioni',
#  '10 anni maledetti accoglioni bastardi',
#  '10 anni nel',
#  '10 anni nel in',
#  '10 anni nel in il',
#  '10 anni nel in il braccio',
#  '10 anni non',
#  '10 anni non sanno',
#  '10 anni non sanno ancora',
#  '10 anni non sanno ancora parlare',
#  '10 anni quindi',
#  '10 anni quindi tutti',
#  '10 anni quindi tutti indistintamente',
#  '10 anni quindi tutti indistintamente prescindere',
#  '10 anni saremo',
#  '10 anni saremo ancora',
#  '10 anni saremo ancora qui',
#  '10 anni saremo ancora qui discuterne',
#  '10 anni tutti',
#  '10 anni tutti napoletani',
#  '10 anni tutti napoletani purosangue',
#  '10 anni tutti napoletani purosangue oltre',
#  '10 barche',
#  '10 barche quindi',
#  '10 barche quindi la',
#  '10 barche quindi la spagna',
#  '10 barche quindi la spagna si',
#  '10 della',
#  '10 della di',
#  '10 della di la',
#  '10 della di la popolazione',
#  '10 della di la popolazione europea',
#  '10 della di la popolazione residente',
#  '10 denunce',
#  '10 denunce seq',
#  '10 di',
#  '10 di migranti',
#  '10 di migranti guerra',
#  '10 di migranti guerra gli',
#  '10 di migranti guerra gli altri',
#  '10 domande',
#  '10 domande che',
#  '10 domande che hai',
#  '10 domande che hai sempre',
#  '10 domande che hai sempre voluto',
#  '10 ed',
#  '10 ed della',
#  '10 ed della di',
#  '10 ed della di la',
#  '10 ed della di la coppadelmondo',
#  '10 fatti',
#  '10 fatti da',
#  '10 fatti da stranieri',
#  '10 fatti da stranieri sempre',
#  '10 fatti da stranieri sempre più',
#  '10 in',
#  '10 in tutta',
#  '10 in tutta italia',
#  '10 in tutta italia non',
#  '10 in tutta italia non contiamo',
#  '10 indagati',
#  '10 informiamoci',
#  '10 informiamoci prima',
#  '10 informiamoci prima di',
#  '10 informiamoci prima di fare',
#  '10 informiamoci prima di fare paragoni',
#  '10 ma',
#  '10 ma siamo',
#  '10 ma siamo sulla',
#  '10 ma siamo sulla su',
#  '10 ma siamo sulla su la',
#  '10 marzo',
#  '10 marzo con',
#  '10 marzo con una',
#  '10 marzo con una serata',
#  '10 marzo con una serata dedicata',
#  '10 marzo convegno',
#  '10 marzo convegno al',
#  '10 marzo convegno al il',
#  '10 marzo convegno al il mamiani',
#  '10 mila',
#  '10 mila euro',
#  '10 mila euro italia',
#  '10 mila euro italia da',
#  '10 mila euro italia da paesi',
#  '10 miliardi',
#  '10 miliardi al',
#  '10 miliardi al il',
#  '10 miliardi al il mondo',
#  '10 miliardi al il mondo che',
#  '10 miliardi annuali',
#  '10 miliardi annuali questa',
#  '10 miliardi annuali questa un',
#  '10 miliardi annuali questa un invasione',
#  '10 milioni',
#  '10 milioni di',
#  '10 milioni di euro',
#  '10 milioni di euro via',
#  '10 min',
#  '10 min di',
#  '10 min di gabbia',
#  '10 min di gabbia voltate',
#  '10 min di gabbia voltate le',
#  '10 minuti',
#  '10 minuti da',
#  '10 minuti da 30',
#  '10 minuti da 30 anni',
#  '10 minuti da 30 anni porci',
#  '10 morti',
#  '10 morti anche',
#  '10 morti anche un',
#  '10 morti anche un turista',
#  '10 no',
#  '10 no della',
#  '10 no della di',
#  '10 no della di la',
#  '10 no della di la mia',
#  '10 persone',
#  '10 radicalizzato',
#  '10 radicalizzato pronto',
#  '10 radicalizzato pronto al',
#  '10 radicalizzato pronto al il',
#  '10 radicalizzato pronto al il terrorismo',
#  '10 rom',
#  '10 rom incinte',
#  '10 rom incinte boom',
#  '10 rom incinte boom di',
#  '10 rom incinte circonda',
#  '10 rom incinte circonda rapina',
#  '10 rom incinte circonda rapina turista',
#  '10 sono',
#  '10 sono clandestini',
#  '10 sono vittime',
#  '10 sono vittime di',
#  '10 sono vittime di epatite',
#  '10 sono vittime di epatite ma',
#  '10 volte',
#  '10 volte intercettazione',
#  '10 volte intercettazione ambientale',
#  '100',
#  '100 000',
#  '100 000 pseudo',
#  '100 000 pseudo profughi',
#  '100 000 pseudo profughi vediamo',
#  '100 000 pseudo profughi vediamo se',
#  '100 000 rom',
#  '100 000 rom che',
#  '100 000 rom che sono',
#  '100 000 rom che sono italiani',
#  '100 1000',
#  '100 1000 rivolte',
#  '100 1000 rivolte come',
#  '100 1000 rivolte come cona',
#  '100 1000 rivolte come cona il',
#  '100 anni',
#  '100 anni m5s',
#  '100 anni m5s usciti',
#  '100 anni m5s usciti dall',
#  '100 anni m5s usciti dall da',
#  '100 anni metterci',
#  '100 anni metterci metter',
#  '100 anni metterci metter ci',
#  '100 anni metterci metter ci tutti',
#  '100 giorni',
#  '100 giorni il',
#  '100 giorni il decreto',
#  '100 giorni il decreto sull',
#  '100 giorni il decreto sull su',
#  '100 immigrati',
#  '100 immigrati la',
#  '100 immigrati la maggior',
#  '100 immigrati la maggior parte',
#  '100 km',
#  '100 km dalla',
#  '100 km dalla da',
#  '100 km dalla da la',
#  '100 km dalla da la casa',
#  '100 milioni',
#  '100 milioni profughi',
#  '100 milioni profughi pronti',
#  '100 milioni profughi pronti venire',
#  '100 milioni profughi pronti venire qui',
#  '100 minori',
#  '100 minori stranieri',
#  '100 minori stranieri soli',
#  '100 minori stranieri soli irreperibili',
#  '100 minori stranieri soli irreperibili dopo',
#  '100 morti',
#  '100 morti nell',
#  '100 morti nell in',
#  '100 morti nell in attentato',
#  '100 morti nell in attentato terroristico',
#  '100 persone',
#  '100 persone anno',
#  '100 persone anno lasciano',
#  '100 persone anno lasciano riace',
#  '100 persone anno lasciano riace per',
#  '100 persone in',
#  '100 persone in mezzo',
#  '100 persone in mezzo ad',
#  '100 persone in mezzo ad una',
#  '100 poliziotti',
#  '100 poliziotti io',
#  '100 poliziotti io pago',
#  '100 profughi',
#  '100 profughi al',
#  '100 profughi al il',
#  '100 profughi al il giorno',
#  '100 profughi al il giorno lasciano',
#  '100 sono',
#  '100 sono clandestini',
#  '100 sono clandestini in',
#  '100 sono clandestini in gran',
#  '100 sono clandestini in gran parte',
#  '100 terroristi',
#  '100 terroristi giustiziati',
#  '100 terroristi giustiziati non',
#  '100 terroristi giustiziati non siamo',
#  '100 terroristi giustiziati non siamo ancora',
#  '100 tra',
#  '100 tra parenti',
#  '100 tra parenti amici',
#  '100 tra parenti amici vanno',
#  '100 tra parenti amici vanno trovarli',
#  '1000',
#  '1000 abitanti',
#  '1000 abitanti 23',
#  '1000 abitanti 23 ma',
#  '1000 abitanti 23 ma ha',
#  '1000 abitanti 23 ma ha fallito',
#  '1000 al',
#  '1000 al il',
#  '1000 al il mese',
#  '1000 al il mese telefonino',
#  '1000 al il mese telefonino si',
#  '1000 euro',
#  '1000 euro al',
#  '1000 euro al il',
#  '1000 euro al il mese',
#  '1000 euro al il mese questi',
#  '1000 gilet',
#  '1000 gilet giali',
#  '1000 gilet giali svedesi',
#  '1000 gilet giali svedesi davanti',
#  '1000 gilet giali svedesi davanti al',
#  '1000 immigrati',
#  '1000 immigrati rimpatrio',
#  '1000 immigrati rimpatrio volontario',
#  '1000 immigrati rimpatrio volontario 600',
#  '1000 immigrati rimpatrio volontario 600 rifarsi',
#  '1000 mese',
#  '1000 mese cadauno',
#  '1000 mese cadauno migranti',
#  '1000 mese cadauno migranti italiani',
#  '1000 mese cadauno migranti italiani in',
#  '1000 nigeriani',
#  '1000 nigeriani in',
#  '1000 nigeriani in zona',
#  '1000 nigeriani in zona già',
#  '1000 nigeriani in zona già problematica',
#  '1000 rivolte',
#  '1000 rivolte come',
#  '1000 rivolte come cona',
#  '1000 rivolte come cona il',
#  '1000 rivolte come cona il comportamento',
#  '1000 somali',
#  '1000 somali la',
#  '1000 somali la guerra',
#  '1000 somali la guerra finita',
#  '1000 somali la guerra finita tornate',
#  '1000 uomini',
#  '1000 uomini ti',
#  '1000 uomini ti liberiamo',
#  '1000 uomini ti liberiamo italia',
#  '1000 uomini ti liberiamo italia in',
#  '100000',
#  '100000 volte',
#  '100000 volte mezzadri',
#  '100000 volte mezzadri che',
#  '100000 volte mezzadri che mezziladri',
#  '1000euri',
#  '1000euri dopo',
#  '1000euri dopo essersela',
#  '1000euri dopo essersela esser',
#  '1000euri dopo essersela esser se',
#  '1000euri dopo essersela esser se la',
#  '1000uomini',
#  '1000uomini alla',
#  '1000uomini alla la',
#  '1000uomini alla la ricerca',
#  '1000uomini alla la ricerca di',
#  '1000uomini alla la ricerca di 1di',
#  '100dei',
#  '100dei nomadi',
#  '100dei nomadi delinquono',
#  '100dei nomadi delinquono questi',
#  '100dei nomadi delinquono questi si',
#  '100dei nomadi delinquono questi si che',
#  '100mila',
#  '100mila euro',
#  '100mila euro di',
#  '100mila euro di taglia',
#  '100mila euro di taglia della',
#  '100mila euro di taglia della di',
#  '100mila euro per',
#  '100mila euro per la',
#  '100mila euro per la guardia',
#  '100mila euro per la guardia nei',
#  '100mila gli',
#  '100mila gli sbarchi',
#  '100mila gli sbarchi capisco',
#  '100mila gli sbarchi capisco che',
#  '100mila gli sbarchi capisco che sinistra',
#  '100mila migranti',
#  '100mila migranti oggi',
#  '100mila migranti oggi 20mila',
#  '100milioni',
#  '100milioni di',
#  '100milioni di facce',
#  '100milioni di facce di',
#  '100milioni di facce di maiale',
#  '100milioni di facce di maiale islamici',
#  '102',
#  '102 profughi',
#  '102 profughi destinati',
#  '102 profughi destinati alla',
#  '102 profughi destinati alla la',
#  '102 profughi destinati alla la valle',
#  '103',
#  '103 milioni',
#  '103 milioni per',
#  '103 milioni per altri',
#  '103 milioni per altri 8074',
#  '103 milioni per altri 8074 migranti',
#  '104',
#  '104 euro',
#  '104 euro cui',
#  '104 euro cui si',
#  '104 euro cui si sommano',
#  '104 euro cui si sommano 204',
#  '10aprile',
#  '10aprile cassimatis',
#  '10aprile cassimatis g7energy',
#  '10marzo',
#  '10marzo di',
#  '10marzo di brescia',
#  '10marzo di brescia col',
#  '10marzo di brescia col con',
#  '10marzo di brescia col con il',
#  '10min',
#  '10min erano',
#  '10min erano terrorizzati',
#  '10mo',
#  '10mo della',
#  '10mo della di',
#  '10mo della di la',
#  '10mo della di la cifra',
#  '10mo della di la cifra moab',
#  '11',
#  '11 anni',
#  '11 anni guidava',
#  '11 anni guidava un',
#  '11 anni guidava un auto',
#  '11 anni guidava un auto rubata',
#  '11 dei',
#  '11 dei di',
#  '11 dei di condannati',
#  '11 dei di condannati per',
#  '11 dei di condannati per reati',
#  '11 febbraio',
#  '11 feriti',
#  '11 feriti video',
#  '11 feriti video islam',
#  '11 feriti video islam la',
#  '11 feriti video islam la negazione',
#  '11 mi',
#  '11 mi occuperò',
#  '11 mi occuperò dei',
#  '11 mi occuperò dei di',
#  '11 mi occuperò dei di casamonica',
#  '11 stranieri',
#  '11 stranieri in',
#  '11 stranieri in campo',
#  '11 stranieri in campo siamo',
#  '11 stranieri in campo siamo internazionali',
#  '110',
#  '110 lo',
#  '110 lo puoi',
#  '110 lo puoi acquistare',
#  '110 lo puoi acquistare solo',
#  '110 lo puoi acquistare solo su',
#  '110 nel',
#  '110 nel in',
#  '110 nel in il',
#  '110 nel in il 2018',
#  '110 nel in il 2018 nessun',
#  '11000',
#  '11000 immigrati',
#  '11000 immigrati sono',
#  '11000 immigrati sono pochi',
#  '11000 immigrati sono pochi pdiota',
#  '11000 immigrati sono pochi pdiota prenditela',
#  '114',
#  '114 le',
#  '114 le donne',
#  '114 le donne uccise',
#  '114 le donne uccise in',
#  '114 le donne uccise in italia',
#  '1150',
#  '1150 mese',
#  '1150 mese padroni',
#  '1150 mese padroni casa',
#  '1150 mese padroni casa nostra',
#  '1150 mese padroni casa nostra senza',
#  '117',
#  '117 migranti',
#  '117 migranti sbarcati',
#  '117 migranti sbarcati pozzallo',
#  '117 migranti sbarcati pozzallo anche',
#  '117 migranti sbarcati pozzallo anche la',
#  '118',
#  '118 soccorritori',
#  '118 soccorritori costretti',
#  '118 soccorritori costretti alla',
#  '118 soccorritori costretti alla la',
#  '118 soccorritori costretti alla la fuga',
#  '11enne',
#  '11enne sono',
#  '11enne sono stati',
#  '11enne sono stati rilasciati',
#  '11enne sono stati rilasciati le',
#  '11enne sono stati rilasciati le femministe',
#  '11f',
#  '11f una',
#  '11f una serata',
#  '11f una serata all',
#  '11f una serata all insegna',
#  '11f una serata all insegna della',
#  '11miliardi',
#  '11miliardi di',
#  '11miliardi di contributi',
#  '11miliardi di contributi providenziali',
#  '11miliardi di contributi providenziali 640',
#  '11miliardi di contributi providenziali 640 000',
#  '12',
#  '12 06',
#  '12 06 18',
#  '12 06 18 macron',
#  '12 06 18 macron linea',
#  '12 06 18 macron linea del',
#  '12 13',
#  '12 13 scippi',
#  '12 13 scippi di',
#  '12 13 scippi di cellulari',
#  '12 30',
#  '12 30 presso',
#  '12 30 presso sala',
#  '12 30 presso sala galmozzi',
#  '12 30 presso sala galmozzi del',
#  '12 40',
#  '12 40 roma',
#  '12 40 roma ldl',
#  '12 40 roma ldl si',
#  '12 40 roma ldl si dissocia',
#  '12 al',
#  '12 al il',
#  '12 al il 24',
#  '12 al il 24 tutte',
#  '12 al il 24 tutte le',
#  '12 anni',
#  '12 anni fatta',
#  '12 anni fatta abortire',
#  '12 anni fatta abortire volte',
#  '12 anni riferimenti',
#  '12 anni riferimenti all',
#  '12 anni riferimenti all immigrazione',
#  '12 anni riferimenti all immigrazione nei',
#  '12 arresti',
#  '12 cristiani',
#  '12 cristiani per',
#  '12 cristiani per una',
#  '12 cristiani per una disputa',
#  '12 cristiani per una disputa di',
#  '12 enne',
#  '12 enne partorisce',
#  '12 enne partorisce lascia',
#  '12 enne partorisce lascia la',
#  '12 enne partorisce lascia la scuola',
#  '12 enni',
#  '12 enni che',
#  '12 enni che co',
#  '12 enni che co tutti',
#  '12 enni che co tutti sti',
#  '12 mesi',
#  '12 mesi ho',
#  '12 mesi ho chiesto',
#  '12 mesi ho chiesto boldrini',
#  '12 mesi ho chiesto boldrini quanti',
#  '12 metri',
#  '12 migranti',
#  '12 migranti alla',
#  '12 migranti alla la',
#  '12 migranti alla la marina',
#  '12 migranti alla la marina libica',
#  '12 migranti di',
#  '12 migranti di fame',
#  '12 migranti di fame di',
#  '12 migranti di fame di sete',
#  '12 migranti si',
#  '12 migranti si sono',
#  '12 migranti si sono stabiliti',
#  '12 migranti si sono stabiliti nel',
#  '12 milioni',
#  '12 milioni ai',
#  '12 milioni ai rom',
#  '12 milioni ai rom gli',
#  '12 milioni ai rom gli italiani',
#  '12 milioni ai rom il',
#  '12 milioni ai rom il giornale',
#  '12 milioni di',
#  '12 milioni di euro',
#  '12 milioni di euro per',
#  '12 milioni di euro per un',
#  '12 milioni di euro roma',
#  '12 milioni di per',
#  '12 milioni di per rom',
#  '12 milioni di per rom applausi',
#  '12 milioni di profughi',
#  '12 milioni di profughi dopo',
#  '12 milioni la',
#  '12 milioni la raggi',
#  '12 milioni la raggi potrebbe',
#  '12 milioni la raggi potrebbe fare',
#  '12 milioni per',
#  '12 milioni per campi',
#  '12 milioni per campi rom',
#  '12 milioni per campi rom roma',
#  '12 milioni per rom',
#  '12 milioni per rom in',
#  '12 milioni per rom in invece',
#  '12 millioni',
#  '12 millioni di',
#  '12 millioni di euro',
#  '12 millioni di euro per',
#  '12 millioni di euro per rom',
#  '12 ml',
#  '12 ml di',
#  '12 ml di euro',
#  '12 ml di euro per',
#  '12 ml di euro per sistemare',
#  '12 ore',
#  '12 ore al',
#  '12 ore al il',
#  '12 ore al il giorno',
#  '12 ore al il giorno ai',
#  '12 pregiudicati',
#  '12 pregiudicati stranieri',
#  '12 pregiudicati stranieri ma',
#  '12 pregiudicati stranieri ma che',
#  '12 pregiudicati stranieri ma che diavolo',
#  '120',
#  '120 000',
#  '120 000 le',
#  '120 000 le 180',
#  '120 000 le 180 00',
#  '120 000 le 180 00 unità',
#  '120 migranti',
#  '120 migranti ticino',
#  '127',
#  '127 miliardi',
#  '127 miliardi via',
#  '128',
#  '128 espulsioni',
#  '128 espulsioni solo',
#  '128 espulsioni solo quest',
#  '128 espulsioni solo quest anno',
#  '128 espulsioni solo quest anno traghettati',
#  '129',
#  '129 migranti',
#  '129 migranti polizia',
#  '129 migranti polizia finanza',
#  '129 migranti polizia finanza blogsicilianotizie',
#  '12enne',
#  '12h',
#  '12h ho',
#  '12h ho osato',
#  '12h ho osato dire',
#  '12h ho osato dire che',
#  '12h ho osato dire che nel',
#  '12m',
#  '12milioni',
#  '12milioni di',
#  '12milioni di euro',
#  '12milioni di euro in',
#  '12milioni di euro in favore',
#  '12milioni di euro in favore dei',
#  '13',
#  '13 104',
#  '13 104 euro',
#  '13 104 euro cui',
#  '13 104 euro cui si',
#  '13 104 euro cui si sommano',
#  '13 23',
#  '13 308',
#  '13 308 euro',
#  '13 308 euro all',
#  '13 308 euro all anno',
#  '13 308 euro all anno 35',
#  '13 anni',
#  '13 anni milano',
#  '13 anni milano arrestato',
#  '13 anni milano arrestato un',
#  '13 anni milano arrestato un latitante',
#  '13 by',
#  '13 by fattoquotidiano',
#  '13 by fattoquotidiano via',
#  '13 enne',
#  '13 enne incinta',
#  ...]

# %%
coefs = clf.coef_
coefs.shape
# Out:
# (1, 581911)

# %%
idx = 0
class_coefs = coefs[idx]

feature_importances = {feature_name: coef for feature_name,
                       coef in zip(features_names, class_coefs)}
sorted_feature_importances = dict(
    sorted(feature_importances.items(), key=lambda item: item[1], reverse=True))

# importances, names = zip(*sorted(zip(feature_importance, features)))

num_to_plot = 15
print(f'Feature importance classe {clf.classes_[idx]}')
plt.barh(range(num_to_plot), list(sorted_feature_importances.values())
         [:num_to_plot], align='center')
plt.yticks(range(num_to_plot), list(
    sorted_feature_importances.keys())[:num_to_plot])
plt.gca().invert_yaxis()

plt.savefig('coefs_ngrammi_parole.svg')
# Out:
# Feature importance classe 0

# %%
scores = cross_val_score(clf, X_test, y_test_hs, cv=5)
print(scores)
print('media:', np.mean(scores))
# Out:
# [0.68 0.68 0.75 0.64 0.73]
# media: 0.6960000000000001

# %% [markdown]
# # N-grammi di PoS

# %%
# Extract POS tags from the parsed sentences
pos_tags = [[token['upos'] for token in sentence] for sentence in sentences]

# %%
def generate_pos_ngrams(pos_tags, max_n):
    ngrams = []
    for n in range(1, max_n + 1):
        ngrams.extend(pos_tags[i:i + n] for i in range(len(pos_tags) - n + 1))
    return ngrams

# Generazione degli n-grammi di POS tags (fino a 6-grammi)
pos_ngrams = [generate_pos_ngrams(sentence_tags, 6)
              for sentence_tags in pos_tags]

# Conversione degli n-grammi di POS tags in stringhe separate da "_"
pos_bigrams_str = [' '.join(['_'.join(ngram) for ngram in sentence_ngrams])
                   for sentence_ngrams in pos_ngrams]

# Creazione di un CountVectorizer con un tokenizzatore personalizzato (divisione sullo spazio bianco)
vectorizer = CountVectorizer(tokenizer=lambda x: x.split())

# %%
# Trasformazione degli n-grammi di POS tags in una matrice delle feature
X = vectorizer.fit_transform(pos_bigrams_str)

# Addestramento e valutazione del classificatore
train_size = 6839
clf = LinearSVC(max_iter=10000, C=0.001, dual=False)
clf.fit(X[:train_size], y_train_hs)
y_pred = clf.predict(X[train_size:])

print(classification_report(y_test_hs, y_pred))
# Out:
# c:\Users\vince\AppData\Local\Programs\Python\Python311\Lib\site-packages\sklearn\feature_extraction\text.py:528: UserWarning: The parameter 'token_pattern' will not be used since 'tokenizer' is not None'
#   warnings.warn(
#               precision    recall  f1-score   support
#
#            0       0.65      0.97      0.78       319
#            1       0.55      0.07      0.12       181
#
#     accuracy                           0.64       500
#    macro avg       0.60      0.52      0.45       500
# weighted avg       0.61      0.64      0.54       500

# %%
features_names = vectorizer.get_feature_names_out(X_train).tolist()
features_names
# Out:
# ['_',
#  '__adj',
#  '__adj_det',
#  '__adj_det_adv',
#  '__adj_det_adv_verb',
#  '__adj_det_adv_verb_pron',
#  '__adj_det_noun',
#  '__adj_det_noun_pron',
#  '__adj_det_noun_pron_verb',
#  '__adj_det_noun_punct',
#  '__adj_det_noun_punct_adv',
#  '__adj_det_noun_punct_aux',
#  '__adj_det_noun_punct_propn',
#  '__adj_det_propn',
#  '__adj_det_propn_det',
#  '__adj_det_propn_det_noun',
#  '__adj_det_propn_propn',
#  '__adj_det_propn_propn_propn',
#  '__adj_det_propn_punct',
#  '__adj_det_propn_punct_adp',
#  '__adj_pron',
#  '__adj_pron_pron',
#  '__adj_pron_pron_punct',
#  '__adj_pron_pron_punct_verb',
#  '__adj_pron_punct',
#  '__adj_pron_punct_aux',
#  '__adj_pron_punct_aux_det',
#  '__adj_pron_verb',
#  '__adj_pron_verb_adp',
#  '__adj_pron_verb_adp_det',
#  '__adp',
#  '__adp_det',
#  '__adp_det__',
#  '__adp_det___adp',
#  '__adp_det___adp_det',
#  '__adp_det___propn',
#  '__adp_det___propn_det',
#  '__adp_det___propn_pron',
#  '__adp_det___verb',
#  '__adp_det___verb_adv',
#  '__adp_det___verb_det',
#  '__adp_det___verb_pron',
#  '__adp_det_adj',
#  '__adp_det_adj__',
#  '__adp_det_adj___adp',
#  '__adp_det_adj___noun',
#  '__adp_det_adj_adj',
#  '__adp_det_adj_adj_noun',
#  '__adp_det_adj_adp',
#  '__adp_det_adj_adp_pron',
#  '__adp_det_adj_adp_propn',
#  '__adp_det_adj_adp_verb',
#  '__adp_det_adj_aux',
#  '__adp_det_adj_aux_aux',
#  '__adp_det_adj_cconj',
#  '__adp_det_adj_cconj_adj',
#  '__adp_det_adj_noun',
#  '__adp_det_adj_noun__',
#  '__adp_det_adj_noun_adj',
#  '__adp_det_adj_noun_adp',
#  '__adp_det_adj_noun_adv',
#  '__adp_det_adj_noun_aux',
#  '__adp_det_adj_noun_cconj',
#  '__adp_det_adj_noun_det',
#  '__adp_det_adj_noun_noun',
#  '__adp_det_adj_noun_num',
#  '__adp_det_adj_noun_pron',
#  '__adp_det_adj_noun_propn',
#  '__adp_det_adj_noun_punct',
#  '__adp_det_adj_noun_verb',
#  '__adp_det_adj_num',
#  '__adp_det_adj_num_adp',
#  '__adp_det_adj_num_noun',
#  '__adp_det_adj_propn',
#  '__adp_det_adj_propn__',
#  '__adp_det_adj_propn_adj',
#  '__adp_det_adj_propn_adp',
#  '__adp_det_adj_propn_adv',
#  '__adp_det_adj_propn_aux',
#  '__adp_det_adj_propn_propn',
#  '__adp_det_adj_propn_punct',
#  '__adp_det_adj_propn_verb',
#  '__adp_det_adj_punct',
#  '__adp_det_adj_punct__',
#  '__adp_det_adj_punct_adj',
#  '__adp_det_adj_punct_adp',
#  '__adp_det_adj_punct_adv',
#  '__adp_det_adj_punct_det',
#  '__adp_det_adj_punct_propn',
#  '__adp_det_adj_punct_punct',
#  '__adp_det_adj_sym',
#  '__adp_det_adj_sym_propn',
#  '__adp_det_adj_verb',
#  '__adp_det_adj_verb_noun',
#  '__adp_det_adj_x',
#  '__adp_det_adj_x_aux',
#  '__adp_det_adp',
#  '__adp_det_adp__',
#  '__adp_det_adp___adp',
#  '__adp_det_adp_adv',
#  '__adp_det_adp_adv__',
#  '__adp_det_adv',
#  '__adp_det_adv__',
#  '__adp_det_adv___adp',
#  '__adp_det_adv_adj',
#  '__adp_det_adv_adj__',
#  '__adp_det_adv_adj_adp',
#  '__adp_det_adv_adj_noun',
#  '__adp_det_adv_adj_propn',
#  '__adp_det_adv_adj_punct',
#  '__adp_det_adv_adp',
#  '__adp_det_adv_adp_verb',
#  '__adp_det_adv_adv',
#  '__adp_det_adv_adv_adp',
#  '__adp_det_adv_adv_det',
#  '__adp_det_adv_adv_punct',
#  '__adp_det_adv_det',
#  '__adp_det_adv_det_noun',
#  '__adp_det_adv_noun',
#  '__adp_det_adv_noun_punct',
#  '__adp_det_aux',
#  '__adp_det_aux_adj',
#  '__adp_det_aux_adj_propn',
#  '__adp_det_aux_verb',
#  '__adp_det_aux_verb_adv',
#  '__adp_det_det',
#  '__adp_det_det_adj',
#  '__adp_det_det_adj_noun',
#  '__adp_det_det_adj_num',
#  '__adp_det_det_adj_propn',
#  '__adp_det_det_adp',
#  '__adp_det_det_adp_det',
#  '__adp_det_det_adp_noun',
#  '__adp_det_det_noun',
#  '__adp_det_det_noun__',
#  '__adp_det_det_noun_adj',
#  '__adp_det_det_noun_adp',
#  '__adp_det_det_noun_adv',
#  '__adp_det_det_noun_aux',
#  '__adp_det_det_noun_cconj',
#  '__adp_det_det_noun_det',
#  '__adp_det_det_noun_noun',
#  '__adp_det_det_noun_pron',
#  '__adp_det_det_noun_propn',
#  '__adp_det_det_noun_punct',
#  '__adp_det_det_noun_sconj',
#  '__adp_det_det_noun_sym',
#  '__adp_det_det_noun_verb',
#  '__adp_det_det_num',
#  '__adp_det_det_num_noun',
#  '__adp_det_det_pron',
#  '__adp_det_det_pron_aux',
#  '__adp_det_det_propn',
#  '__adp_det_det_propn_adj',
#  '__adp_det_det_propn_adp',
#  '__adp_det_det_propn_cconj',
#  '__adp_det_det_propn_punct',
#  '__adp_det_det_propn_verb',
#  '__adp_det_det_punct',
#  '__adp_det_det_punct_adv',
#  '__adp_det_det_punct_propn',
#  '__adp_det_noun',
#  '__adp_det_noun__',
#  '__adp_det_noun___adp',
#  '__adp_det_noun___propn',
#  '__adp_det_noun___verb',
#  '__adp_det_noun_adj',
#  '__adp_det_noun_adj__',
#  '__adp_det_noun_adj_adj',
#  '__adp_det_noun_adj_adp',
#  '__adp_det_noun_adj_adv',
#  '__adp_det_noun_adj_aux',
#  '__adp_det_noun_adj_cconj',
#  '__adp_det_noun_adj_det',
#  '__adp_det_noun_adj_intj',
#  '__adp_det_noun_adj_noun',
#  '__adp_det_noun_adj_num',
#  '__adp_det_noun_adj_pron',
#  '__adp_det_noun_adj_propn',
#  '__adp_det_noun_adj_punct',
#  '__adp_det_noun_adj_sconj',
#  '__adp_det_noun_adj_sym',
#  '__adp_det_noun_adj_verb',
#  '__adp_det_noun_adj_x',
#  '__adp_det_noun_adp',
#  '__adp_det_noun_adp__',
#  '__adp_det_noun_adp_adj',
#  '__adp_det_noun_adp_adp',
#  '__adp_det_noun_adp_adv',
#  '__adp_det_noun_adp_aux',
#  '__adp_det_noun_adp_det',
#  '__adp_det_noun_adp_noun',
#  '__adp_det_noun_adp_num',
#  '__adp_det_noun_adp_pron',
#  '__adp_det_noun_adp_propn',
#  '__adp_det_noun_adp_punct',
#  '__adp_det_noun_adp_verb',
#  '__adp_det_noun_adv',
#  '__adp_det_noun_adv__',
#  '__adp_det_noun_adv_adj',
#  '__adp_det_noun_adv_adp',
#  '__adp_det_noun_adv_adv',
#  '__adp_det_noun_adv_aux',
#  '__adp_det_noun_adv_cconj',
#  '__adp_det_noun_adv_det',
#  '__adp_det_noun_adv_num',
#  '__adp_det_noun_adv_pron',
#  '__adp_det_noun_adv_propn',
#  '__adp_det_noun_adv_punct',
#  '__adp_det_noun_adv_sconj',
#  '__adp_det_noun_adv_verb',
#  '__adp_det_noun_aux',
#  '__adp_det_noun_aux__',
#  '__adp_det_noun_aux_adj',
#  '__adp_det_noun_aux_adp',
#  '__adp_det_noun_aux_adv',
#  '__adp_det_noun_aux_aux',
#  '__adp_det_noun_aux_det',
#  '__adp_det_noun_aux_noun',
#  '__adp_det_noun_aux_num',
#  '__adp_det_noun_aux_pron',
#  '__adp_det_noun_aux_propn',
#  '__adp_det_noun_aux_verb',
#  '__adp_det_noun_cconj',
#  '__adp_det_noun_cconj__',
#  '__adp_det_noun_cconj_adj',
#  '__adp_det_noun_cconj_adp',
#  '__adp_det_noun_cconj_adv',
#  '__adp_det_noun_cconj_aux',
#  '__adp_det_noun_cconj_cconj',
#  '__adp_det_noun_cconj_det',
#  '__adp_det_noun_cconj_noun',
#  '__adp_det_noun_cconj_num',
#  '__adp_det_noun_cconj_pron',
#  '__adp_det_noun_cconj_propn',
#  '__adp_det_noun_cconj_punct',
#  '__adp_det_noun_cconj_sconj',
#  '__adp_det_noun_cconj_verb',
#  '__adp_det_noun_cconj_x',
#  '__adp_det_noun_det',
#  '__adp_det_noun_det_adj',
#  '__adp_det_noun_det_adv',
#  '__adp_det_noun_det_cconj',
#  '__adp_det_noun_det_det',
#  '__adp_det_noun_det_noun',
#  '__adp_det_noun_det_num',
#  '__adp_det_noun_det_pron',
#  '__adp_det_noun_det_propn',
#  '__adp_det_noun_det_punct',
#  '__adp_det_noun_intj',
#  '__adp_det_noun_intj_aux',
#  '__adp_det_noun_intj_noun',
#  '__adp_det_noun_noun',
#  '__adp_det_noun_noun__',
#  '__adp_det_noun_noun_adj',
#  '__adp_det_noun_noun_adp',
#  '__adp_det_noun_noun_adv',
#  '__adp_det_noun_noun_aux',
#  '__adp_det_noun_noun_cconj',
#  '__adp_det_noun_noun_det',
#  '__adp_det_noun_noun_noun',
#  '__adp_det_noun_noun_pron',
#  '__adp_det_noun_noun_propn',
#  '__adp_det_noun_noun_punct',
#  '__adp_det_noun_noun_sconj',
#  '__adp_det_noun_noun_verb',
#  '__adp_det_noun_num',
#  '__adp_det_noun_num_adp',
#  '__adp_det_noun_num_aux',
#  '__adp_det_noun_num_cconj',
#  '__adp_det_noun_num_det',
#  '__adp_det_noun_num_noun',
#  '__adp_det_noun_num_num',
#  '__adp_det_noun_num_punct',
#  '__adp_det_noun_num_sconj',
#  '__adp_det_noun_num_verb',
#  '__adp_det_noun_num_x',
#  '__adp_det_noun_pron',
#  '__adp_det_noun_pron__',
#  '__adp_det_noun_pron_adj',
#  '__adp_det_noun_pron_adp',
#  '__adp_det_noun_pron_adv',
#  '__adp_det_noun_pron_aux',
#  '__adp_det_noun_pron_cconj',
#  '__adp_det_noun_pron_det',
#  '__adp_det_noun_pron_noun',
#  '__adp_det_noun_pron_pron',
#  '__adp_det_noun_pron_propn',
#  '__adp_det_noun_pron_punct',
#  '__adp_det_noun_pron_verb',
#  '__adp_det_noun_propn',
#  '__adp_det_noun_propn__',
#  '__adp_det_noun_propn_adj',
#  '__adp_det_noun_propn_adp',
#  '__adp_det_noun_propn_adv',
#  '__adp_det_noun_propn_aux',
#  '__adp_det_noun_propn_cconj',
#  '__adp_det_noun_propn_det',
#  '__adp_det_noun_propn_noun',
#  '__adp_det_noun_propn_num',
#  '__adp_det_noun_propn_pron',
#  '__adp_det_noun_propn_propn',
#  '__adp_det_noun_propn_punct',
#  '__adp_det_noun_propn_verb',
#  '__adp_det_noun_propn_x',
#  '__adp_det_noun_punct',
#  '__adp_det_noun_punct__',
#  '__adp_det_noun_punct_adj',
#  '__adp_det_noun_punct_adp',
#  '__adp_det_noun_punct_adv',
#  '__adp_det_noun_punct_aux',
#  '__adp_det_noun_punct_cconj',
#  '__adp_det_noun_punct_det',
#  '__adp_det_noun_punct_intj',
#  '__adp_det_noun_punct_noun',
#  '__adp_det_noun_punct_num',
#  '__adp_det_noun_punct_pron',
#  '__adp_det_noun_punct_propn',
#  '__adp_det_noun_punct_punct',
#  '__adp_det_noun_punct_sconj',
#  '__adp_det_noun_punct_sym',
#  '__adp_det_noun_punct_verb',
#  '__adp_det_noun_punct_x',
#  '__adp_det_noun_sconj',
#  '__adp_det_noun_sconj__',
#  '__adp_det_noun_sconj_adv',
#  '__adp_det_noun_sconj_aux',
#  '__adp_det_noun_sconj_cconj',
#  '__adp_det_noun_sconj_det',
#  '__adp_det_noun_sconj_noun',
#  '__adp_det_noun_sconj_pron',
#  '__adp_det_noun_sconj_propn',
#  '__adp_det_noun_sconj_verb',
#  '__adp_det_noun_sym',
#  '__adp_det_noun_sym_adv',
#  '__adp_det_noun_sym_aux',
#  '__adp_det_noun_sym_det',
#  '__adp_det_noun_sym_noun',
#  '__adp_det_noun_sym_pron',
#  '__adp_det_noun_sym_propn',
#  '__adp_det_noun_sym_verb',
#  '__adp_det_noun_verb',
#  '__adp_det_noun_verb__',
#  '__adp_det_noun_verb_adj',
#  '__adp_det_noun_verb_adp',
#  '__adp_det_noun_verb_adv',
#  '__adp_det_noun_verb_aux',
#  '__adp_det_noun_verb_cconj',
#  '__adp_det_noun_verb_det',
#  '__adp_det_noun_verb_noun',
#  '__adp_det_noun_verb_num',
#  '__adp_det_noun_verb_pron',
#  '__adp_det_noun_verb_propn',
#  '__adp_det_noun_verb_punct',
#  '__adp_det_noun_verb_sconj',
#  '__adp_det_noun_verb_sym',
#  '__adp_det_noun_verb_verb',
#  '__adp_det_noun_x',
#  '__adp_det_noun_x_adj',
#  '__adp_det_noun_x_noun',
#  '__adp_det_noun_x_punct',
#  '__adp_det_noun_x_x',
#  '__adp_det_num',
#  '__adp_det_num__',
#  '__adp_det_num___adp',
#  '__adp_det_num_adj',
#  '__adp_det_num_adj_noun',
#  '__adp_det_num_adp',
#  '__adp_det_num_adp_adv',
#  '__adp_det_num_adp_det',
#  '__adp_det_num_adp_noun',
#  '__adp_det_num_adp_num',
#  '__adp_det_num_adp_pron',
#  '__adp_det_num_adp_propn',
#  '__adp_det_num_adp_verb',
#  '__adp_det_num_adv',
#  '__adp_det_num_adv_adj',
#  '__adp_det_num_aux',
#  '__adp_det_num_aux_det',
#  '__adp_det_num_aux_verb',
#  '__adp_det_num_cconj',
#  '__adp_det_num_cconj_pron',
#  '__adp_det_num_det',
#  '__adp_det_num_det_pron',
#  '__adp_det_num_noun',
#  '__adp_det_num_noun__',
#  '__adp_det_num_noun_adj',
#  '__adp_det_num_noun_adp',
#  '__adp_det_num_noun_adv',
#  '__adp_det_num_noun_aux',
#  '__adp_det_num_noun_cconj',
#  '__adp_det_num_noun_det',
#  '__adp_det_num_noun_noun',
#  '__adp_det_num_noun_num',
#  '__adp_det_num_noun_pron',
#  '__adp_det_num_noun_propn',
#  '__adp_det_num_noun_punct',
#  '__adp_det_num_noun_verb',
#  '__adp_det_num_pron',
#  '__adp_det_num_pron_pron',
#  '__adp_det_num_pron_verb',
#  '__adp_det_num_propn',
#  '__adp_det_num_propn_propn',
#  '__adp_det_num_propn_punct',
#  '__adp_det_num_punct',
#  '__adp_det_num_punct_adv',
#  '__adp_det_num_punct_cconj',
#  '__adp_det_num_punct_det',
#  '__adp_det_num_punct_noun',
#  '__adp_det_num_punct_num',
#  '__adp_det_num_punct_propn',
#  '__adp_det_num_punct_punct',
#  '__adp_det_num_punct_verb',
#  '__adp_det_num_sconj',
#  '__adp_det_num_sconj_det',
#  '__adp_det_num_sym',
#  '__adp_det_num_sym__',
#  '__adp_det_num_sym_adj',
#  '__adp_det_num_sym_adp',
#  '__adp_det_num_sym_det',
#  '__adp_det_num_sym_noun',
#  '__adp_det_num_sym_propn',
#  '__adp_det_num_sym_punct',
#  '__adp_det_num_verb',
#  '__adp_det_num_verb__',
#  '__adp_det_num_verb_adp',
#  '__adp_det_num_verb_det',
#  '__adp_det_pron',
#  '__adp_det_pron_adp',
#  '__adp_det_pron_adp_noun',
#  '__adp_det_pron_adv',
#  '__adp_det_pron_adv__',
#  '__adp_det_pron_adv_aux',
#  '__adp_det_pron_adv_cconj',
#  '__adp_det_pron_adv_det',
#  '__adp_det_pron_adv_pron',
#  '__adp_det_pron_adv_punct',
#  '__adp_det_pron_adv_verb',
#  '__adp_det_pron_aux',
#  '__adp_det_pron_aux_adj',
#  '__adp_det_pron_aux_adv',
#  '__adp_det_pron_aux_aux',
#  '__adp_det_pron_aux_det',
#  '__adp_det_pron_aux_noun',
#  '__adp_det_pron_aux_pron',
#  '__adp_det_pron_aux_verb',
#  '__adp_det_pron_cconj',
#  '__adp_det_pron_cconj__',
#  '__adp_det_pron_det',
#  '__adp_det_pron_det_noun',
#  '__adp_det_pron_det_propn',
#  '__adp_det_pron_pron',
#  '__adp_det_pron_pron_aux',
#  '__adp_det_pron_punct',
#  '__adp_det_pron_punct__',
#  '__adp_det_pron_punct_adj',
#  '__adp_det_pron_punct_adp',
#  '__adp_det_pron_punct_cconj',
#  '__adp_det_pron_punct_det',
#  '__adp_det_pron_punct_noun',
#  '__adp_det_pron_punct_pron',
#  '__adp_det_pron_punct_propn',
#  '__adp_det_pron_punct_punct',
#  '__adp_det_pron_punct_sconj',
#  '__adp_det_pron_punct_verb',
#  '__adp_det_pron_verb',
#  '__adp_det_pron_verb__',
#  '__adp_det_pron_verb_adp',
#  '__adp_det_pron_verb_adv',
#  '__adp_det_pron_verb_det',
#  '__adp_det_pron_verb_noun',
#  '__adp_det_pron_verb_pron',
#  '__adp_det_pron_verb_punct',
#  '__adp_det_propn',
#  '__adp_det_propn__',
#  '__adp_det_propn___adp',
#  '__adp_det_propn___propn',
#  '__adp_det_propn___verb',
#  '__adp_det_propn_adj',
#  '__adp_det_propn_adj__',
#  '__adp_det_propn_adj_adj',
#  '__adp_det_propn_adj_adp',
#  '__adp_det_propn_adj_adv',
#  '__adp_det_propn_adj_aux',
#  '__adp_det_propn_adj_cconj',
#  '__adp_det_propn_adj_det',
#  '__adp_det_propn_adj_noun',
#  '__adp_det_propn_adj_punct',
#  '__adp_det_propn_adj_verb',
#  '__adp_det_propn_adp',
#  '__adp_det_propn_adp__',
#  '__adp_det_propn_adp_adj',
#  '__adp_det_propn_adp_adv',
#  '__adp_det_propn_adp_aux',
#  '__adp_det_propn_adp_det',
#  '__adp_det_propn_adp_noun',
#  '__adp_det_propn_adp_num',
#  '__adp_det_propn_adp_pron',
#  '__adp_det_propn_adp_propn',
#  '__adp_det_propn_adp_punct',
#  '__adp_det_propn_adp_verb',
#  '__adp_det_propn_adv',
#  '__adp_det_propn_adv__',
#  '__adp_det_propn_adv_adj',
#  '__adp_det_propn_adv_adp',
#  '__adp_det_propn_adv_adv',
#  '__adp_det_propn_adv_aux',
#  '__adp_det_propn_adv_cconj',
#  '__adp_det_propn_adv_det',
#  '__adp_det_propn_adv_noun',
#  '__adp_det_propn_adv_pron',
#  '__adp_det_propn_adv_punct',
#  '__adp_det_propn_adv_sconj',
#  '__adp_det_propn_adv_verb',
#  '__adp_det_propn_aux',
#  '__adp_det_propn_aux__',
#  '__adp_det_propn_aux_adj',
#  '__adp_det_propn_aux_adp',
#  '__adp_det_propn_aux_adv',
#  '__adp_det_propn_aux_det',
#  '__adp_det_propn_aux_noun',
#  '__adp_det_propn_aux_pron',
#  '__adp_det_propn_aux_propn',
#  '__adp_det_propn_aux_punct',
#  '__adp_det_propn_aux_verb',
#  '__adp_det_propn_cconj',
#  '__adp_det_propn_cconj__',
#  '__adp_det_propn_cconj_adp',
#  '__adp_det_propn_cconj_adv',
#  '__adp_det_propn_cconj_aux',
#  '__adp_det_propn_cconj_det',
#  '__adp_det_propn_cconj_noun',
#  '__adp_det_propn_cconj_num',
#  '__adp_det_propn_cconj_pron',
#  '__adp_det_propn_cconj_propn',
#  '__adp_det_propn_cconj_punct',
#  '__adp_det_propn_cconj_verb',
#  '__adp_det_propn_det',
#  '__adp_det_propn_det_adj',
#  '__adp_det_propn_det_det',
#  '__adp_det_propn_det_noun',
#  '__adp_det_propn_det_pron',
#  '__adp_det_propn_det_propn',
#  '__adp_det_propn_intj',
#  '__adp_det_propn_intj_punct',
#  '__adp_det_propn_noun',
#  '__adp_det_propn_noun__',
#  '__adp_det_propn_noun_adj',
#  '__adp_det_propn_noun_adp',
#  '__adp_det_propn_noun_cconj',
#  '__adp_det_propn_noun_noun',
#  '__adp_det_propn_noun_punct',
#  '__adp_det_propn_num',
#  '__adp_det_propn_num_adp',
#  '__adp_det_propn_num_det',
#  '__adp_det_propn_num_noun',
#  '__adp_det_propn_num_punct',
#  '__adp_det_propn_num_sym',
#  '__adp_det_propn_num_verb',
#  '__adp_det_propn_pron',
#  '__adp_det_propn_pron_adj',
#  '__adp_det_propn_pron_adp',
#  '__adp_det_propn_pron_adv',
#  '__adp_det_propn_pron_aux',
#  '__adp_det_propn_pron_det',
#  '__adp_det_propn_pron_pron',
#  '__adp_det_propn_pron_verb',
#  '__adp_det_propn_propn',
#  '__adp_det_propn_propn__',
#  '__adp_det_propn_propn_adj',
#  '__adp_det_propn_propn_adp',
#  '__adp_det_propn_propn_adv',
#  '__adp_det_propn_propn_aux',
#  '__adp_det_propn_propn_cconj',
#  '__adp_det_propn_propn_det',
#  '__adp_det_propn_propn_noun',
#  '__adp_det_propn_propn_num',
#  '__adp_det_propn_propn_propn',
#  '__adp_det_propn_propn_punct',
#  '__adp_det_propn_propn_sconj',
#  '__adp_det_propn_propn_verb',
#  '__adp_det_propn_propn_x',
#  '__adp_det_propn_punct',
#  '__adp_det_propn_punct__',
#  '__adp_det_propn_punct_adj',
#  '__adp_det_propn_punct_adp',
#  '__adp_det_propn_punct_adv',
#  '__adp_det_propn_punct_aux',
#  '__adp_det_propn_punct_cconj',
#  '__adp_det_propn_punct_det',
#  '__adp_det_propn_punct_noun',
#  '__adp_det_propn_punct_num',
#  '__adp_det_propn_punct_pron',
#  '__adp_det_propn_punct_propn',
#  '__adp_det_propn_punct_punct',
#  '__adp_det_propn_punct_sconj',
#  '__adp_det_propn_punct_sym',
#  '__adp_det_propn_punct_verb',
#  '__adp_det_propn_punct_x',
#  '__adp_det_propn_sconj',
#  '__adp_det_propn_sconj_det',
#  '__adp_det_propn_sconj_noun',
#  '__adp_det_propn_sconj_propn',
#  '__adp_det_propn_sconj_verb',
#  '__adp_det_propn_sym',
#  '__adp_det_propn_sym_aux',
#  '__adp_det_propn_sym_noun',
#  '__adp_det_propn_sym_propn',
#  '__adp_det_propn_verb',
#  '__adp_det_propn_verb__',
#  '__adp_det_propn_verb_adp',
#  '__adp_det_propn_verb_adv',
#  '__adp_det_propn_verb_cconj',
#  '__adp_det_propn_verb_det',
#  '__adp_det_propn_verb_noun',
#  '__adp_det_propn_verb_num',
#  '__adp_det_propn_verb_pron',
#  '__adp_det_propn_verb_propn',
#  '__adp_det_propn_verb_punct',
#  '__adp_det_propn_verb_sconj',
#  '__adp_det_propn_verb_verb',
#  '__adp_det_punct',
#  '__adp_det_punct__',
#  '__adp_det_punct___adp',
#  '__adp_det_punct_adj',
#  '__adp_det_punct_adj_noun',
#  '__adp_det_punct_adj_punct',
#  '__adp_det_punct_adv',
#  '__adp_det_punct_adv_adj',
#  '__adp_det_punct_adv_adv',
#  '__adp_det_punct_adv_pron',
#  '__adp_det_punct_aux',
#  '__adp_det_punct_aux_punct',
#  '__adp_det_punct_aux_verb',
#  '__adp_det_punct_det',
#  '__adp_det_punct_det_noun',
#  '__adp_det_punct_noun',
#  '__adp_det_punct_noun__',
#  '__adp_det_punct_noun_adj',
#  '__adp_det_punct_noun_adp',
#  '__adp_det_punct_noun_noun',
#  '__adp_det_punct_noun_propn',
#  '__adp_det_punct_noun_punct',
#  '__adp_det_punct_pron',
#  '__adp_det_punct_pron_adp',
#  '__adp_det_punct_pron_pron',
#  '__adp_det_punct_propn',
#  '__adp_det_punct_propn__',
#  '__adp_det_punct_propn_adp',
#  '__adp_det_punct_propn_adv',
#  '__adp_det_punct_propn_aux',
#  '__adp_det_punct_propn_cconj',
#  '__adp_det_punct_propn_propn',
#  '__adp_det_punct_propn_punct',
#  '__adp_det_punct_propn_sconj',
#  '__adp_det_punct_propn_verb',
#  '__adp_det_punct_punct',
#  '__adp_det_punct_punct_adj',
#  '__adp_det_punct_punct_noun',
#  '__adp_det_punct_punct_propn',
#  '__adp_det_punct_punct_verb',
#  '__adp_det_punct_verb',
#  '__adp_det_punct_verb_det',
#  '__adp_det_punct_verb_noun',
#  '__adp_det_sym',
#  '__adp_det_sym_adv',
#  '__adp_det_sym_adv_punct',
#  '__adp_det_sym_det',
#  '__adp_det_sym_det_num',
#  '__adp_det_verb',
#  '__adp_det_verb_adj',
#  '__adp_det_verb_adj_det',
#  '__adp_det_verb_adp',
#  '__adp_det_verb_adp_noun',
#  '__adp_det_verb_det',
#  '__adp_det_verb_det_det',
#  '__adp_det_verb_det_noun',
#  '__adp_det_verb_noun',
#  '__adp_det_verb_noun_adp',
#  '__adp_det_verb_noun_noun',
#  '__adp_det_verb_noun_punct',
#  '__adp_det_verb_noun_sconj',
#  '__adp_det_verb_pron',
#  '__adp_det_verb_pron_cconj',
#  '__adp_det_verb_punct',
#  '__adp_det_verb_punct_det',
#  '__adp_det_verb_punct_propn',
#  '__adp_det_x',
#  '__adp_det_x_propn',
#  '__adp_det_x_propn_adv',
#  '__adp_det_x_x',
#  '__adp_det_x_x_punct',
#  '__adp_pron',
#  '__adp_pron_adp',
#  '__adp_pron_adp_noun',
#  '__adp_pron_adp_noun_cconj',
#  '__adp_pron_punct',
#  '__adp_pron_punct_punct',
#  '__adp_pron_punct_punct_propn',
#  '__adp_pron_verb',
#  '__adp_pron_verb_adv',
#  '__adp_pron_verb_adv_noun',
#  '__adp_propn',
#  '__adp_propn_adj',
#  '__adp_propn_adj_punct',
#  '__adp_propn_adj_punct_propn',
#  '__adp_propn_adp',
#  '__adp_propn_adp_propn',
#  '__adp_propn_adp_propn_propn',
#  '__adp_propn_propn',
#  '__adp_propn_propn__',
#  '__adp_propn_propn___adp',
#  '__adp_propn_propn___propn',
#  '__adp_propn_propn_adj',
#  '__adp_propn_propn_adj_aux',
#  '__adp_propn_propn_adp',
#  '__adp_propn_propn_adp_propn',
#  '__adp_propn_propn_aux',
#  '__adp_propn_propn_aux_propn',
#  '__adp_propn_propn_aux_verb',
#  '__adp_propn_propn_cconj',
#  '__adp_propn_propn_cconj__',
#  '__adp_propn_propn_cconj_propn',
#  '__adp_propn_propn_propn',
#  '__adp_propn_propn_propn__',
#  '__adp_propn_propn_propn_adj',
#  '__adp_propn_propn_propn_adp',
#  '__adp_propn_propn_propn_adv',
#  '__adp_propn_propn_propn_aux',
#  '__adp_propn_propn_propn_cconj',
#  '__adp_propn_propn_propn_propn',
#  '__adp_propn_propn_propn_punct',
#  '__adp_propn_propn_propn_verb',
#  '__adp_propn_propn_punct',
#  '__adp_propn_propn_punct_cconj',
#  '__adp_propn_propn_punct_det',
#  '__adp_propn_propn_punct_noun',
#  '__adp_propn_propn_punct_propn',
#  '__adp_propn_propn_punct_punct',
#  '__adp_propn_propn_sym',
#  '__adp_propn_propn_verb',
#  '__adp_propn_propn_verb_sconj',
#  '__adp_propn_punct',
#  '__adp_propn_punct_propn',
#  '__adp_propn_punct_propn_punct',
#  '__adv',
#  '__adv_det',
#  '__adv_det_noun',
#  '__adv_det_noun_noun',
#  '__adv_det_noun_noun_punct',
#  '__adv_pron',
#  '__adv_pron_punct',
#  '__adv_pron_punct_det',
#  '__adv_pron_punct_det_punct',
#  '__aux',
#  '__aux_pron',
#  '__aux_pron_adp',
#  '__aux_pron_adp_noun',
#  '__aux_pron_adp_noun_punct',
#  '__aux_pron_pron',
#  '__aux_pron_pron_verb',
#  '__aux_pron_pron_verb_verb',
#  '__aux_pron_verb',
#  '__aux_pron_verb_adp',
#  '__aux_pron_verb_adp_det',
#  '__aux_pron_verb_adp_noun',
#  '__aux_pron_verb_adp_pron',
#  '__aux_pron_verb_adv',
#  '__aux_pron_verb_adv_adp',
#  '__aux_pron_verb_adv_noun',
#  '__aux_pron_verb_det',
#  '__aux_pron_verb_det_noun',
#  '__aux_pron_verb_punct',
#  '__aux_pron_verb_punct_noun',
#  '__aux_pron_verb_punct_verb',
#  '__aux_pron_verb_verb',
#  '__aux_pron_verb_verb_det',
#  '__cconj',
#  '__cconj_pron',
#  '__cconj_pron_verb',
#  '__cconj_pron_verb__',
#  '__cconj_pron_verb___adp',
#  '__det',
#  '__det_det',
#  '__det_det_noun',
#  '__det_det_noun_pron',
#  '__det_det_noun_pron_pron',
#  '__noun',
#  '__noun_adj',
#  '__noun_adj_adp',
#  '__noun_adj_adp_noun',
#  '__noun_adj_adp_noun_det',
#  '__noun_adj_det',
#  '__noun_adj_det_noun',
#  '__noun_adj_det_noun_sconj',
#  '__noun_det',
#  '__noun_det__',
#  '__noun_det___adp',
#  '__noun_det___adp_det',
#  '__noun_det_adv',
#  '__noun_det_adv_noun',
#  '__noun_det_adv_noun_adp',
#  '__noun_det_adv_pron',
#  '__noun_det_adv_pron_verb',
#  '__noun_det_noun',
#  '__noun_det_noun_adj',
#  '__noun_det_noun_adj_punct',
#  '__noun_det_noun_adp',
#  '__noun_det_noun_adp_det',
#  '__noun_det_noun_det',
#  '__noun_det_noun_det_noun',
#  '__noun_det_num',
#  '__noun_det_num_noun',
#  '__noun_det_num_noun__',
#  '__noun_det_propn',
#  '__noun_det_propn_cconj',
#  '__noun_det_propn_cconj_pron',
#  '__noun_det_punct',
#  '__noun_det_punct_sconj',
#  '__noun_det_punct_sconj_noun',
#  '__noun_pron',
#  '__noun_pron__',
#  '__noun_pron___adp',
#  '__noun_pron___adp_det',
#  '__noun_pron_adv',
#  '__noun_pron_adv_num',
#  '__noun_pron_adv_num_noun',
#  '__noun_pron_cconj',
#  '__noun_pron_cconj_verb',
#  '__noun_pron_cconj_verb_punct',
#  '__noun_pron_pron',
#  '__noun_pron_pron_verb',
#  '__noun_pron_pron_verb_adp',
#  '__noun_pron_pron_verb_punct',
#  '__noun_propn',
#  '__noun_propn_propn',
#  '__noun_propn_propn_adp',
#  '__noun_propn_propn_adp_propn',
#  '__pron',
#  '__pron_det',
#  '__pron_det_adv',
#  '__pron_det_adv__',
#  '__pron_det_adv___adj',
#  '__pron_det_noun',
#  '__pron_det_noun_adp',
#  '__pron_det_noun_adp_pron',
#  '__pron_det_noun_cconj',
#  '__pron_det_noun_cconj_adp',
#  '__pron_det_noun_punct',
#  '__pron_det_noun_punct_verb',
#  '__pron_pron',
#  '__pron_pron_adp',
#  '__pron_pron_adp_noun',
#  '__pron_pron_adp_noun_punct',
#  '__pron_pron_aux',
#  '__pron_pron_aux_verb',
#  '__pron_pron_aux_verb_adp',
#  '__pron_pron_aux_verb_sconj',
#  '__pron_pron_pron',
#  '__pron_pron_pron_aux',
#  '__pron_pron_pron_aux_adv',
#  '__pron_pron_punct',
#  '__pron_pron_punct_det',
#  '__pron_pron_punct_det_noun',
#  '__pron_pron_verb',
#  '__pron_pron_verb__',
#  '__pron_pron_verb___adp',
#  '__pron_pron_verb_adp',
#  '__pron_pron_verb_adp_propn',
#  '__pron_pron_verb_adv',
#  '__pron_pron_verb_adv_adp',
#  '__pron_pron_verb_det',
#  '__pron_pron_verb_det_noun',
#  '__pron_pron_verb_propn',
#  '__pron_pron_verb_propn_propn',
#  '__pron_pron_verb_punct',
#  '__pron_pron_verb_punct_det',
#  '__pron_pron_verb_punct_verb',
#  '__pron_pron_verb_sconj',
#  '__pron_pron_verb_sconj_det',
#  '__pron_pron_verb_sconj_verb',
#  '__pron_pron_verb_verb',
#  '__pron_pron_verb_verb_verb',
#  '__propn',
#  '__propn_adj',
#  '__propn_adj_adp',
#  '__propn_adj_adp_propn',
#  '__propn_adj_adp_propn__',
#  '__propn_adj_aux',
#  '__propn_adj_aux_verb',
#  '__propn_adj_aux_verb_adp',
#  '__propn_adj_propn',
#  '__propn_adj_propn_punct',
#  '__propn_adj_propn_punct_propn',
#  '__propn_adj_punct',
#  '__propn_adj_punct_punct',
#  '__propn_adj_punct_punct_punct',
#  '__propn_det',
#  '__propn_det_det',
#  '__propn_det_det_noun',
#  '__propn_det_det_propn',
#  '__propn_det_det_propn_propn',
#  '__propn_det_noun',
#  '__propn_det_noun_adj',
#  '__propn_det_noun_adj_pron',
#  '__propn_det_noun_propn',
#  '__propn_det_noun_propn_adp',
#  '__propn_det_noun_propn_aux',
#  '__propn_det_noun_propn_propn',
#  '__propn_det_noun_punct',
#  '__propn_det_noun_punct_propn',
#  '__propn_det_noun_verb',
#  '__propn_det_noun_verb_adp',
#  '__propn_det_propn',
#  '__propn_det_propn_adj',
#  '__propn_det_propn_adj_verb',
#  '__propn_det_propn_adp',
#  '__propn_det_propn_adp_propn',
#  '__propn_det_propn_det',
#  '__propn_det_propn_det_propn',
#  '__propn_det_propn_propn',
#  '__propn_det_propn_propn__',
#  '__propn_det_propn_propn_adp',
#  '__propn_det_propn_propn_det',
#  '__propn_det_propn_propn_propn',
#  '__propn_det_propn_punct',
#  '__propn_det_propn_punct_adv',
#  '__propn_det_propn_punct_noun',
#  '__propn_det_propn_punct_pron',
#  '__propn_det_propn_punct_propn',
#  '__propn_det_propn_verb',
#  '__propn_det_propn_verb_adp',
#  '__propn_pron',
#  '__propn_pron__',
#  '__propn_pron___adp',
#  '__propn_pron___adp_det',
#  '__propn_pron_adp',
#  '__propn_pron_adp_noun',
#  '__propn_pron_adp_noun_pron',
#  '__propn_pron_adv',
#  '__propn_pron_adv_punct',
#  '__propn_pron_adv_punct_noun',
#  '__propn_pron_cconj',
#  '__propn_pron_cconj_noun',
#  '__propn_pron_cconj_noun_adp',
#  '__propn_pron_cconj_verb',
#  '__propn_pron_cconj_verb_adv',
#  '__propn_pron_det',
#  '__propn_pron_det_det',
#  '__propn_pron_det_det_noun',
#  '__propn_pron_det_noun',
#  '__propn_pron_det_noun_adp',
#  '__propn_pron_det_noun_cconj',
#  '__propn_pron_pron',
#  '__propn_pron_pron_adp',
#  '__propn_pron_pron_adp_det',
#  '__propn_pron_pron_adp_noun',
#  '__propn_pron_pron_punct',
#  '__propn_pron_pron_punct_noun',
#  '__propn_pron_propn',
#  '__propn_pron_propn_punct',
#  '__propn_pron_propn_punct_noun',
#  '__propn_pron_punct',
#  '__propn_pron_punct_num',
#  '__propn_pron_punct_num_noun',
#  '__propn_pron_punct_propn',
#  '__propn_pron_punct_propn_adv',
#  '__propn_pron_punct_verb',
#  '__propn_pron_punct_verb_punct',
#  '__propn_pron_sconj',
#  '__propn_pron_sconj_det',
#  '__propn_pron_sconj_det_noun',
#  '__propn_pron_verb',
#  '__propn_pron_verb_punct',
#  '__propn_pron_verb_punct_pron',
#  '__propn_pron_verb_punct_punct',
#  '__propn_propn',
#  '__propn_propn__',
#  '__propn_propn___adp',
#  '__propn_propn___adp_det',
#  '__propn_propn___adp_propn',
#  '__propn_propn_adj',
#  '__propn_propn_adj_cconj',
#  '__propn_propn_adj_cconj_adj',
#  '__propn_propn_adj_punct',
#  '__propn_propn_adj_punct_propn',
#  '__propn_propn_adp',
#  '__propn_propn_adp_propn',
#  '__propn_propn_adp_propn__',
#  '__propn_propn_adp_propn_adp',
#  '__propn_propn_adp_propn_propn',
#  '__propn_propn_cconj',
#  '__propn_propn_cconj__',
#  '__propn_propn_cconj___propn',
#  '__propn_propn_cconj_propn',
#  '__propn_propn_cconj_propn_verb',
#  '__propn_propn_det',
#  '__propn_propn_det_det',
#  '__propn_propn_det_det_propn',
#  '__propn_propn_det_propn',
#  ...]

# %%
coefs = clf.coef_
coefs.shape
# Out:
# (1, 141846)

# %%
idx = 0
class_coefs = coefs[idx]

feature_importances = {feature_name: coef for feature_name,
                       coef in zip(features_names, class_coefs)}
sorted_feature_importances = dict(
    sorted(feature_importances.items(), key=lambda item: item[1], reverse=True))

# importances, names = zip(*sorted(zip(feature_importance, features)))

num_to_plot = 15
print(f'Feature importance classe {clf.classes_[idx]}')
plt.barh(range(num_to_plot), list(sorted_feature_importances.values())
         [:num_to_plot], align='center')
plt.yticks(range(num_to_plot), list(
    sorted_feature_importances.keys())[:num_to_plot])
plt.gca().invert_yaxis()


plt.savefig('coefs_ngrammi_pos.svg')
# Out:
# Feature importance classe 0

# %%
scores = cross_val_score(clf, X_test, y_test_hs, cv=5)
print(scores)
print('media:', np.mean(scores))
# Out:
# [0.68 0.68 0.75 0.64 0.73]
# media: 0.6960000000000001

# %% [markdown]
# # Word Embeddings (itWac)

# %% [markdown]
# ### Embeddings singolo (128 elementi)

# %%
conn = sqlite3.connect("embeddings/itwac128.sqlite")
c = conn.cursor()

dizionario = {}
# Eseguo la query per estrarre le parole e i relativi embeddings
for row in c.execute("SELECT * from store"):
    if row[0] != "\t":
        dizionario[row[0]] = row[1:129]

# %%
len(dizionario)
# Out:
# 1247492

# %%
def conllu_sentences_to_strings(sentences):
    return [' '.join([token["form"] for token in sentence]) for sentence in sentences]


sentence_strings = conllu_sentences_to_strings(sentences)
testo_addestramento = pd.Series(sentence_strings)

# Calcolo degli embedding delle frasi come media degli embedding delle parole (ogni documento è rappresentato da un vettore di 128 elementi)
embeddings_train = []
for text in testo_addestramento[:6839]:
    words = text.split()
    text_embedding = np.mean([dizionario[word]
                             for word in words if word in dizionario], axis=0)
    embeddings_train.append(text_embedding)

embeddings_test = []
for text in testo_addestramento[6839:]:
    words = text.split()
    text_embedding = np.mean([dizionario[word]
                             for word in words if word in dizionario], axis=0)
    embeddings_test.append(text_embedding)

train_size = 6839
clf = LinearSVC()
clf.fit(embeddings_train, y_train_hs)
y_pred = clf.predict(embeddings_test)

print(classification_report(y_test_hs, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.69      0.98      0.81       319
#            1       0.85      0.23      0.36       181
#
#     accuracy                           0.71       500
#    macro avg       0.77      0.60      0.58       500
# weighted avg       0.75      0.71      0.65       500

# %%
scores = cross_val_score(clf, embeddings_test, y_test_hs, cv=5)
print(scores)
print('media:', np.mean(scores))
# Out:
# [0.85 0.78 0.8  0.68 0.8 ]
# media: 0.782

# %% [markdown]
# ### 3 Embeddings congiunti usando aggettivi, sostantivi e verbi

# %%
def conllu_sentences_to_categorized_words(sentences):
    categorized_words = []
    for sentence in sentences:
        nouns = [token["form"]
                 for token in sentence if token["upos"] == "NOUN"]
        adjectives = [token["form"]
                      for token in sentence if token["upos"] == "ADJ"]
        verbs = [token["form"]
                 for token in sentence if token["upos"] == "VERB"]
        categorized_words.append((nouns, adjectives, verbs))
    return categorized_words


categorized_words = conllu_sentences_to_categorized_words(sentences)
categorized_words
# Out:
# [(['terrorismo', 'stato', 'soggezione', 'persone', 'innocue'],
#   [],
#   ['mettere', 'render']),
#  (['campi', '#rom', 'ok'], [], ['', 'guadagnato']),
#  (['buche', 'campi', 'rom'], [], ['dimenticataMazzette']),
#  (['migranti', 'terra'], ['israeliti'], ['arrivarono', 'fecero']),
#  (['divertimento', 'giorno', 'patrioti', 'rom', 'spesa'],
#   ['italiani', 'multinazionale', 'tedesca'],
#   ['Trovare', 'inneggiano', 'facendo']),
#  (['benzina', 'nomadi', 'figli', 'scuola', 'giunta'], [], ['paga', 'portano']),
#  (['islam', 'cristianesimo', 'c', 'ignorante'], ['...a'], ['sorbire']),
#  (['grazie', 'stavo', 'campi', 'rom'],
#   ['giusto'],
#   ['', 'caricando', 'messo', 'avallava', 'finanziare']),
#  (['italiani', 'strada'],
#   ['innocenti'],
#   ['smettetela', 'dire', 'trattati', 'uccidevano']),
#  (['Minorenne', 'rom', 'furto', 'appartamento'], [], ['arrestato']),
#  (['Studentessa', 'nomade', '20anni', 'nomade', 'campo'],
#   ['cinese', 'vicino', 'nomade'],
#   ['morta', 'fermato', 'denunciato']),
#  (['Ddl', 'velo', 'apologia', 'reato', 'accordo'],
#   ['islamico', 'diventino'],
#   []),
#  (['campo', 'rom', 'arresti', 'ombra', 'racket'], [], ['rapina']),
#  (['pazza', 'cosa', 'musulmani', 'gay.quelli', 'colore'],
#   ['parla#Trump'],
#   ['Rischiando', 'presa', 'sa']),
#  (['Povertà', 'esclusione', 'istruzione', 'minori', 'rom', 'vita', 'nascita'],
#   ['scarsa'],
#   ['hanno', 'segnata']),
#  (['grazie', 'collegamento', 'campi', '#rom', '#mediaset', 'calo', '#furti'],
#   ['#tv', 'esponenziale'],
#   []),
#  (['zucchero', 'amico', 'rom', 'problemi'], ['negro'], ['visto', 'fate']),
#  (['#profughi', 'malvedenti', 'maldicenti', 'donne', 'bambini'],
#   ['....e', 'malpensanti'],
#   ['sono', 'parlano']),
#  (['caso', 'città', '#sanpietroburgo', 'civiltà', 'fastidio'],
#   ['occidentale', 'terroristica'],
#   ['colpita']),
#  (['euro', 'rom', 'spesa'], [], ['regalati', 'fare']),
#  (['Commissione',
#    'visti',
#    'criteri',
#    'stallo',
#    'legge',
#    'terrorismo',
#    'rimpatri',
#    'aprile'],
#   ['anti'],
#   ['mancano', 'Accordo']),
#  (['parole', 'immigrazionisti', 'mondo'],
#   ['inutili', 'politici'],
#   ['eliminare']),
#  (['clienti', 'avvocato'],
#   ['stranieri'],
#   ['#Milano', 'raggirava', 'truffava', 'arrestato']),
#  (['INTERVISTA', 'memorandum'], ['Immorale', 'migranti'], ['siglato']),
#  (['#terroristifiloccidentali', 'vita'], [], ['#AleppoLibera', 'torna']),
#  (['risultato', 'circolazione', 'paesi', 'groppone'],
#   ['libera', ':nomadi', 'altri'],
#   ['sopporta']),
#  (['Inchiesta', 'torino', 'tesoro', 'regina', 'rom'], [], ['Trovato']),
#  (['favore', 'immigrati', 'marcia'],
#   ['altri', 'europei'],
#   ['visto', 'fatto', 'successo']),
#  (['giorni', 'amore', 'forza.....'], [], ['', 'nomadi,sono', 'andare']),
#  (['territorio', 'profughi'], ['ITALIANIIII'], []),
#  (['polizia', 'rom', 'aprile', 'novembre', 'Operazione', 'Questura'],
#   [],
#   ['allontana']),
#  (['oro', 'gioielli', 'abitazione', 'Centro', 'rom', 'minorenne', 'articolo'],
#   ['storico'],
#   ['Rubano', 'denunciate', 'leggi']),
#  (['guerra', 'terroristi'], [], ['finirà', 'elimineremo']),
#  (['', 'occhio', 'furbacchioni', 'profughi', 'protezione'],
#   [],
#   ['trasformano', 'ottengono']),
#  (['rapinatore'], ['#nomade', '#latitante'], ['arrestato']),
#  (['città', 'campo', 'rom', 'dialogo'], ['posticipata'], ['tenta']),
#  (['', 'aggiungo', 'rom', 'parole'],
#   ['clandestini', 'iussoli', 'stranieri', 'criminali'],
#   ['fatto']),
#  (['bene.Questi', 'posti', 'ns.giovani', 'feccia'],
#   ['stranieri'],
#   ['fatto', 'occupato', 'far', 'giocare', ',da', 'vengono']),
#  (['nomadi', 'idea', 'incredibile.'],
#   ['..ci'],
#   ['Dici', 'rassegnano', 'arrivata']),
#  (['campi', 'rom', 'gennaio', 'piano'], [], ['chiudere']),
#  (['#ultimenotizie',
#    '#news',
#    '#notizie',
#    'donna',
#    'campo',
#    'rom',
#    'via',
#    'studentessa'],
#   ['trovata', 'cinese'],
#   ['morta']),
#  (['', 'testa', 'rom', 'un...'], [], []),
#  (['pecora', 'pallone', 'bambino', 'rom', 'pastore'],
#   [],
#   ['colpisce', 'accecato']),
#  (['cambio', 'impegno', 'tasse', 'figli', 'scuola'],
#   ['nomadi'],
#   ['prefabbricati', 'pagare', 'mandare']),
#  (['rom', 'governo'],
#   ['delinquenti', 'clandestini'],
#   ['votare', 'libereremmo', 'protetti']),
#  (['autista', 'terrorista', 'killer', 'fuga'],
#   ['polacco'],
#   ['Attentato', 'cercato', 'fermare']),
#  (['mirino', 'nomade', 'monetine', 'acqua'], ['sorpreso'], ['rubare']),
#  (['Allarme', 'terrorismo', 'fantasmi', 'identificazione'], ['vera'], ['']),
#  (['Fatto', '#notizie', '#attentato'],
#   ['terroristico', 'metropolitana'],
#   ['sventato', 'Arrestato']),
#  (['stragi', 'violenza', 'forma', 'posto'],
#   ['terroristiche'],
#   ['condanniamo']),
#  (['terroristi'], [], []),
#  (['passato', 'Verità', '#democrazie'],
#   ['recente', 'occidentali'],
#   ['riscritto']),
#  (['invocazione', 'islamica', 'corda', 'non...'],
#   [],
#   ['conclusa', '”Afferratevi']),
#  (['civili', 'città', 'terroristi', 'scontri'],
#   ['violenti'],
#   ['avanzano', '#siriano']),
#  (['Campi', '#rom', 'bocciatura', '#roma'], ['severa'], ['richiama']),
#  (['Studentessa', 'rom'],
#   ['cinese', 'altri'],
#   ['morta', 'catturato', 'denunciati']),
#  (['storia', 'campo', 'rom', 'razzismo'], [], ['Bisogna', 'far', 'valere']),
#  (['talebani', 'mano', 'mitra', 'ragazzini', 'terroristi'],
#   [],
#   ['mettono', 'far']),
#  (['Intervista', 'Grazie'], ['liberale', 'musulmano'], []),
#  (['#ultimenotizie', '#news', '#notizie', 'rom', 'morte', 'studentessa'],
#   ['cinese'],
#   ['Fermato']),
#  (['nomade', 'fuga', 'furto', 'pm', 'risarcimento', 'milione', 'euro'],
#   [],
#   ['spara', 'chiede']),
#  (['stupro', 'campo', 'rom', 'pm', 'insediamento', '#news'],
#   ['#ansa'],
#   ['chiuso']),
#  (['garante', 'centro', 'minori', 'minacce', 'morte'],
#   ['stranieri'],
#   ['sequestrata']),
#  (['legame', 'wedding', 'matrimoni', 'italiani', 'dato', 'fatto'],
#   ['stretto', 'stranieri'],
#   []),
#  (['Repubblica', 'allarme', 'terrorismo', 'treni', 'bus', '#palermo'],
#   [],
#   ['bloccati']),
#  (['#profughi', 'minore', 'norme', 'immigrazione', 'optional'],
#   ['poveri', 'vero'],
#   ['accompagnato', 'rispettare']),
#  (['#Napoli', 'giorno', 'apertura', 'campo', 'rom', 'fascisti', 'ronde'],
#   ['nuovo', 'comunale'],
#   ['ricominciato', 'fare']),
#  (['migranti', 'posto'], [], ['hanno', 'pagano']),
#  (['Gentiloni',
#    'parte',
#    'islamici',
#    'terrorismo',
#    'vittime',
#    'silenzio',
#    'attentati'],
#   ['maggior'],
#   ['rifiuta']),
#  (['Lavori', '#rom'], [], []),
#  (['vaccinazioni', 'morbillo', 'vaiolo', 'poliomielite', 'rom'],
#   [],
#   ['combattuto', 'parlando']),
#  (['leggi', 'tutto...'], ['nomadi'], ['accampati']),
#  (['alleanza', 'unione', 'intenti', 'italia', 'islam', 'speranza'],
#   [],
#   ['serve', 'salvare']),
#  (['immigrati', 'rom', 'fondo'], ['nuovo'], ['', 'scrivete']),
#  (['superamento', 'campi', 'rom'], [], ['via', '']),
#  (['binari', 'ferrovia', 'rom'], [], ['Vivevano', 'sgomberati']),
#  (['CdT', 'accordare', 'di...'],
#   ['altri', 'stranieri'],
#   ['distanzia', 'permessi']),
#  (['corriere', '#rom', 'frase', 'benpensanti'],
#   ['stessa'],
#   ['scritto', 'sbraneranno']),
#  (['Inclusione', 'rom', 'scetticismo', 'case', 'i...'],
#   [],
#   ['regna', '#roma']),
#  (['parte', 'storia.', 'Ds,sky,giornali', 'raccordo', 'penne', 'rom.'],
#   ['altra'],
#   ['facendo', 'snobbare']),
#  (['ciclisti', 'nomadi', 'baraccati', 'zona'],
#   [],
#   ['', 'passeranno', 'vivono']),
#  (['amici', 'amici', 'pagina'], ['Benvenuti', 'stranieri'], ['seguono']),
#  (['crocerossa', 'attività', 'inclusione', 'ragazzi', 'ospiti'], [], []),
#  (['violenza', 'danni', 'auto', 'profughi', 'rom', 'assicurazione..'],
#   ['simbolica', 'bruciata....i'],
#   ['fare', 'hanno']),
#  (['enne', 'patente', 'panico', 'inseguimento', 'incidenti', 'feriti'],
#   [],
#   ['semina']),
#  (['banda', 'topi', 'auto', 'rom'], [], ['presa', 'arrestati']),
#  (['Censimento', 'superamento', 'campi', '', '#rom'], [], ['coinvolgere']),
#  (['tesoro', 'milioni', 'famiglie', 'rom...', '#news'], [], ['sequestrato']),
#  (['modo', 'nomadi', 'ma.', 'fatto'], ['gravissimo'], ['condivido', 'vivere']),
#  (['tw',
#    'alimento',
#    'odio',
#    'sinti',
#    'rom',
#    'grazie',
#    '#hatespeech',
#    '#violenza'],
#   ['#razzismo', '#odio'],
#   ['chiediamo', 'eliminar']),
#  (['stranieri', 'idea'], ['ottima'], ['sfruttare', '']),
#  (['#dimartedì', 'ragione', 'rom', 'salute'],
#   [],
#   ['ha', 'basta', 'fare', 'pesare', 'vedere']),
#  (['giro', 'mazzette', 'appalti', 'campi', 'rom', 'a...'],
#   [],
#   ['pilotare', '']),
#  (['ok', 'figli', 'garantito', 'rom'],
#   [],
#   ['', 'fare', 'fai', 'concepisci', 'mandi', 'elemosinare']),
#  (['fenomeno', 'migranti', 'paesi'], [], ['Paragonare', 'trasportati']),
#  (['#immigrati', 'diritto', '#italiani', 'errore'],
#   ['#clandestini'],
#   ['#dallavostraparte', 'hanno', 'spiegate']),
#  (['Inclusione', 'rom', 'scetticismo', 'case', 'italiani'], [], ['regna']),
#  (['diversità', 'pd', 'invasoone', 'immigrati'],
#   [],
#   ['è', 'firmato', 'autirizzare']),
#  (['neurone', 'rom'], ['clandestini', 'iussoli'], ['dotato', 'sa']),
#  (['controlli', '#polizia', 'campo'], ['nomadi'], []),
#  (['Senadid', 'carcere', 'aggravato', 'resistenza', 'pubblico'],
#   ['nomade', 'liberato', 'furto', 'ufficiale'],
#   ['accusadi']),
#  (['abilità',
#    'amici',
#    'jihādisti',
#    'vittime',
#    'terrorismo',
#    'testimonial',
#    'amore'],
#   ['islamico'],
#   ['consiste', 'trasformare']),
#  (['base', 'terrorismo.', 'realtà'], ['sicura'], ['', 'usata', '...sembra']),
#  (['sapienza', 'situazione', 'rom', 'gente'],
#   [],
#   ['fai', 'tor', 'arrabbiati', 'è', 'fa']),
#  (['Bici', 'ciclisti', 'campo'], ['nomadi'], ['rubate', 'trovate']),
#  (['fondo', 'po', 'po'], ['nomadi', 'stranieri'], ['pensando']),
#  (['vita', 'campi', 'profughi'], ['ita', 'insostenibile'], []),
#  (['fine', 'fuggitivo', 'revisione'], [], ['', 'fare', 'terrorizzato']),
#  (['reddito', 'cittadinanza', 'più', 'immigrati', 'rom', 'coperture'],
#   [],
#   ['costa']),
#  (['aumento', 'povertà', 'aumento', 'immigrati'], ['etc.etc'], ['']),
#  (['importanza', 'momenti', 'attentati', 'immigrazione'],
#   ['difficili', 'tragedia'],
#   ['ricorda']),
#  (['via', 'incontro', '…le', 'proposte', 'realtà'],
#   ['politiche', 'europee', 'locali'],
#   []),
#  (['#Ok', 'decreto', 'novità', 'testo', 'via'], ['libera', 'definitivo'], []),
#  (['nomadi', 'gabbiotto', 'addetti'], [], ['rinchiudono', 'denunciati']),
#  (['piano', 'migranti', 'blocco'], ['navale'], ['bloccare']),
#  (['vertici',
#    'accordi',
#    'ambiente',
#    'parigi',
#    '.quelli',
#    'roma',
#    'migranti',
#    'vienna'],
#   ['internazionali'],
#   ['parate', 'vanificati']),
#  (['Ministro', 'Esteri'], [], ['collaborare']),
#  (['vittime', 'ebree', 'musulmane', 'parte', 'umanità'],
#   ['uguali', 'stessa'],
#   []),
#  (['dito', 'fede', 'caccia', 'rom'], [], ['spezzano', 'rubar']),
#  (['polizia', 'rom', 'camper', 'gente'],
#   ['arresta', 'ladri'],
#   ['sgombera', 'applaude']),
#  (['go', 'pray', 'church', 'bisogno', '#Cristi'],
#   ['go', 'd'],
#   ['Fidanzato', 'dice', 'significa', 'ha']),
#  (['errore', 'migranti'],
#   ['catastrofico', 'grande'],
#   ['commesso', 'scegliendo', 'accogliere', 'ho']),
#  (['studenti', 'scuole', 'battenti', 'docenti'],
#   ['stranieri'],
#   ['chiuderebbero', 'perderebbero']),
#  (['reportage', 'traffico', 'migranti'], [], ['fatto', 'descrive']),
#  (['Via', 'campo', 'censimento'], [], ['maxirissa', 'nomadi']),
#  (['', 'disordine', 'rom', 'terra...', '#pdioti'],
#   [],
#   ['crea', 'frugano', 'lasciano', 'fotografato']),
#  (['giunta', 'euro', 'nomadi', 'scuola'], [], ['trasportare']),
#  (['paese', '#invasione'], [], []),
#  (['ragazzi', 'gente', 'paura', '#migranti'],
#   ['tali'],
#   ['è', 'muore', 'aiutar', 'fa', 'odia']),
#  (['news', 'Dicembre', 'terrorismi'], ['PTV'], ['colpiscono', '']),
#  (['allerta', 'terrorismo', 'rischio', 'Concertone'], ['massima'], []),
#  (['80enne', 'casa', 'botte', 'rapina', 'ascensore', 'rom'],
#   [],
#   ['Seguono', 'arrestati']),
#  (['terroristi', 'base', 'pace'],
#   ['logistica'],
#   ['', 'hanno', 'pianificare', 'copre']),
#  (['politica', 'famiglia', 'culi', 'vita'],
#   ['filo', 'musulmana', 'neri', 'bella'],
#   ['portato', 'fare']),
#  (['', 'rom', 'cazzate'],
#   ['varie'],
#   ['intervenuto', 'continua', 'occupar', 'pare']),
#  (['invasione', 'illuso', 'lavori', 'gratis'],
#   ['grandi'],
#   ['pagare', 'fare', 'bloccano']),
#  (['nomadi', 'agenti', 'Polizia', 'possesso', 'di...'],
#   ['minorenni'],
#   ['denunciate']),
#  (['inchiesta', 'campi', 'rom', 'pressi', 'università'],
#   ['importanti', 'connessi'],
#   ['perdetevi']),
#  (['ladri', 'rame', 'deposito', 'Ferrovie', 'Stato', 'banda', 'nomadi'],
#   [],
#   ['presa']),
#  (['bici', 'campo'], ['nomadi'], ['#Milano', 'Ritrovate']),
#  (['affanculo', 'terrorista', 'partito', 'momento', 'valigie'],
#   [],
#   ['va', 'perso', 'fare']),
#  (['legalità', 'illegalità', 'sistema', 'diffusione', 'peste'],
#   [],
#   ['Parliamo', 'porta']),
#  (['appello', 'chiesa', 'Azione', 'lobby', 'immigrazione'],
#   ['politica'],
#   ['Vaticano', 'far', 'cambiare']),
#  (['segreto', 'terrorismo', 'religione', 'provenienza', 'ideologia'],
#   [],
#   ['approfitto', 'svelare', 'ha', 'ha', 'ha']),
#  (['straniera.', 'italia'], [], ['', 'credo', 'stai', 'parlando']),
#  (['nomade', 'posto', 'elemosina', 'asilo', 'coop'],
#   ['utente'],
#   ['subappalta', 'richiedente']),
#  (['Signore', 'preghiere', 'morti', 'feriti', 'attacco'],
#   ['terribile', 'terroristico'],
#   ['#stoccolma']),
#  (['Video', 'rom', 'gabbiotto', 'boomerang'], ['ultima'], []),
#  (['nomadi', '#news'],
#   ['cinese', '#ansa'],
#   ['morta', 'condannati', 'derubarono']),
#  (['islamici', 'razzisti'], [], ['dire', 'temiamo', 'sennò']),
#  (['sti', 'pizza'],
#   ['stranieri'],
#   ['scusa', 'tacere', 'pensavo', 'sapere', 'fare']),
#  (['battesimo', 'bimbo', 'rom', 'famiglie'], [], ['sono']),
#  (['..peggio', 'mafia...si', 'criminali', 'rom'],
#   ['sempre..associazioni', 'immigrati'],
#   ['dico', 'arricchiscono']),
#  (['sera', 'puntata', 'video', 'donne', 'rom'],
#   [],
#   ['capito', 'parlerete', 'fate']),
#  (['migranti', 'sostengo', 'sindaco'], [], ['Magliano', 'arrivano']),
#  (['Strage', 'ufficiali', 'omicidio'], ['militare', 'colposo'], ['indagati']),
#  (['tangenti', 'campi', '#rom', 'funzionari', 'processo'], [], ['rischiano']),
#  (['migranti', 'giorno'], ['#clandestini'], ['soccorsi', 'Chiamate']),
#  (['rom', 'resto'], ['approvo', 'ke'], ['dice', 'dice', 'apprezzerà']),
#  (['Mortacci', 'coop', '#migranti'], ['vostri'], ['accorgono', 'lucrano']),
#  (['esercizio', 'immigrati', 'malattie', 'inferno'],
#   ['.....si'],
#   ['pensa', 'fatto', 'portano', 'scatenato']),
#  (['Operazione', 'Polizia', 'quartiere', 'rom', 'grammi', 'cocaina'],
#   [],
#   ['sequestrati']),
#  (['solco', 'buono', 'bar', 'sud', 'mafia', 'rom', 'casa'],
#   ['gentista'],
#   ['fatto', 'hanno', 'entrano']),
#  (['dubbio', '#rom'], ['#zingari'], ['era']),
#  (['comunità', 'rom'], [], ['dice', 'discriminate']),
#  (['assalto', 'metro'], [], []),
#  (['scuola', 'borseggio', 'metro', 'nomadi'], [], ['arrestate']),
#  (['legge', 'riconoscimento', 'cittadinanza', 'bambini'],
#   ['stranieri'],
#   ['nati', 'aspettare']),
#  (['minorenne', 'rom', 'furto'], [], ['Torre', 'arrestato']),
#  (['barbarie', 'imposizione', 'violenza', 'riconversioni', 'odi'],
#   ['islamiche', 'razziali'],
#   ['rischiano', 'fomentare']),
#  (['casa', 'gola', 'consigliere', 'rom'], ['ex'], ['ferito', 'arrestata']),
#  (['incendio', 'campo', 'colonna', 'fumo', 'problemi', 'traffico'],
#   ['nomadi', 'alta'],
#   ['scoppia']),
#  (['Provvedimento',
#    'immigrazione',
#    'difesa',
#    'identità',
#    'tradizione',
#    'governo'],
#   ['nuovi'],
#   ['aspettiamo', 'vediamo', 'dice']),
#  (['#rom', 'classe', 'genitori', 'problema', 'discriminazione', 'tutela'],
#   ['preoccupati'],
#   []),
#  (['Gentiloni', 'conti', '#notizie'], ['rigida', 'flessibile'], []),
#  (['designer', 'ladre', 'rom', 'colpo', '#designer'],
#   ['incinte'],
#   ['#Milano', 'circondato', 'sventato']),
#  (['sedia', 'madre'], ['spacca'], ['immigrato', 'arrestato']),
#  (['tragedia', 'migranti', 'grazie'],
#   ['bella', 'soli'],
#   ['lascia', 'costringendo', 'indebitar', 'salvar', 'assister']),
#  (['masochisti', 'giornalisti', 'italiani', 'fama...'],
#   ['soliti', 'stranieri'],
#   ['precisiamo', 'ridevano']),
#  (['Operazione', 'terrorismo'], ['black'], []),
#  (['Salvini', 'rom', 'ruspe'], [], ['fare']),
#  (['migranti', 'salvataggio', 'Giornale'], ['piccolo'], ['nato']),
#  (['campo', 'rom'], ['sgombero'], []),
#  (['giro', 'vite', 'carabinieri', 'procura', 'nomadi', 'piemontesi...'],
#   ['Stretto', 'sinti'],
#   []),
#  (['Guerra', 'terrorismo', 'religione', 'fondamentalisti', 'Guerra'],
#   [],
#   ['centrano', 'abbiamo']),
#  (['aiuti', 'rom'], [], ['Fiaccolata']),
#  (['giro', 'mazzette', 'appalti', 'campi', 'rom', 'procura'],
#   [],
#   ['pilotare', '']),
#  (['italiano', 'magistratura', 'vittima', '#rom'], [], ['muore', 'dorme']),
#  (['stirpe', 'rom', 'stronza'], [], ['credo', 'discenda']),
#  (['', 'numero', 'campagna'],
#   ['maggior'],
#   ['sembra', 'contare', 'proviene', 'è,a', 'fare']),
#  (['ricordo', 'strage'], [], []),
#  (['Bambini', 'rom', 'scuola', 'ruspa', 'Costituzione'],
#   [],
#   ['abbattere', '']),
#  (['uscita', 'migranti', 'soluzione'], ['illegale'], []),
#  (['strategia', 'campi', 'rom'], ['nuova'], ['imbonir', 'chiudere']),
#  (['piedi', 'cimitero', 'stranieri', 'anni', 'settembre', 'novembre'], [], []),
#  (['immigrata', 'accesso'], ['studentessa'], ['accoglie', 'negato', '']),
#  (['problema', 'fatto', 'nascita', 'islam', 'crociate', 'storia'],
#   [],
#   ['studi', 'riguarda']),
#  (['campo', 'rom'], ['nuovo'], ['nascerà']),
#  (['Sfruttamento',
#    '#prostituzione',
#    'favoreggiamento',
#    '#immigrazione',
#    '#nigeriani'],
#   ['clandestina', 'agrigentini'],
#   ['arrestati']),
#  (['Nazioni', 'casa', 'rom'], ['Unite'], ['dare']),
#  (['immigrati'], ['gnocche', 'felice'], ['sostituire', 'mantenere', 'dire']),
#  (['#Multiculturalismo', 'arresti', 'rom', 'mistero', 'ragazza'],
#   ['cinese'],
#   ['risorsa', 'risolto']),
#  (['scemenze', 'twitter', 'spirito', 'odio', 'migranti'], [], ['scritte']),
#  (['Ambasciatore', 'cambi', 'approccio', 'lotta', 'terrorismo'],
#   [],
#   ['spera']),
#  (['donne', 'rom', 'ragazza'], [], ['tentato', 'rapire', 'fatto']),
#  (['comunita', 'bene.'], ['islamica'], ['pagato']),
#  (['euro', 'terrorista', 'lavoro', '10mo', 'cifra'],
#   ['ucciso', 'stesso'],
#   ['faceva']),
#  (['Attacco', 'moschea', 'terroristi', 'arabo'], [], ['presi']),
#  (['polizia', 'campo', 'borse', 'controllo'],
#   [],
#   ['nomadi:trovate', 'rubate']),
#  (['Ragazza', 'rom', '16enne', 'uomo'],
#   ['cinese', 'morta', 'terzo'],
#   ['Fermato', 'denunciato', 'cerca']),
#  (['famiglia', 'rom', 'area', 'persone', 'terremoto', 'come...'],
#   [],
#   ['erano', 'colpite']),
#  (['Studentessa', 'nomadi', 'grazie', 'depenalizzazioni'],
#   ['cinese', 'liberi'],
#   ['morta', 'condannati', 'condannati', 'rimanere']),
#  (['stampa', 'parlamentare', 'fin', 'vita', 'via', '#migranti'],
#   ['serissima'],
#   ['dice']),
#  (['scuola', 'suore', 'cristiane', 'maggioranza'],
#   ['francescane', 'bambine'],
#   ['Andiamo', 'studiano']),
#  (['islam'], ['evidente'], ['fare']),
#  (['bastoni', 'campo', 'rom', 'bosniaco', 'omicidio'],
#   ['tentato'],
#   ['Rissa', 'fermato', 'accusato']),
#  (['marzo', 'immigrati', 'rom', 'preferita'],
#   ['islamici', 'comitiva'],
#   ['incontrerà']),
#  (['rom', 'ladri.'], ['....so', 'sportivi'], []),
#  (['rom', 'anni'], ['....le', 'problematiche'], ['esistono']),
#  (['Zuckerberg', 'big', 'ban'], [], ['rifugiati', 'immigrati']),
#  (['ragazzone', 'mano...', 'softair', 'legione', 'mamma'],
#   ['straniera'],
#   ['#chilhavisto', 'fatto', 'prendere', 'passando']),
#  (['rom', 'sinti', 'popolazione', 'territorio...'],
#   ['presente'],
#   ['vivono', 'rappresentano']),
#  (['condizioni', '#migrante', 'palle', '#razzisti', '#9febbraio'],
#   ['piccola'],
#   ['visto', 'stanno', 'sanno', 'parlano']),
#  (['scuola', 'video', 'rom', 'articolo', ''], [], ['imparato', 'parlando']),
#  (['rom', 'ok', 'disonesti'], ['disonesti', 'italiani'], ['vogliamo']),
#  (['Studentessa'], ['cinese'], ['morta', 'fermato']),
#  (['immigrati'], ['prigionieri'], []),
#  (['ruspe...', 'campi', 'rom', 'palazzi', 'anno'], ['buon'], ['vogliono']),
#  (['villa', 'nomadi', 'caccia', 'mesi'], [], ['Rapina', 'presi', 'durata']),
#  (['studentessa', 'treno', 'nomade'], ['cinese'], ['uccisa', 'fermato']),
#  (['stabilimento', '#museo', '#streetart', 'rom'],
#   ['ex'],
#   ['diventa', 'gestito']),
#  (['lavastrade'], ['immigrati', 'organizzati'], []),
#  (['rom', 'delinquenti', 'ragazza'],
#   ['italiani', 'cinese'],
#   ['fare', 'ucciso', 'studiava', 'so']),
#  (['dato', 'fatto', 'punto', 'snodo', 'passaggio', 'terroristi'], [], []),
#  (['rom', 'figli', 'testa', 'rom', 'rom'], [], ['fanno', 'togliere']),
#  (['casse', 'mandarini', 'attrezzi', 'nomadi', 'furti'],
#   [],
#   ['arrestati', 'colpito']),
#  (['sindaco', 'scuola', 'arti', 'stranieri', 'ideologo'],
#   ['leghista'],
#   ['crea', 'fare']),
#  (['condizioni', 'rom'], [], ['#dallavostraparte', 'fare', 'migliorare']),
#  (['chiusura', 'transitati', 'via'], [], []),
#  (['avviso', 'problema', 'costi', 'rom'],
#   ['buonista', 'approfittano.'],
#   ['sanno']),
#  (['tweet', 'vicinanza', '#donna', 'amico'], ['#immigrato'], ['malmenata']),
#  (['modi', 'popoli', 'fisici', 'margini', 'società', '#rom'],
#   ['interi', '#genocidi', 'morali'],
#   ['sono', 'distruggere', 'lasciando']),
#  (['imprendittore',
#    'azienda',
#    'tempo',
#    'supermercato',
#    'scarpe',
#    'islam',
#    'combatto'],
#   [],
#   ['sto', 'perdo', 'rifletto', 'fa']),
#  (['immigrati', 'stipendi', 'persone'],
#   ['belle'],
#   ['dice', 'vogliamo', 'diminuire']),
#  (['censimento', 'campi', 'rom', 'lavoro', 'superamento', 'villaggi'],
#   ['Concluso'],
#   []),
#  (['lega', 'destra', 'lavoratori', 'rom'],
#   ['stranieri'],
#   ['', 'sfrutta', 'contestano', 'guadagnato']),
#  (['fuoco', 'baracca', '18enne', 'rom', 'Foto'], [], ['ustionata']),
#  (['leggi', 'rom'], ['speciali'], []),
#  (['#dallavostraparte',
#    'dignità',
#    'illegalita',
#    'affermazione',
#    'sig',
#    'nero',
#    'livello',
#    'rom'],
#   [],
#   ['Riacquistare', 'è']),
#  (['buonista', 'razzista', 'poliziotto', 'terrorista', 'terrorista'],
#   ['ke', 'fascista', 'francese', 'ke', 'caro'],
#   ['sentire', 'sparato']),
#  (['anni', 'giro', 'rapine', 'banda'], [], ['fare', 'presa']),
#  (['donne',
#    'rom',
#    'paura',
#    'sberleffo',
#    'cittadini',
#    'vittime',
#    'anni',
#    'rom'],
#   [],
#   ['#biancoenero', 'hanno', 'ridicoli']),
#  (['esempio', 'immigration'], ['iraniana'], ['prendiamo', 'namo']),
#  (['case', 'rom'],
#   [],
#   ['Visto', 'difendete', 'hai', 'dire', 'dare', 'stanziato']),
#  (['immigrazione', 'Presentazione', 'gennaio', 'libreria'], [], []),
#  (['Giornata', 'rom'], [], ['commemorano']),
#  (['Ordine', 'ebrei', 'cattolici', 'cristiani'], ['islamici'], ['revocato']),
#  (['Foto'], [], ['ospiterei']),
#  (['', 'serie', 'gente', 'opportunità'], ['brava'], []),
#  (['autorità', 'raid', 'stati', 'stato', 'allerta'],
#   ['tedesche', 'antiterrorismo'],
#   ['effettuato']),
#  (['', 'terrorista', 'colpa', 'pd', 'alfano', 'soldi', 'coperative'],
#   ['rosse'],
#   ['fatto', 'passare', 'fatte']),
#  (['verità', 'immigrazione'], ['clandestini'], []),
#  (['campo', 'raggi', 'persone', 'precedenti', 'ricercato'],
#   ['nomadi', 'controllate'],
#   ['è']),
#  (['proteste', 'compagnie', 'misure', 'ambito'], [], ['schierano']),
#  (['rom', 'complotti'], [], ['uncino']),
#  (['trovata', 'ore', 'banditi', 'campo', 'rom'],
#   ['cinese', 'morta'],
#   ['contate', 'scippata', 'Vengono']),
#  (['Giornata',
#    'diritti',
#    'adolescenza',
#    'Associazione',
#    'luglio',
#    'rom',
#    'povertà'],
#   ['Internazionale', 'infanzia', 'minori', 'assoluta'],
#   ['vivono']),
#  (['Gb', 'barriere', 'castello', 'cambio', 'guardia', 'meta', 'turisti'],
#   ['nuove', 'tradizionale'],
#   ['antiterrorismo']),
#  (['via', 'arrivo', 'nigeriani', 'zona', 'nomadi', 'problema'],
#   ['casalombroso', 'problematica'],
#   ['previsto', 'innestando']),
#  (['caso', 'attacco'], ['terroristico'], ['fare']),
#  (['sequestratori', 'donna', '#rom', '#rom', 'sorella', 'figlia'],
#   ['bianconero'],
#   ['vedere']),
#  (['futura', 'roma', 'rom', 'caminanti', 'accesso', 'servizi'],
#   ['Politica', 'sinti'],
#   ['spera']),
#  (['stampa', 'parte', '#ribelli', 'civili', '#terroristi'],
#   ['gran', '#siriani', 'inermi'],
#   ['Tanta', 'ignorato']),
#  (['media', 'giornalisti', 'rosa', 'partite', 'nazionale'],
#   ['Italiani', 'stranieri'],
#   ['spero', 'accontenti', 'vedremo', 'rilassati']),
#  (['', 'sindaco', 'sindaco', 'ordinanze', 'rom', 'auguri'],
#   ['uguale'],
#   ['è', 'mette', 'fioriere', 'è', 'fa']),
#  (['immigrati'], ['restante'], ['rifugiati', 'mettere']),
#  (['indagati', 'favori', 'migranti', 'viceprefetto'], [], ['arrestato']),
#  (['chiusura', 'campo', 'rom', 'sinistra', 'sinistra'], [], ['boccia']),
#  (['musulmano', 'donna', 'proni', 'volontà'],
#   ['inferiore'],
#   ['considera', 'è']),
#  (['stadio', 'testa', 'saviano', 'xo', 'paesi'],
#   ['roma,lidl,rom,la'],
#   ['vede', 'parlare', 'sono', 'terremotati', 'fatto']),
#  (['aggressione', 'rapina', 'dettagli', 'arresto', 'rom', 'web'], [], []),
#  (['genere', 'velo'],
#   ['favorevole', 'islamico'],
#   ['immagino', 'accaduto', 'avessero']),
#  (['campo', 'rom', 'arresti', 'ombra', 'racket'], [], ['rapina']),
#  (['boom', '#italiani', '#turisti', 'crisi', 'terrorismo'],
#   [],
#   ['Capodanno', '']),
#  (['', 'nn', 'litro', 'latte', 'rom', 'prostitute'],
#   [],
#   ['sa', 'costa', 'figuriamo', 'parlare', 'parla']),
#  (['dibattito', 'sicurezza', 'immigrazione', 'omicidio', 'piazzale', ''],
#   ['Loreto'],
#   ['riaccende']),
#  (['case', 'rom', 'rabbia', 'residenti'], ['popolari'], ['assegnate']),
#  ([], ['immigrati'], []),
#  (['Studentessa', 'ventenne', 'nomade', 'campo', 'via'],
#   ['cinese'],
#   ['morta', 'fermato', '']),
#  (['negozio', 'terroristi', 'protesta', 'clienti'], [], ['colpito', 'scatta']),
#  (['cu', '#terrorismo'], ['nuove'], []),
#  (['Podisti', 'video', 'campo', 'rom'], ['marsicani'], ['derubati']),
#  (['mittente', 'immigrazione'], [], ['Rimando', 'accusa']),
#  (['scuola', 'rom', 'tempo'], ['bambina'], ['andata', 'giocato', 'speso']),
#  (['carabinieri', 'albergo', 'profuga', 'bambina'], [], ['pagano']),
#  (['campo', 'censimento', 'arresti'], [], ['rissa', 'nomadi']),
#  (['bello', 'nomadismo'], ['differentispossible'], ['sentire', '', 'parlare']),
#  (['stupro', 'campo', 'rom', 'pm', 'insediamento'], [], []),
#  (['fase', 'strillo', 'canzone', 'mente', 'campo', 'rom'],
#   [],
#   ['Grillo', 'stai', 'venuto']),
#  (['reazione', 'migrante'], ['forte'], ['entra']),
#  (['Bilancio', 'salvadanaio', 'migranti', 'oneri', 'onori'], ['stessi'], []),
#  (['#immigrati', 'Imprenditori'],
#   ['pseudo'],
#   ['campano', 'arricchiscono', '']),
#  (['tweet', 'condanna', 'gesto', 'rom...'], [], ['', 'vedo']),
#  (['italy', 'animali', 'barconi', 'rom', 'vergogna', 'governo'],
#   ['ecc'],
#   ['fanno', 'morire', 'arriva', 'danno']),
#  (['donna', 'ladre', 'rom'], [], ['picchiata', 'denunciato', '']),
#  (['uomini', 'aspetto'], [], ['avuto']),
#  (['islamici'], [], ['Rimangono']),
#  (['centinaia',
#    'casi',
#    'mesi',
#    'casi',
#    '#morte..tranquilli',
#    'norma',
#    '#immigrazione'],
#   ['primi'],
#   ['#meningite', 'incide']),
#  (['occasione', 'rom'], [], ['perdete', 'fare']),
#  (['sopravvive', 'immigrati'],
#   ['concordo'],
#   ['penso', 'disposte', 'calpestare']),
#  (['rom', 'italiani.....'], [], ['fare', 'so']),
#  (['profughi', 'arrestato', 'accuse', 'vittima'], [], ['respinge']),
#  (['forza',
#    'immigrati',
#    'governo',
#    'città',
#    'favelas,violenze',
#    'sporcizia,furti',
#    'degrado'],
#   [],
#   ['sembra', 'goda', 'avere']),
#  (['intesa', 'petrolio', 'terrorismo'], [], ['raggiunta']),
#  (['', 'rom', 'casa', 'leggi'],
#   ['illegali', 'europee'],
#   ['vengono', 'applichiamo']),
#  (['Questione', 'rom', 'piano', 'lavoro'], [], ['bluffa']),
#  (['lite', 'rom', 'Intervento'], ['#MunicipioIII', 'ennesima'], []),
#  (['anziani', 'pranzo'], [], ['accompagnano']),
#  (['rom', 'sentenze', 'tribunale', 'disastro'],
#   ['ambientale'],
#   ['madama', 'sgombra']),
#  (['', 'straniero', 'milioni', 'pezzi'],
#   [],
#   ['restanti', 'risparmiati', 'inizia', 'comprar', ',figo,no']),
#  (['testa', 'servizi', 'gente'],
#   ['americani'],
#   ['toglie', 'seguono', 'sanno', 'stanno', 'fare']),
#  (['agente', 'cella', 'picchia', 'agente', '|...'],
#   [],
#   ['tocca', 'finisce', 'torna']),
#  (['bacchettata', 'situazione', 'rom'], [], []),
#  (['simpatia', 'dipendenti', 'rom'], [], ['spiace', 'provo']),
#  (['migranti', 'estero', 'paesi'],
#   ['stessi', 'esteri'],
#   ['andare', 'vogliono']),
#  (['studentessa', 'condanna', 'patteggiamento', 'rom'], ['cinese'], ['morta']),
#  (['profughi'], [], ['destinati']),
#  (['campagna', 'racconto', 'legge', 'immigrazione', 'obiettivi'],
#   [],
#   ['Lanciata', 'cambiare']),
#  (['rom', ',assassini', 'cazzo', 'etnia'],
#   [],
#   ['delinquenti', 'ladri', 'entra']),
#  (['#rom', 'stereotipi', 'discriminazioni', 'persone'],
#   [],
#   ['visto', 'lavora', 'colpiscono', 'appartenenti']),
#  (['Allaccio', 'campo', 'rom', 'mesi'], ['regolare'], ['cambiato']),
#  (['musulmani', 'terroristi', 'paese'], [], ['attacca', 'accolga']),
#  (['scuola', 'alunni'], ['stranieri'], []),
#  (['Giornale', 'rom', 'diritti'], [], ['fondano']),
#  (['nomadi', 'asilo'], ['politico'], ['chiedono']),
#  (['banda',
#    'rom',
#    'pizzo',
#    'anni',
#    'ristoratore',
#    'colpi',
#    'mitra',
#    'permaloso..'],
#   ['esausto'],
#   ['chiedeva', 'uccide']),
#  (['stupidità', 'donna', 'islamico'], ['incredibile', 'critica'], ['', 'sta']),
#  (['crisi',
#    'salute',
#    'migranti',
#    'tragedie',
#    'migranti',
#    'rifugiati',
#    'riversano...'],
#   ['mentale'],
#   []),
#  (['valanga', 'voti', 'immigrazione', 'virata'],
#   [],
#   ['perdendo', 'accorti', 'tentato', 'crede']),
#  (['#dallavostraparte', 'visita', 'rom', 'cosa', '#lodi'],
#   ['#cimbro', 'ricevi', 'predica', '#legittimadifesa'],
#   ['Speriamo', 'vediamo']),
#  (['amore', 'immigrati', 'schifo'], ['Strano'], ['fanno']),
#  (['rom', 'minoranze', 'gen.,ma', 'dissidenti', 'nonno'],
#   ['ebrei'],
#   ['pestato']),
#  (['terroristi', 'tratte'], ['stesse'], ['facciamo', 'prendo']),
#  (['amico', 'dittatore', 'terroristi', 'bombe'],
#   [],
#   ['Visto', 'vede', 'fanno']),
#  (['coprifuoco', 'compagni', '#nave', '#migranti'],
#   [],
#   ['dicono', 'utilizzata', 'lasciare']),
#  (['#migranti', 'anno'], [], ['servono']),
#  (['storia', 'campi', 'rom'], [], []),
#  (['Capo', 'decreto', 'immigrazione'], [], ['licenzia']),
#  (['giro', 'mazzette', 'appalti', 'campi', 'rom', 'procura', 'inchiesta'],
#   ['nuova'],
#   ['pilotare', 'chiude']),
#  (['#dallavostraparte', 'nero...'],
#   ['fottiti', ''],
#   ['principessina', 'nomadano', 'sbattono']),
#  (['ricorso', 'appello', 'ok', 'sospensione', 'politica', 'migranti'],
#   [],
#   ['Respinto']),
#  (['dito', 'fede', 'caccia', 'rom'], [], ['spezzano', 'rubar']),
#  (['contratto', 'case', 'case.Solo'],
#   ['immigrati'],
#   ['DIRITTOOO.Hanno', 'pagato.Guardate', 'danno', 'pagano']),
#  (['accordo', 'migranti'], [], ['saltato']),
#  (['#rom',
#    'sapere',
#    'borseggio',
#    'fondi',
#    'assegnazione',
#    'case',
#    'esenzioni',
#    'romani'],
#   [],
#   ['tramandano', 'Raggi']),
#  (['nomadi', 'asilo'], ['politico'], ['chiedono']),
#  (['arresti', 'rom', 'mistero', 'ragazza'], ['cinese'], ['risolto']),
#  (['Papa',
#    'studenti',
#    'risposta',
#    'paura',
#    'accoglienza',
#    'accompagnamento',
#    'migranti'],
#   [],
#   []),
#  (['parte', 'immigrati', 'carica', 'conti'],
#   [],
#   ['accettare', 'risulta', 'fatto']),
#  (['colombiana', 'metro', 'rom'], [], ['becca', 'rubare', 'riducono']),
#  (['migliaia', 'cinesi', 'rom'], [], ['votarono']),
#  (['cinese', 'ore', 'campo', 'rom'],
#   ['morta'],
#   ['contate', 'scippata', 'Vengono']),
#  (['', 'processo', 'codice', 'rom'],
#   ['penale', 'clandestini', 'caro'],
#   ['difende']),
#  (['diventati', 'cittadinanze', 'complici'], ['italiani', 'Ong'], []),
#  (['', 'guerra', 'migranti', 'richiedenti', 'asilo', 'diritti'],
#   ['difficile'],
#   ['scappano', 'distinguere']),
#  (['rom', 'correttore', 'telefono'], [], []),
#  (['stragi', 'terrorismo', 'vedi'], ['/atti'], ['fare']),
#  (['spalle', '#rom'],
#   [],
#   ['divisa', 'guarda', 'fida', 'disprezza', 'vissuto']),
#  (['corno', 'euro', 'euro', 'rom'], [], ['', 'voglio', 'capire', 'parlare']),
#  (['dito', '80enne', 'fede', 'Caccia', 'rom'], [], ['spezzano', 'rubar']),
#  (['fatto', 'indicazione'], ['straniero'], ['so', 'fornisce']),
#  ([], [], ['scritto']),
#  (['domiciliari', 'furto', 'nomadi', 'treno'],
#   ['libero'],
#   ['condannati', 'scipparono', 'morta']),
#  (['#padova', 'ladre', 'grondaia', 'nomadi', 'incinta', 'mese'],
#   ['acrobate'],
#   ['arrampicano', 'fermate']),
#  (['anni', 'immigrati', 'rom....'],
#   [],
#   ['Riprender', 'cominciando', 'occupato']),
#  (['', 'donna', 'campo', 'rom', 'via'], ['trovata'], ['morta']),
#  (['Caos', 'migranti', 'via'], ['sgombero'], []),
#  (['rom...', 'turisti', 'decine', 'ragazzi'],
#   ['romani'],
#   ['controlla', 'lavorare']),
#  (['milioni', 'campi', 'rom'], [], ['spende']),
#  (['conferma', 'immigrati', 'scelti.', 'sapevo', 'conferma'],
#   [],
#   ['avuto', '....avere']),
#  (['Malattie', 'diritto', 'studio', 'fine', 'famiglie', 'rom', 'via'],
#   ['negato'],
#   ['fatto', 'sgomberate']),
#  (['MILIONI', 'famiglie', '#rom', 'cittadinanza'],
#   ['insediate'],
#   ['RISORSE', 'Sequestrati']),
#  (['campi', 'milioni', 'anno'], ['nomadi'], ['finanziava']),
#  (['fonte', 'mainstream', 'immagini', 'strage', 'gas', 'terrorista'], [], []),
#  (['pista'], ['valuta'], ['islamista\\nFerito']),
#  (['campo', 'schifo', 'rom'], [], ['smantellato']),
#  (['media', 'attacco'], ['terroristico'], ['cercato', 'dire']),
#  (['', 'momento', 'terrorismo', 'fenomeno', 'feriti'],
#   ['locale'],
#   ['sa', 'tratta', 'morti']),
#  (['guida',
#    'gommone',
#    'migranti',
#    'polizia',
#    'finanza',
#    '#blogsicilianotizie'],
#   [],
#   []),
#  (['Top', '#news', 'campo', 'rom'],
#   ['nuovo', 'see', 'more'],
#   ['esposto', 'Bando']),
#  (['argentina', 'muro'], ['anti', '-immigrati'], ['vogliamo']),
#  (['#demagogia', 'problema', 'migranti', 'barconi'],
#   ['confusionaria'],
#   ['Solita', 'sposta', 'arrivano']),
#  (['problema', 'cultura', 'legalità', 'rom', 'bambini'],
#   ['#biancoenero'],
#   ['è', 'vanno', 'rubare', 'è', 'spinge']),
#  (['Domenica', 'fede', 'cristiani', 'profughi'], ['iracheni'], []),
#  (['messaggero', 'acqua', '#rom'], ['calda'], ['scoperto']),
#  (['campi', 'rom'], [], ['lavorando', 'chiudere']),
#  (['scontro', 'migranti', 'Pronti', 'veto', 'quote', 'causa'], [], ['fare']),
#  (['migranti', 'passaporti'], [], ['Fermati', 'rubati']),
#  (['strilli', 'sbraiti', 'rom', 'minoranza', 'stolti'],
#   [],
#   ['Basta', 'mobilitare', 'abituati', 'difendere']),
#  (['campo', 'rom'], ['nuovo'], ['nascerà', '']),
#  (['scatenata', 'statua', 'libertà', 'immigrazione'],
#   ['anacronistica'],
#   ['Incita']),
#  (['grazie', 'stasera', '#convergenze'],
#   ['bravo', 'migranti', '#migrationNocrime'],
#   ['nominato', 'parla']),
#  (['rom', 'mirino', 'coop', 'politici'], [], []),
#  (['#ultimenotizie',
#    'notizie',
#    'foto',
#    'blitz',
#    'arresto',
#    'terrorista',
#    'strage'],
#   [],
#   ['portato']),
#  (['roma', 'campi', 'italiani', 'abitazioni', 'gente', 'boldrini'],
#   ['nuovi', 'nomadi'],
#   ['abbandonano', 'abbiamo', 'difende']),
#  (['setaccio', 'carabinieri', 'campo', 'nomadi', 'Via', '#news'],
#   [],
#   ['Passato']),
#  (['incubo', 'rom', 'lezione'],
#   [],
#   ['svegliato', 'culona', 'siede', 'soffocando', 'detto']),
#  (['cazzo', 'rom'], ['merda'], ['sa', 'entrino']),
#  (['tunisini', 'rom'], [], ['', 'metti', 'cavano']),
#  (['anziani', 'nomadi', 'fatto'], ['sinti', 'assolti'], ['commesso']),
#  (['fatto', 'palle', 'religioni', 'attentato', 'stampo'],
#   ['islamico'],
#   ['guarda', 'stiano', 'entra']),
#  (['Papa', 'migrante', 'terra'], ['lontana'], []),
#  (['poliziotto', 'terrorista', 'località'],
#   ['segreta'],
#   ['uccise', 'trasferito']),
#  (['gemello', 'terroristi', 'dubbio', 'alleanza'],
#   ['piccolo', 'palese'],
#   ['viavai', 'aveva']),
#  (['accordo', 'migranti'], [], []),
#  (['rom', 'voto', 'associazioni'], [], ['passo', 'slitta', 'Ascoltiamo']),
#  (['lavoro', 'immigrati'], [], ['hanno', 'sono']),
#  (['banda', 'rom', 'circonda', 'rapina', 'via'], ['turista'], ['incinte']),
#  (['rom', 'macchinoni', 'oro', 'cianfe', '#schifo'],
#   [],
#   ['dite', 'hanno', 'lavorano']),
#  (['giunta', 'euro', 'nomadi', 'scuola'], [], ['trasportare', '']),
#  (['Giornata', '#migrante', '#sindacati', 'appello'],
#   ['#internazionale', '#pensionati'],
#   ['firmano']),
#  (['Messaggio', 'ufficiali', 'islamisti'],
#   ['chiaro'],
#   ['detiene', 'dirigevano']),
#  (['Associazioni', 'derubati'], ['vero'], ['pensate', 'inventato']),
#  (['giornata', 'memoria', 'accordo', '#profughisiria'], [], ['mette']),
#  (['can', 'can', 'giorni', 'elezioni', 'vittoria', 'antislamista'],
#   [],
#   ['sancire']),
#  (['rapine', 'turisti', 'nomadi'], [], ['pubblicato', 'fermate']),
#  (['ragazza', 'notte', 'ai...'], ['immigrato'], ['sequestrata', 'stuprata']),
#  (['nomadi', 'aree', 'lavoro', 'superamento', 'campi'], ['attrezzate'], []),
#  (['chiesa', 'persone', 'operazioni'],
#   ['copta', 'altre', 'terroristiche'],
#   ['Attentato', 'Arrestati', 'sospettati', 'progettare']),
#  (['immigrati', 'canale', 'introiti'], [], ['rendono', 'diceva', 'trovato']),
#  (['ambulante', 'sputi', 'agenti', 'rom'], [], ['botte', 'arrestati']),
#  (['Caos', 'furto', 'bordo', 'nave', 'immigrati'], [], ['identificati']),
#  (['', 'parte', 'stupidità', 'dipendenti', 'nomade'],
#   [],
#   ['recita', 'invita']),
#  (['linciaggio', 'bar', 'piazza', 'ragazzini', 'nonno'],
#   ['extracomunitario', 'infuriato'],
#   ['Bojano', '#bojano']),
#  (['terrorista', 'giudici'], [], ['interrogato', 'rifiuta', 'rispondere']),
#  (['IL', 'individuo', 'volonta', 'vero', 'creatore'],
#   ['musulmano', 'unico'],
#   ['sottomette']),
#  (['Secessionisti', 'pm', 'rinvii', 'giudizio', 'terrorismo'], [], ['chiede']),
#  (['colpe', 'islam', 'guerrafondaie', 'territori'],
#   ['politiche'],
#   ['riconoscere']),
#  (['#sud', 'Allarme', 'povertà', 'centri...'],
#   ['#andria', 'italiani', 'stranieri'],
#   []),
#  (['ministro', 'ingiustizia', 'sntenze', 'favore', 'rom', 'marcia', 'favore'],
#   ['tutte'],
#   ['fa', 'vedere']),
#  (['parte', 'storia', '#islam'], ['#10aprile'], ['racconta', '#cassimatis']),
#  (['minaccia', 'terrorismo', 'diffusione', 'cultura', 'primitiva.'],
#   ['vera', 'barbara'],
#   []),
#  (['mario', 'cipriani', '', 'negozi', 'stranieri', '6°mun...'],
#   ['fascista'],
#   []),
#  (['senno', 'rom', 'rame'], [], ['uscendo', 'disegna', 'vestiti', 'rubano']),
#  (['rom'], ['illegale'], ['adattare', 'dire', 'rubare']),
#  (['#dallavostraparte', 'rom', 'lavoro', 'rom', 'tasse', 'italia', 'case'],
#   [],
#   ['esiste', 'cerca', 'pagano', 'pretendono']),
#  (['attentatore', 'cibo', 'migranti...'], [], ['era', 'portava']),
#  (['esplosione', 'terrorismo'], ['pronta'], ['collaborare']),
#  (['farmacisti', 'terrorismo', 'sos', 'congresso', 'missi......'],
#   ['migranti'],
#   ['parla']),
#  (['bonifica', 'campi', 'rom', 'rinvii', 'giudizio'],
#   [],
#   ['mazzette', 'chiesti', '']),
#  (['mesi', 'nomade', 'inseguimento'], [], ['ricercata', 'arrestata']),
#  (['', 'Grazie', 'arroganza', 'volta', 'eh...'],
#   ['islamisti', 'buona'],
#   ['sveglia', 'vediamo']),
#  (['soluzione', 'terroristi.', 'loro...'],
#   ['..basta'],
#   ['', 'far', 'diventare', 'fare', 'vogliono']),
#  (['immigrazione', 'governo', 'magia'], [], ['ricorre']),
#  (['campo', 'rom'], ['nuovo'], ['nascerà']),
#  (['Yao,i', 'rom', 'vicenda', 'bottino'], [], ['accusano']),
#  (['profugo', 'mozione', 'banchi', 'sala'], [], ['Adotta', 'approda']),
#  (['indagini', 'sull‘ideologia', 'estremisti'],
#   ['islamici', 'illegittima'],
#   ['dici']),
#  (['', 'parte', 'fatto', 'controllo', 'immigrazione'],
#   ['preventivo'],
#   ['stavo', 'parlando', 'giustifica']),
#  (['favore', 'bicchiere', 'acqua', 'nomadi', 'soldi'], [], ['rubano']),
#  (['rom', 'webitalia360...'], [], ['circondata', 'derubata']),
#  (['#dallavostraparte', 'signora', 'figlio', 'campi', 'rom', 'giorno'],
#   [],
#   ['lasci', 'vediamo', 'pensa']),
#  (['voti'], ['islamici'], ['eletti']),
#  (['euro', 'rom', 'volta', 'vittima...'],
#   [],
#   ['condannato', 'risarcire', 'cercò', 'uccider']),
#  (['donne', 'rom', 'volto', 'miseria', 'gabbia'], [], ['filmate', 'derise']),
#  (['casa', 'rom'], [], ['dare']),
#  (['responsabili', 'situazione', 'vigliacco', 'rom', 'migranti', '#bravo'],
#   ['faticoso', 'rischioso'],
#   ['Prender', 'prendi']),
#  (['incremento', 'reati', 'aumento', 'presenza', 'immigrati'],
#   [],
#   ['stato', '']),
#  (['ladri', 'rom', 'balcone'], ['acrobati'], ['arrestati', 'arrampicavano']),
#  (['rom', 'accoglienza', 'discriminazione', 'marzo'], ['convegno'], []),
#  (['rom....parmi'], ['strano'], ['sbagliati']),
#  (['ragazza', 'donne', 'rom'],
#   [],
#   ['tentano', 'rapire', 'far', 'prostituire', 'arrestate']),
#  (['Studentessa', 'rom'], ['cinese', 'terzo'], ['morta', 'fermato']),
#  (['massacri', 'cristiani', 'azizi', 'gole'],
#   ['musulmani', 'tagliate'],
#   ['Piazzapulita', 'fermata', 'dimenticato']),
#  (['#notizie', 'carovana', 'nomadi', 'settimana', 'ca...'],
#   [],
#   ['sgomberata']),
#  (['ok', 'campo', 'rom', 'Misure', 'Obiettivo', 'villaggi'],
#   ['comune', 'nuovo', 'temporanee'],
#   ['superare']),
#  (['ragazza', 'centro', 'accoglienza', 'profughi', 'operatori'],
#   [],
#   ['Muore', 'rivolta', 'bloccano']),
#  (['mesi', 'muro'], ['anti', 'migranti'], ['finito', 'finanziato']),
#  (['scuola', 'figlio', 'elemosina'],
#   [],
#   ['manda', 'far', 'chiedere', 'arrestata']),
#  (['rom', 'interno', 'forbice', 'unità'],
#   ['presenti', 'ampia', 'controversa', 'compresa'],
#   ['mantengono']),
#  (['scuola', 'zingari', 'figli', 'rom', 'euro'], [], ['spingono', 'bastano']),
#  (['palme', 'cammelli', 'tetto', 'rom'],
#   [],
#   ['#Milano', 'cacciano', 'taglieggiati']),
#  (['Maltempo', 'fiume', 'piena'], [], ['arrivato', 'disperso', 'sfigati']),
#  (['cristiano', 'anti-islam', 'squadra'], [], []),
#  (['scuola,arrestato', 'rom', 'pc', 'monitor'],
#   [],
#   ['Ruba', 'computer', 'preso', 'impossessato']),
#  (['ragazza', 'rom'],
#   [],
#   ['Cercano', 'rapire', 'far', 'prostituire', 'arrestate']),
#  (['negri', 'rom', 'risorse'], ['islamici', 'clandestini'], ['dimostra']),
#  (['numeri', 'migrante', 'abitanti', 'invasione'], [], ['spaventosi']),
#  (['#cristiani', '#terroristi'], [], ['#libera']),
#  (['campo', 'residenti', 'blitz'],
#   ['nomadi', 'abusivo', 'pregiudicati', 'maxi'],
#   ['Sgomberato']),
#  (['nomadi', 'furto', 'coppia'], [], ['arrestati']),
#  (['bambini', 'ospedali', 'terroristi'],
#   ['civili'],
#   ['sanno', 'nascondono', '']),
#  (['Italiani', 'stranieri', 'Paese'], ['integrati'], ['aiutano']),
#  (['podisti', 'rom'], [], ['perseguitati']),
#  (['#dallavostraparte', 'condoni', 'passato', 'governo', 'cosa', 'rom'],
#   [],
#   ['stai', 'facendo', 'basta']),
#  (['tensione', 'capitale', 'fuga', 'capi', 'lire', '#Terrorismo'],
#   ['terroristi', 'siriane'],
#   ['portando']),
#  (['Governo', 'comunità', 'vittima', 'terrorismo'],
#   ['musulmana'],
#   ['Attentato']),
#  (['#terrorismo', 'vittima', 'strada'], [], []),
#  (['Psicosi', 'leggende', 'Attenzione', 'furgone', 'rom'],
#   ['pieno'],
#   ['galoppano']),
#  (['giocatori', 'straniero'],
#   ['italiani', 'brocchi'],
#   ['temo', 'oriundo', 'andrebbe']),
#  (['programmi', 'battute', 'immigrazione', 'cosa', 'coglioni'],
#   ['seria', 'albanese', '#domenicalive'],
#   ['cazzeggia']),
#  (['giro', 'vite', 'tagli', 'welfare', 'stranieri', 'sussidi', 'anni'],
#   [],
#   []),
#  (['#nomadi', '#strada', '#frigorifero', 'automobilisti'],
#   [],
#   ['bloccano', '#rapinare']),
#  (['sparatoria', 'pressi', 'centro'], ['islamico'], ['Attentato']),
#  (['furto', 'appartamento', 'rom', 'via', '#news'],
#   ['minorenni'],
#   ['denunciati']),
#  (['donne', 'inseguimento'], ['nomadi', 'pericoloso'], ['retata']),
#  (['migranti', 'punti', '#news'], ['salienti', '#ansa'], []),
#  (['cuccioli', 'vendita', 'indagini', 'campo', 'rom'], [], ['sequestrati']),
#  (['tempo',
#    'guerre',
#    'popoli',
#    'fuga',
#    'terrorismo',
#    'violenze',
#    'semi',
#    'bontà',
#    'bellezza'],
#   [],
#   ['fatto', 'spargere']),
#  (['donne', 'spazzatura', 'sequestri', 'torturi', 'stranieri'],
#   ['incivili'],
#   ['', 'vedi', 'frugare', 'dici']),
#  (['registro', '#confini', '#profughi', '#immigrazione'],
#   [],
#   ['cambia', 'chiude']),
#  (['persone', 'cena', 'profughi'], [], ['preparata']),
#  (['invasione', 'rom', 'ospedale', 'capofamiglia', 'moglie'],
#   ['quotidiano'],
#   ['dona']),
#  (['miliardo', 'Musulmani', 'terroristi', 'fondamentalisti'],
#   [],
#   ['credo', 'credo']),
#  (['Bambini', 'rom', 'scuola', 'ruspa', 'Costituzione'], [], ['abbattere']),
#  (['domenica', 'rom', 'campi', 'torre', 'fumi'],
#   ['antismog', 'abusivi', 'spaccata', 'tossici'],
#   ['', 'smettere', 'emanare']),
#  (['trombati', 'rom', 'politica'], [',i'], ['#portaaporta']),
#  (['paese', 'tombe', 'migranti'], [], ['ospitare', 'morti']),
#  (['legge', 'minori'], ['stranieri'], ['accompagnati']),
#  (['business', 'profughi'], ['falsi'], []),
#  (['', 'negozi', 'carrefour', 'tedesca'],
#   ['stranieri', 'francesi', 'lidl'],
#   ['intendono']),
#  (['campo', 'rom', 'procura', 'sequestro'], [], ['convalida']),
#  (['lavori', 'esima', 'accoglienza'], [], ['Aperti', 'Parliamo']),
#  (['#PrimariePD', 'coscrizione', 'nomadi', 'farsa', 'inizio'],
#   ['pronti'],
#   ['abbia']),
#  (['campo', 'rom', 'procura', 'sequestro', 'Giornale'], [], ['convalida']),
#  (['scommesse', 'tipo', 'lavoro', 'rom'],
#   [],
#   ['Accettiamo', 'andando', 'fare']),
#  (['Grazie', 'evoluzione', 'prox', 'gabbia', '#rom'],
#   ['chiaro', 'inciampa'],
#   ['spero']),
#  (['Centinaia', 'terroristi', 'profughi'], [], ['avverte', 'arrivando']),
#  (['Borse', 'minaccia', 'mirino'], ['terroristica'], ['caute']),
#  (['Ventenne', 'morte'], ['nomade', 'minore'], ['fermato', 'denunciato']),
#  (['Giornata', 'rom', 'sinti', 'inclusione'],
#   ['internazionale', 'lontana'],
#   ['è']),
#  (['sgomberi', 'campi', 'rom', 'zingari', 'diritto', 'casa', 'via'],
#   [''],
#   ['annulla', 'hanno']),
#  (['Giornata', 'i#nfanzia', '#rom', 'baraccopoli'], [], ['discuterà']),
#  (['storia', 'guardia', 'immigrazione', '#storia'],
#   ['nazionale', '#la'],
#   ['contrastare']),
#  (['problemi', 'elezioni', 'merkel', 'terrorismo', 'pazzi'],
#   ['psichici'],
#   ['camuffa', '....fessi']),
#  (['campo', 'nomadi', 'via', 'casa', 'Giorno'], [], ['dotata']),
#  (['',
#    'mercoledì',
#    'prefetto',
#    'Sindaci',
#    'piano',
#    'distribuzione',
#    'profughi'],
#   [],
#   ['convocato', 'annunciar']),
#  (['campi', 'rom', 'gennaio', 'piano', 'Paese'], [], ['chiudere']),
#  (['bici', 'macchina', 'fisica', 'bici', 'macchina', 'rom'],
#   ['grande', 'ladri'],
#   ['caricare', 'accorti', 'sembravamo']),
#  (['immigrati'], [], ['', 'accolti', 'fare']),
#  (['Eredita', 'rom'],
#   ['masseria', 'disperato'],
#   ['occupata', 'Pensionato', 'distruggendo']),
#  (['famo', 'paragone', 'ab.su', 'profugo'],
#   ['mattè,se', 'cor', 'siriano'],
#   []),
#  (['Pil', 'immigrati', 'miliardi'], [], ['vale', 'pesa']),
#  (['Studentessa', 'scippo', 'condanna', 'rom', 'carcere'],
#   ['cinese'],
#   ['morta', 'patteggiano']),
#  (['Raggi', 'rom', 'roma', 'nord'],
#   [],
#   ['so', 'promesso', 'promesso', 'aprir', '...e', 'aprendi']),
#  (['società', 'multirazziale..', '#profughi', '#rom'], [], []),
#  (['bambini', 'scuola', 'rom', 'scuola'],
#   [],
#   ['vanno', 'integrano', 'insegno', 'avuto', 'fare']),
#  (['#dallavostraparte', 'rapinatori', '#rom', 'morte', 'domiciliari'],
#   ['seriali', 'cinese'],
#   ['provocato']),
#  (['bombe', 'attentato', 'terroristi'], [], ['', 'fatto']),
#  (['vicenda', 'nomadi', 'residenza', 'cancellazione...'],
#   [],
#   ['Continua', 'far', 'discutere']),
#  (['campo', 'parcheggio', 'ospedale', '#italia'], ['nomadi', '#bhive'], []),
#  (['torchio', 'rom', 'campo', 'nomadi'], ['cinese'], ['morta']),
#  (['rom', 'gabbia'], [], ['difende']),
#  (['stella', 'musica', '#rom'], [], ['morta', '#esmaredzepova']),
#  (['paesi', 'negozi', 'buttafuori', 'clienti', 'fan', 'pare'],
#   ['rom/ladri'],
#   ['Sapete', 'sono', 'controllano+tutelano']),
#  (['alleato', '', 'favore', '#austerità', 'amico'], ['nuovo'], []),
#  (['#campo', '#rom', 'portafogli', 'donne', 'trasfe...'],
#   [],
#   ['rubare', 'arrestate']),
#  (['profugo', 'bono', 'profugo', 'fatto', ',ma'],
#   ['bono,no', 'ricco', 'nera'],
#   ['lasciamo', 'stare']),
#  (['rom', 'comunità', 'vittima', 'pratiche', 'base'],
#   ['sola', 'istituzionali', 'etnica'],
#   ['pensate', 'realizzate']),
#  (['bar', 'sport', 'maxirata', 'finanziamento'],
#   [],
#   ['terrorizzati', 'portato']),
#  (['Articolo', '#nomadi', 'mezzo', 'nomadare...'],
#   ['razzista', 'populista', 'poveri'],
#   ['Accusati', 'cercavano']),
#  (['Fondamentalismo', 'religione', 'islamica.....'], ['islamico'], []),
#  (['stereotipi', 'migranti'], ['diffusi'], ['elenca']),
#  (['', 'stregua', 'terroristi'], [], ['trattati']),
#  (['vetri', 'campi', 'rom', 'ciglio', 'ferrovia', 'decoro'],
#   ['disegnati', 'spero'],
#   ['', 'decidano', 'dar', 'merita']),
#  (['polizia', 'fuoco', 'nomade'], ['latitante'], ['apre']),
#  (['Meglio', 'islamico...'], ['morto'], []),
#  (['insediamenti', 'nomadi', 'quartieri', 'uffici', 'questura'],
#   ['abusivi'],
#   ['#chilhavisto', 'degradati']),
# ...
#  (['problema',
#    'sicurezza',
#    'campo',
#    'nomadi',
#    'profughi',
#    'online',
#    'provincia'],
#   [],
#   ['Quotidiano']),
#  (['Ragazza', 'anni', 'nomadi'], [], ['stuprata']),
#  (['genitori', 'studentessa', 'campo', 'rom', 'polizia'],
#   ['cinese'],
#   ['dice', 'scippata', 'trovata', 'morta', 'entrare']),
#  (['migranti', 'rischio', 'salute', 'grazie'],
#   ['pubblica'],
#   ['rappresentano']),
#  (['ing', 'forza', 'gentiloni', 'dogi', 'errori', 'incidenti', 'rom'],
#   ['biban', 'italia', 'padovan', 'italiani', 'libera'],
#   ['Viva', 'sono', 'uscita']),
#  (['commissione', 'periferie', 'campo', 'rom', 'immondizia'], [], []),
#  (['ordinanza', 'camper', 'rom', 'Controlli'],
#   ['nuovo', 'sgombero'],
#   ['Prorogata']),
#  (['cena', 'amicizia', 'famiglia', '#rom', 'casa', 'anni', 'baracche'],
#   [],
#   ['incontrar']),
#  (['vittime', 'terroristi'], ['uccisi'], ['ATTENTATI']),
#  (['benvenuto', 'profughi', 'link'], [], ['festa', 'dare']),
#  (['avances', 'rom'], ['anziano'], ['rifiuta', 'rapina']),
#  (['voto', 'islamici', 'pari', 'rom'], [], ['', 'assicura']),
#  (['polizia', 'rom', 'camper', 'gente'],
#   ['arresta', 'ladri'],
#   ['sgombera', 'applaude']),
#  (['bello', 'democrazia', 'opinione', 'paesi'],
#   ['islamici'],
#   ['abituati', 'hai']),
#  (['blitz', 'scuola', 'campo', 'sequestri', 'denunce'],
#   ['nuovo', 'ex', '#napoli'],
#   ['sgomberato']),
#  (['intervento', 'problemi', 'via', 'questioni', 'rom'],
#   ['altre'],
#   ['Nuovo', 'mercatino']),
#  (['incassi', 'multe', 'pattuglie', 'rom'], ['asfalti', 'anti'], []),
#  (['rivendicazione', 'isis..al', 'musulmani', 'milione'],
#   ['quaeda', 'estremisti'],
#   ['...sono']),
#  (['leghisti', 'fascisti', 'uomo', 'rom', 'gabbiotto'], [], ['chiuso']),
#  (['Irruzione', 'casa', 'minacce', 'profughi'], ['disoccupato'], ['ha']),
#  (['pazzo', 'akbar'],
#   ['kossovaro,musulmano', 'allah'],
#   ['ordina', 'dire', 'tratta', 'grida', '#terror']),
#  (['tata', 'sicurezza', 'rom', 'fronte', 'auto'], [], ['esprime']),
#  (['messa', 'immigrati', 'struttura', 'di...'], ['ospiti'], []),
#  (['Accoglienza', '#profughi', 'sostegno', 'Croce'], ['Rossa'], []),
#  (['storia', 'chiusura', 'campi', 'rom', 'abitazioni'],
#   ['vera'],
#   ['', 'sembra', 'diano']),
#  (['agricoltura', 'grazie', 'giovani', 'stranieri'], ['lombarda'], ['cresce']),
#  (['lavoro', 'costo', 'caporali', 'immigrazione', 'broker', 'nome'],
#   ['basso', 'uguale'],
#   ['gestito', 'cambia', 'risultato']),
#  (['favola', 'migrante', 'calciatore'], [], []),
#  (['masseria', '#rom', 'bonifica'],
#   [],
#   ['Liberata', 'occupata', 'andar', 'devastato', 'paga']),
#  (['profughi', 'somalo', 'processo', 'rito'], ['immediato'], ['#Milano']),
#  (['proposta', 'assessore', 'casa', 'rom'], ['Danese', 'fruibili'], []),
#  (['stadio',
#    'blocco',
#    'olimpiadi',
#    'insediamenti',
#    'campi',
#    '#rom',
#    'incapacità'],
#   ['continui'],
#   []),
#  (['casino', 'rom', 'diritto'],
#   ['pari'],
#   ['difendo', 'fa', 'incita', 'bruciare', 'perde', 'considerato']),
#  (['via', 'seta', 'nomadi'], [], ['Internazionale', 'disegnata']),
#  (['rom', 'gabbia', 'dipendenti', 'polemica'],
#   ['chiuse'],
#   ['diventa', 'accende']),
#  (['italia', 'fesso', 'terrorista'], [], ['far', 'prendere']),
#  (['difensore', 'cristianità', 'islam'], ['imbecille', 'inadatto'], []),
#  (['fatto', 'crimini', 'guerra', 'propaganda'],
#   ['antyi'],
#   ['sarà', 'esistono']),
#  (['Controlli', 'campo', 'lavoro', 'Polizia', 'Stato'], ['nomadi'], []),
#  (['vittime', '#terrorismo', 'vittime', 'turisti', 'religione'],
#   ['stranieri', '#islamica'],
#   ['fare', 'ammazzato']),
#  (['', 'terroristi', 'affitti'], ['clandestini'], ['sa', 'dietro,a']),
#  (['fermata', 'disperati', 'cantiere', 'rifugio', '#rom'],
#   ['bloccato'],
#   ['metrò']),
#  (['euro', 'giorno', 'guardiania', 'campo', 'rom'], ['Mille'], ['']),
#  (['Minaccia', 'flessibilità', 'migranti', 'terremoto'], ['populista'], []),
#  (['peggio', 'onda', 'Punto', 'rom', 'fuoco', 'sua...'],
#   ['Politico'],
#   ['derubò', 'dà']),
#  (['indagini',
#    'terroristi',
#    'proselitismo',
#    'carcere',
#    'campo',
#    'applicazione',
#    'bis'],
#   ['monche'],
#   ['Uffa', 'fanno']),
#  (['controllo', 'droga', 'africani', 'rom', 'figli'], ['futuro'], ['Andiamo']),
#  (['straniero', '', 'ambito', 'operazione'],
#   ['misterioso'],
#   ['#riscopriamo', '', 'edito']),
#  (['Nomadi', 'fatto', 'carabinieri', 'rom', 'cacciavite'],
#   [],
#   ['colti', 'aggrediscono', 'tenta']),
#  (['incremento', 'reati', 'aumento', 'presenza', 'immigrati'], [], ['stato']),
#  (['immigrato', 'semplice', 'dipendente'],
#   ['italiano', 'ex', 'licenziato'],
#   ['richiedente']),
#  (['terrorista'], [], ['preoccupato', 'stava']),
#  (['campo', 'rom', 'via', 'appello', '#news'], ['sgombero'], ['Fermate']),
#  (['rom...', '#dallavostraparte'], ['filo'], ['far', 'mancare']),
#  (['cordoglio', 'morte', 'terra', 'amore', 'terrorismo'], [], ['passerà']),
#  (['opinione', 'rom', 'una...'], [], ['è', 'capito', 'chiuse']),
#  (['intervento', 'Guardia', 'stretta', 'immigrati'],
#   ['Nazionale'],
#   ['nega', 'chiederà']),
#  (['italiani', 'nomadi', 'termine', 'politicallycorrect', 'mondo'],
#   ['soliti'],
#   ['razzisti', 'benvisti']),
#  (['campo'], ['bici', 'nomadi'], ['pubblicato', 'trovate']),
#  (['via', 'camper', 'nomadi'], [], []),
#  (['camere', 'gas', '#rom', '#furbettidelcartellino', 'capire...'], [], []),
#  (['#terrorismo',
#    'venezia',
#    'appartamento',
#    'centro',
#    'preghiera',
#    'allentamenti'],
#   ['clandestino'],
#   ['preparavano', 'video']),
#  (['', 'terroristi', 'musulmani'], [], []),
#  (['trucchi', 'ladruncole', 'rom', 'fine'], ['infallibili', 'sociale'], []),
#  (['Malattie', 'diritto', 'studio', 'fine', 'famiglie', 'rom'],
#   ['negato'],
#   ['fatto']),
#  (['patto', 'flussi', 'migranti'], [], ['Firmato', 'Fermeremo']),
#  (['Insegnante', 'choc', 'migranti', 'profugo'],
#   [],
#   ['vivi', 'Dispiace', 'sentire']),
#  (['modernità', 'velo'], ['islamico'], ['amnantano', 'conoscere', 'mette']),
#  (['Giorno', 'rom', 'porrajmos', 'genocidio'], [], ['ricordano']),
#  (['rom', 'gabbia', 'supermercato', 'dipendente', 'Giornale'],
#   ['iscritto'],
#   ['messe']),
#  (['rom', 'casa', 'grazie', 'sindaco'], ['leghista'], ['tornano']),
#  (['terrorismo', 'paura', 'black', 'allerta', '#terrorismo', '#ma'],
#   ['allerta', 'bloc'],
#   ['scatta', 'fanno', '#scatta']),
#  (['west', 'poliziotti', 'trentina', '#nomadi', '#invasione'],
#   ['#repubblica'],
#   ['far', 'aggrediti', 'Votare', 'fermare']),
#  (['anno', 'case', 'rom', 'Contenti'],
#   ['romani'],
#   ['comincia', 'far', 'comincia', 'dare', 'votata', '']),
#  (['mld', 'rimesse'], ['terza'], []),
#  (['rifugio', 'terroristi', 'accoglienza', '#buonisti'], ['sicuro'], []),
#  (['legge', 'rom', 'italiani'],
#   ['frittata!La', 'giusto'],
#   ['rigiriamo', 'rispettare', '']),
#  (['commissaria', 'stop', 'immigrati'], ['comunale'], ['dice', 'basta']),
#  (['Festa', 'animali', 'margini', 'strada'],
#   ['islamica'],
#   ['sacrificati', 'Arrivano']),
#  (['#terrorismo', 'modo', 'inizio', 'anno...', '#rip'],
#   ['infame', 'spiace'],
#   ['trova', '#paceintutteleterre']),
#  (['rom', 'turisti', 'furto'],
#   ['colombiana', 'quotidiano'],
#   ['picchiata', 'avvertito']),
#  (['rom', 'sala', 'immigrazione'],
#   ['uniti'],
#   ['uniti', 'confermato', 'votato', 'capito']),
#  (['fatto', 'razzisti', 'rom', 'maledetti', 'parola'],
#   ['buonisti', 'baaastaaaa'],
#   ['fa', 'rider', 'inventato']),
#  (['italiani', '#rom'], ['italiani'], ['vivono']),
#  (['comunità'], ['principali', 'straniere'], []),
#  (['campo', 'rom', 'macchinista', 'treno...'], [], ['indagato']),
#  (['#dallavostraparte', 'politici', 'sinistra', 'immigrati'],
#   ['Inutile', 'ke'],
#   ['parlare', 'derubano']),
#  (['estero', 'parole', 'eh'],
#   ['straniere', 'italiane', 'tranquilli'],
#   ['crediamo', 'vivete', 'mischiate']),
#  (['attivisti'], ['sgombero'], ['arriva', 'fermiamo', '']),
#  (['Grazie'], ['migranti'], ['facendo', 'vedere', 'diventati']),
#  (['rom', 'metà', 'cittadinanza'], ['italiana'], ['sono']),
#  (['rom', 'offerta'], [], ['capito', 'successo', 'erano']),
#  (['ue', 'm.', 'italia', 'migranti'], ['lontani'], ['discrimina']),
#  (['', 'rom', 'suite', 'centro', 'caviale', 'champagne'], [], ['trasferiti']),
#  (['Uomo', 'amico', 'impero', 'centri', 'profughi'],
#   ['‘ndrangheta'],
#   ['creato']),
#  (['presepe'], ['musulmano'], ['incendia', 'fatto']),
#  (['studentessa', 'condanna', 'patteggiamento', 'rom'], ['cinese'], ['morta']),
#  (['Libertà', 'immigrata'], [], ['ditelo']),
#  (['#scuola', '#islam', '#migrazioni', 'radicalizzazioni'], ['violente'], []),
#  (['commedia', 'accordo', 'flessibilità', 'bilancio', 'cambio', 'migranti'],
#   ['ottiene'],
#   [',sono', 'tiene']),
#  (['autore', 'sparatoria', 'centro', '#20dicembre'],
#   ['morto', 'presunto', 'islamico'],
#   ['trovato']),
#  (['storia', 'patente', 'immigrati'],
#   ['laggente'],
#   ['gratis', 'fa', 'infuriare', '']),
#  (['pro', 'soni'],
#   ['c.sociali', 'antagonisti', 'clandestini'],
#   ['dichiarato', 'pro', 'pro', 'pro']),
#  (['nomi', 'fotografie', 'agenti', 'terrorista', 'iniziati...'],
#   [],
#   ['diffuso', 'aggrediti']),
#  (['nomadi', 'aree'], ['attrezzate'], []),
#  (['ricovero'], [], ['Saviano', 'ripartire', 'riempie']),
#  (['carcere', 'rom', 'ragazza'], ['cinese'], ['derubato', '']),
#  (['imbarbarimento', 'rom', ',schippano,ti', 'casa'],
#   [':rubano'],
#   ['avvenuto', 'concesso', 'entrano', 'arrestano']),
#  (['proposta', 'impiego', '#migranti', '#Stato'],
#   ['interessante'],
#   ['attiva', '#leiene']),
#  (['rapper', 'vita', 'profugo'], ['comoda'], ['canta', 'casca']),
#  (['rom', 'mirino', 'coop', 'politici'], [], ['']),
#  (['muro', 'soluzione', 'immigrants', 'overstayers', 'immigrants'],
#   ['illegal'],
#   ['guarda', 'spaccia']),
#  (['nomade', 'nellappartamento', '#di'],
#   ['incinta', 'svaligiato'],
#   ['#Milano', 'rischia', 'partorire']),
#  (['bilancio', 'rom', 'giorni', 'fotofinish'], [], []),
#  (['zona', 'immigrati'], ['franca', 'Liberi'], ['fare', 'vogliono']),
#  (['Reinserimento', 'solidarietà', 'colpa', 'politica'], ['nomadi'], []),
#  (['inizio', 'mondializzazione'], ['islamica'], []),
#  (['rom', 'gabbia'], ['simpatico'], []),
#  (['Cronaca', 'campo', 'borsoni', 'maratona'],
#   ['nomadi'],
#   ['Ritrovati', 'rubati']),
#  (['Ragazza', 'inquirenti', 'leader', 'rom', 'ragazzi'],
#   ['cinese'],
#   ['morta', 'Consegnate', 'rapinato']),
#  (['intervento', 'bisogno', '#immigrati'], ['Grande'], ['ha']),
#  (['Liste'], ['stranieri', 'retorica'], ['Speriamo', 'dice']),
#  (['#vigili', 'campi', 'straordinari'], ['#nomadi'], ['inchiesta']),
#  (['rom', 'delinquenti', 'posto'], ["piu'"], ['difende', 'voglio', 'andate']),
#  (['#LAltraFaenza', '#fiaccolata', 'protesta', '', 'fallimento', '#rom'],
#   [],
#   []),
#  (['immigrati', 'aziende', 'punti', 'dito', 'partite', 'immigrati'],
#   ['irregolari', ',alle', 'grandi'],
#   ['servono', '']),
#  (['bambini', '#rom', 'campo', 'pastore'], [], ['bastona']),
#  (['profughi', 'casa'], ['falsi'], ['mandiamo']),
#  (['cultura', 'rom', '#dallavostraparte'], [], []),
#  (['campo', 'rom', 'contraddizione'], [], ['farà']),
#  (['mai...', 'popolo', 'pro', 'rom'],
#   ['italiano', 'clandestini', 'iussoli'],
#   ['appoggiato', '', 'frega']),
#  (['vari', 'calciatori', 'veline', 'prenditori', 'umanità'],
#   [],
#   ['è', 'Billionaire', 'spettacolume', 'varia', 'fa']),
#  (['migranti',
#    'punti',
#    'controllo',
#    'confini',
#    'finanziamento',
#    'centri',
#    'accoglienza'],
#   ['salienti', 'libici'],
#   []),
#  (['Reinserimento', 'business', 'solidarietà', 'colpa', 'politica'],
#   ['nomadi'],
#   []),
#  (['west', 'poliziotti', 'trentina', 'nomadi', 'fermi'],
#   [],
#   ['far', 'aggrediti']),
#  (['#paolodeldebbio', '#ghettorom'], ['mito', '#camponomadi'], ['#roma']),
#  (['borseggiatore', 'campo', 'rom'],
#   ['cinese', 'morta', 'terzo'],
#   ['fermato']),
#  (['migranti', 'casa', '', '', 'accoglienti.'],
#   ['buoni', '...............prrrrrrrrrrrrrrr'],
#   ['sembrano']),
#  (['cita', 'unificazione', 'laboratorio', 'immigrazione'], ['attuale'], ['']),
#  (['anno', 'avvenimenti', 'terremoti', 'terrorismo,...'],
#   ['luttuosi'],
#   ['chiude', 'contraddistinto']),
#  (['Boldrini', 'Politica', 'terroristi', 'paladinba', 'Strategia'],
#   ['pericolosa', '90°'],
#   ['rafforza']),
#  (['ventenne', 'nomade', 'campo', 'via'], ['Cinese'], ['morta', 'fermato']),
#  (['vicenda', 'nomadi', 'residenza', 'cancellazione...'],
#   [],
#   ['Continua', 'far', 'discutere']),
#  (['banda', 'rom', 'pizzo', 'anni', 'ristoratore', 'colpi', 'mitra', 'via'],
#   ['esausto'],
#   ['chiedeva', 'uccide']),
#  (['#ultimenotizie', 'notizie', 'appalti', 'campi', 'processo', 'funzionari'],
#   ['nomadi'],
#   []),
#  (['Campo', 'persone', 'baracche'], ['nomadi', 'abusivo'], ['vivono']),
#  (['soccorso', 'campo'], ['pronto', 'cellulare', 'nomadi'], ['ritrovato']),
#  (['orrore', 'somalo', 'omicidi', 'stupri', '#campoprofughi'],
#   ['simile', 'colpevole'],
#   ['visto']),
#  (['paladina', 'piffero', 'rom', 'manco', '#biancoenero'],
#   [],
#   ['Scusate', 'sta', 'permesso', 'scende']),
#  (['vicinanze', 'uomo', 'rom', 'zona'],
#   ['mendicante'],
#   ['accaduto', 'frequenta']),
#  (["po'", 'soldi', 'rom'], [], ['', 'fanno']),
#  (['strada', 'mano', 'stranieri', 'Giornale'], [], ['aggredito']),
#  (['rt', 'Sindaci', 'Provincia', 'tema'], ['comuni_anci'], []),
#  (['atto', 'terrorismo'], ['necessario'], ['definito']),
#  (['problema', 'immigrati,vero'], [], ['commentare']),
#  (['fisionomia', 'immigrazione', 'comunità', 'anni'],
#   ['islamica'],
#   ['cambiata']),
#  (['scandalo', 'rischio', 'progetti', 'casa-accoglienza', 'profughi'],
#   ['transessuali'],
#   []),
#  (['Paolini', '#profughi', 'provincia', 'Presidio', 'ore'], ['Altri'], []),
#  (['cittadino', 'rom', 'fuga...'], ['pronto'], ['investiti', 'fermato']),
#  (['tavola', '', 'bambini', 'dimora', 'rom', 'famiglie', 'paese'],
#   ['anziani'],
#   []),
#  (['Avramopoulos', 'piano', 'migranti'], ['Ottimo'], []),
#  (['#Istituzioni', 'bambini', 'ragazzi', '#rom', 'giro', 'elemosine'],
#   [],
#   ['permettono', 'stiano', 'rubare', 'chiedere']),
#  (['musulmano'], [], ['ripeterà', 'dipende']),
#  (['migranti'], [], ['annegati']),
#  (['attentati', 'matrice'], ['islamica'], ['avvenuti', 'Basta', 'informar']),
#  (['Spostamento', 'campo', 'mistero', 'Comune'], ['nomadi'], ['spendere']),
#  (['Podisti', 'rom', 'chiavi', 'casa', 'portafogli', 'telefonini'],
#   [],
#   ['derubati', 'sfidano', 'recuperare']),
#  (['rom', 'monnezza'], [], ['vada', 'esasperati']),
#  (['campi', 'rom', 'nomadi', 'abitazioni', 'aiuti'],
#   ['altri'],
#   ['fornire', 'chiedono', 'diminuire']),
#  (['Donne',
#    'mamma',
#    'rischio',
#    'accesso',
#    'terapie',
#    'diagnosi',
#    'Difficoltà',
#    'linguisti...'],
#   ['straniere'],
#   ['Mancato']),
#  (['Giornale', 'rom', 'turista', 'volte', 'anni', 'carabinieri'],
#   [],
#   ['arrestata']),
#  (['Bomba', 'metro', 'terrorismo'], [], ['escludo']),
#  (['Accampamento', 'rom', 'denunce', 'allaccio', 'rete'],
#   ['improvvisato', 'abusivo', 'elettrica'],
#   []),
#  ([], [], []),
#  (['legge', 'terra', 'stranieri'], ['possibile'], ['Domandiamo', 'venga']),
#  (['inseguimento', 'nomadi', 'manette'], [], ['Arrestati', 'riconoscete']),
#  (['cultura', 'rom', 'pazza', 'nome', ''],
#   ['famosa', 'scatenata'],
#   ['apprezzata']),
#  (['#ultimenotizie', 'notizie', 'caos', 'dimissioni', 'caccia', 'terrorista'],
#   [],
#   []),
#  (['freno', 'esodo', 'insegnanti', 'nord', 'simpatia', 'rom'],
#   ['vero', 'meridionali', 'certa'],
#   ['porre', 'nutre']),
#  (['campo', 'rom', 'nomade', 'vigile'], [], ['tentato', 'investire']),
#  (['governatore', 'hotel', 'migranti', 'povero'],
#   ['altro', 'italiano'],
#   ['cerca', 'uccide', '']),
#  (['scippatori', 'campo', 'rom'], ['cinese'], ['trovata', 'morta']),
#  (['rom', 'anziani', 'accordo'], ['italiani'], ['credo', 'stati', 'sareste']),
#  (['righe', 'accordo', 'turca', 'tenerveli', '#immigrazione'],
#   [''],
#   ['Par', 'capire', 'vorrebbe', 'volete']),
#  (['gente', 'qualità', 'vita', 'schifo', 'sl', 'feccia', 'paese'],
#   ['clandestini', 'qst'],
#   ['va', 'fa']),
#  (['ville', 'nomadi', 'giorno', 'rom'],
#   ['abusive'],
#   ['#Milano', 'costruisco', 'demoliscono', 'costruiscono', 'succede']),
#  (['palmeti', 'bananalandia', 'campi', 'rom', 'nomi', 'vie', 'arabo'],
#   [],
#   ['', 'fare', 'andate']),
#  (['governo', 'terremotati', 'esseri'], ['umani'], []),
#  (['rom', 'Censimento', 'lavoro', '#roma'], ['concluso'], ['chiudere']),
#  (['#rom', '#sinti', 'storia', 'città', 'lotta'], [], ['cancellati']),
#  ...]

# %%
nouns_list = [word[0] for word in categorized_words]
adjectives_list = [word[1] for word in categorized_words]
verbs_list = [word[2] for word in categorized_words]

nouns_vector = np.array([word[0] for word in categorized_words], dtype=object)
adjectives_vector = np.array([word[1]
                             for word in categorized_words], dtype=object)
verbs_vector = np.array([word[2] for word in categorized_words], dtype=object)

# %%
def calculate_embeddings(words_list, dictionary, embedding_size=128):
    if not words_list:
        return np.zeros(embedding_size)
    embeddings = [dictionary[word]
                  for word in words_list if word in dictionary]
    if not embeddings:
        return np.zeros(embedding_size)
    return np.mean(embeddings, axis=0)


embeddings_train = []
for words_set in categorized_words[:6839]:
    nouns_embedding = calculate_embeddings(words_set[0], dizionario)
    adjectives_embedding = calculate_embeddings(words_set[1], dizionario)
    verbs_embedding = calculate_embeddings(words_set[2], dizionario)
    combined_embedding = np.concatenate(
        [nouns_embedding, adjectives_embedding, verbs_embedding])
    embeddings_train.append(combined_embedding)

embeddings_test = []
for words_set in categorized_words[6839:]:
    nouns_embedding = calculate_embeddings(words_set[0], dizionario)
    adjectives_embedding = calculate_embeddings(words_set[1], dizionario)
    verbs_embedding = calculate_embeddings(words_set[2], dizionario)
    combined_embedding = np.concatenate(
        [nouns_embedding, adjectives_embedding, verbs_embedding])
    embeddings_test.append(combined_embedding)

print(len(embeddings_test[0]))
# Out:
# 384

# %%
clf = LinearSVC()
clf.fit(embeddings_train, y_train_hs)
y_pred = clf.predict(embeddings_test)

print(classification_report(y_test_hs, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.91      0.80       319
#            1       0.68      0.33      0.45       181
#
#     accuracy                           0.70       500
#    macro avg       0.69      0.62      0.62       500
# weighted avg       0.70      0.70      0.67       500

# %%
scores = cross_val_score(clf, embeddings_test, y_test_hs, cv=5)
print(scores)
print('media:', np.mean(scores))
# Out:
# [0.73 0.69 0.72 0.65 0.73]
# media: 0.704

# %% [markdown]
# # Word Embeddings (Twitter)

# %% [markdown]
# ### Embeddings singolo (128 elementi)

# %%
conn = sqlite3.connect("embeddings/twitter128.sqlite")
c = conn.cursor()

dizionario = {}
# Eseguo la query per estrarre le parole e i relativi embeddings
for row in c.execute("SELECT * from store"):
    if row[0] != "\t":
        dizionario[row[0]] = row[1:129]

# %%
len(dizionario)
# Out:
# 1188949

# %%
def conllu_sentences_to_strings(sentences):
    return [' '.join([token["form"] for token in sentence]) for sentence in sentences]


sentence_strings = conllu_sentences_to_strings(sentences)
testo_addestramento = pd.Series(sentence_strings)

# Calcolo degli embedding delle frasi come media degli embedding delle parole (ogni documento è rappresentato da un vettore di 128 elementi)
embeddings_train = []
for text in testo_addestramento[:6839]:
    words = text.split()
    text_embedding = np.mean([dizionario[word]
                             for word in words if word in dizionario], axis=0)
    embeddings_train.append(text_embedding)

embeddings_test = []
for text in testo_addestramento[6839:]:
    words = text.split()
    text_embedding = np.mean([dizionario[word]
                             for word in words if word in dizionario], axis=0)
    embeddings_test.append(text_embedding)

train_size = 6839
clf = LinearSVC()
clf.fit(embeddings_train, y_train_hs)
y_pred = clf.predict(embeddings_test)

print(classification_report(y_test_hs, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.68      0.99      0.81       319
#            1       0.90      0.20      0.33       181
#
#     accuracy                           0.70       500
#    macro avg       0.79      0.59      0.57       500
# weighted avg       0.76      0.70      0.63       500

# %%
scores = cross_val_score(clf, embeddings_test, y_test_hs, cv=5)
print(scores)
print('media:', np.mean(scores))
# Out:
# [0.87 0.8  0.82 0.67 0.8 ]
# media: 0.792

# %% [markdown]
# ### 3 Embeddings congiunti usando aggettivi, sostantivi e verbi

# %%
def conllu_sentences_to_categorized_words(sentences):
    categorized_words = []
    for sentence in sentences:
        nouns = [token["form"]
                 for token in sentence if token["upos"] == "NOUN"]
        adjectives = [token["form"]
                      for token in sentence if token["upos"] == "ADJ"]
        verbs = [token["form"]
                 for token in sentence if token["upos"] == "VERB"]
        categorized_words.append((nouns, adjectives, verbs))
    return categorized_words


categorized_words = conllu_sentences_to_categorized_words(sentences)
categorized_words
# Out:
# [(['terrorismo', 'stato', 'soggezione', 'persone', 'innocue'],
#   [],
#   ['mettere', 'render']),
#  (['campi', '#rom', 'ok'], [], ['', 'guadagnato']),
#  (['buche', 'campi', 'rom'], [], ['dimenticataMazzette']),
#  (['migranti', 'terra'], ['israeliti'], ['arrivarono', 'fecero']),
#  (['divertimento', 'giorno', 'patrioti', 'rom', 'spesa'],
#   ['italiani', 'multinazionale', 'tedesca'],
#   ['Trovare', 'inneggiano', 'facendo']),
#  (['benzina', 'nomadi', 'figli', 'scuola', 'giunta'], [], ['paga', 'portano']),
#  (['islam', 'cristianesimo', 'c', 'ignorante'], ['...a'], ['sorbire']),
#  (['grazie', 'stavo', 'campi', 'rom'],
#   ['giusto'],
#   ['', 'caricando', 'messo', 'avallava', 'finanziare']),
#  (['italiani', 'strada'],
#   ['innocenti'],
#   ['smettetela', 'dire', 'trattati', 'uccidevano']),
#  (['Minorenne', 'rom', 'furto', 'appartamento'], [], ['arrestato']),
#  (['Studentessa', 'nomade', '20anni', 'nomade', 'campo'],
#   ['cinese', 'vicino', 'nomade'],
#   ['morta', 'fermato', 'denunciato']),
#  (['Ddl', 'velo', 'apologia', 'reato', 'accordo'],
#   ['islamico', 'diventino'],
#   []),
#  (['campo', 'rom', 'arresti', 'ombra', 'racket'], [], ['rapina']),
#  (['pazza', 'cosa', 'musulmani', 'gay.quelli', 'colore'],
#   ['parla#Trump'],
#   ['Rischiando', 'presa', 'sa']),
#  (['Povertà', 'esclusione', 'istruzione', 'minori', 'rom', 'vita', 'nascita'],
#   ['scarsa'],
#   ['hanno', 'segnata']),
#  (['grazie', 'collegamento', 'campi', '#rom', '#mediaset', 'calo', '#furti'],
#   ['#tv', 'esponenziale'],
#   []),
#  (['zucchero', 'amico', 'rom', 'problemi'], ['negro'], ['visto', 'fate']),
#  (['#profughi', 'malvedenti', 'maldicenti', 'donne', 'bambini'],
#   ['....e', 'malpensanti'],
#   ['sono', 'parlano']),
#  (['caso', 'città', '#sanpietroburgo', 'civiltà', 'fastidio'],
#   ['occidentale', 'terroristica'],
#   ['colpita']),
#  (['euro', 'rom', 'spesa'], [], ['regalati', 'fare']),
#  (['Commissione',
#    'visti',
#    'criteri',
#    'stallo',
#    'legge',
#    'terrorismo',
#    'rimpatri',
#    'aprile'],
#   ['anti'],
#   ['mancano', 'Accordo']),
#  (['parole', 'immigrazionisti', 'mondo'],
#   ['inutili', 'politici'],
#   ['eliminare']),
#  (['clienti', 'avvocato'],
#   ['stranieri'],
#   ['#Milano', 'raggirava', 'truffava', 'arrestato']),
#  (['INTERVISTA', 'memorandum'], ['Immorale', 'migranti'], ['siglato']),
#  (['#terroristifiloccidentali', 'vita'], [], ['#AleppoLibera', 'torna']),
#  (['risultato', 'circolazione', 'paesi', 'groppone'],
#   ['libera', ':nomadi', 'altri'],
#   ['sopporta']),
#  (['Inchiesta', 'torino', 'tesoro', 'regina', 'rom'], [], ['Trovato']),
#  (['favore', 'immigrati', 'marcia'],
#   ['altri', 'europei'],
#   ['visto', 'fatto', 'successo']),
#  (['giorni', 'amore', 'forza.....'], [], ['', 'nomadi,sono', 'andare']),
#  (['territorio', 'profughi'], ['ITALIANIIII'], []),
#  (['polizia', 'rom', 'aprile', 'novembre', 'Operazione', 'Questura'],
#   [],
#   ['allontana']),
#  (['oro', 'gioielli', 'abitazione', 'Centro', 'rom', 'minorenne', 'articolo'],
#   ['storico'],
#   ['Rubano', 'denunciate', 'leggi']),
#  (['guerra', 'terroristi'], [], ['finirà', 'elimineremo']),
#  (['', 'occhio', 'furbacchioni', 'profughi', 'protezione'],
#   [],
#   ['trasformano', 'ottengono']),
#  (['rapinatore'], ['#nomade', '#latitante'], ['arrestato']),
#  (['città', 'campo', 'rom', 'dialogo'], ['posticipata'], ['tenta']),
#  (['', 'aggiungo', 'rom', 'parole'],
#   ['clandestini', 'iussoli', 'stranieri', 'criminali'],
#   ['fatto']),
#  (['bene.Questi', 'posti', 'ns.giovani', 'feccia'],
#   ['stranieri'],
#   ['fatto', 'occupato', 'far', 'giocare', ',da', 'vengono']),
#  (['nomadi', 'idea', 'incredibile.'],
#   ['..ci'],
#   ['Dici', 'rassegnano', 'arrivata']),
#  (['campi', 'rom', 'gennaio', 'piano'], [], ['chiudere']),
#  (['#ultimenotizie',
#    '#news',
#    '#notizie',
#    'donna',
#    'campo',
#    'rom',
#    'via',
#    'studentessa'],
#   ['trovata', 'cinese'],
#   ['morta']),
#  (['', 'testa', 'rom', 'un...'], [], []),
#  (['pecora', 'pallone', 'bambino', 'rom', 'pastore'],
#   [],
#   ['colpisce', 'accecato']),
#  (['cambio', 'impegno', 'tasse', 'figli', 'scuola'],
#   ['nomadi'],
#   ['prefabbricati', 'pagare', 'mandare']),
#  (['rom', 'governo'],
#   ['delinquenti', 'clandestini'],
#   ['votare', 'libereremmo', 'protetti']),
#  (['autista', 'terrorista', 'killer', 'fuga'],
#   ['polacco'],
#   ['Attentato', 'cercato', 'fermare']),
#  (['mirino', 'nomade', 'monetine', 'acqua'], ['sorpreso'], ['rubare']),
#  (['Allarme', 'terrorismo', 'fantasmi', 'identificazione'], ['vera'], ['']),
#  (['Fatto', '#notizie', '#attentato'],
#   ['terroristico', 'metropolitana'],
#   ['sventato', 'Arrestato']),
#  (['stragi', 'violenza', 'forma', 'posto'],
#   ['terroristiche'],
#   ['condanniamo']),
#  (['terroristi'], [], []),
#  (['passato', 'Verità', '#democrazie'],
#   ['recente', 'occidentali'],
#   ['riscritto']),
#  (['invocazione', 'islamica', 'corda', 'non...'],
#   [],
#   ['conclusa', '”Afferratevi']),
#  (['civili', 'città', 'terroristi', 'scontri'],
#   ['violenti'],
#   ['avanzano', '#siriano']),
#  (['Campi', '#rom', 'bocciatura', '#roma'], ['severa'], ['richiama']),
#  (['Studentessa', 'rom'],
#   ['cinese', 'altri'],
#   ['morta', 'catturato', 'denunciati']),
#  (['storia', 'campo', 'rom', 'razzismo'], [], ['Bisogna', 'far', 'valere']),
#  (['talebani', 'mano', 'mitra', 'ragazzini', 'terroristi'],
#   [],
#   ['mettono', 'far']),
#  (['Intervista', 'Grazie'], ['liberale', 'musulmano'], []),
#  (['#ultimenotizie', '#news', '#notizie', 'rom', 'morte', 'studentessa'],
#   ['cinese'],
#   ['Fermato']),
#  (['nomade', 'fuga', 'furto', 'pm', 'risarcimento', 'milione', 'euro'],
#   [],
#   ['spara', 'chiede']),
#  (['stupro', 'campo', 'rom', 'pm', 'insediamento', '#news'],
#   ['#ansa'],
#   ['chiuso']),
#  (['garante', 'centro', 'minori', 'minacce', 'morte'],
#   ['stranieri'],
#   ['sequestrata']),
#  (['legame', 'wedding', 'matrimoni', 'italiani', 'dato', 'fatto'],
#   ['stretto', 'stranieri'],
#   []),
#  (['Repubblica', 'allarme', 'terrorismo', 'treni', 'bus', '#palermo'],
#   [],
#   ['bloccati']),
#  (['#profughi', 'minore', 'norme', 'immigrazione', 'optional'],
#   ['poveri', 'vero'],
#   ['accompagnato', 'rispettare']),
#  (['#Napoli', 'giorno', 'apertura', 'campo', 'rom', 'fascisti', 'ronde'],
#   ['nuovo', 'comunale'],
#   ['ricominciato', 'fare']),
#  (['migranti', 'posto'], [], ['hanno', 'pagano']),
#  (['Gentiloni',
#    'parte',
#    'islamici',
#    'terrorismo',
#    'vittime',
#    'silenzio',
#    'attentati'],
#   ['maggior'],
#   ['rifiuta']),
#  (['Lavori', '#rom'], [], []),
#  (['vaccinazioni', 'morbillo', 'vaiolo', 'poliomielite', 'rom'],
#   [],
#   ['combattuto', 'parlando']),
#  (['leggi', 'tutto...'], ['nomadi'], ['accampati']),
#  (['alleanza', 'unione', 'intenti', 'italia', 'islam', 'speranza'],
#   [],
#   ['serve', 'salvare']),
#  (['immigrati', 'rom', 'fondo'], ['nuovo'], ['', 'scrivete']),
#  (['superamento', 'campi', 'rom'], [], ['via', '']),
#  (['binari', 'ferrovia', 'rom'], [], ['Vivevano', 'sgomberati']),
#  (['CdT', 'accordare', 'di...'],
#   ['altri', 'stranieri'],
#   ['distanzia', 'permessi']),
#  (['corriere', '#rom', 'frase', 'benpensanti'],
#   ['stessa'],
#   ['scritto', 'sbraneranno']),
#  (['Inclusione', 'rom', 'scetticismo', 'case', 'i...'],
#   [],
#   ['regna', '#roma']),
#  (['parte', 'storia.', 'Ds,sky,giornali', 'raccordo', 'penne', 'rom.'],
#   ['altra'],
#   ['facendo', 'snobbare']),
#  (['ciclisti', 'nomadi', 'baraccati', 'zona'],
#   [],
#   ['', 'passeranno', 'vivono']),
#  (['amici', 'amici', 'pagina'], ['Benvenuti', 'stranieri'], ['seguono']),
#  (['crocerossa', 'attività', 'inclusione', 'ragazzi', 'ospiti'], [], []),
#  (['violenza', 'danni', 'auto', 'profughi', 'rom', 'assicurazione..'],
#   ['simbolica', 'bruciata....i'],
#   ['fare', 'hanno']),
#  (['enne', 'patente', 'panico', 'inseguimento', 'incidenti', 'feriti'],
#   [],
#   ['semina']),
#  (['banda', 'topi', 'auto', 'rom'], [], ['presa', 'arrestati']),
#  (['Censimento', 'superamento', 'campi', '', '#rom'], [], ['coinvolgere']),
#  (['tesoro', 'milioni', 'famiglie', 'rom...', '#news'], [], ['sequestrato']),
#  (['modo', 'nomadi', 'ma.', 'fatto'], ['gravissimo'], ['condivido', 'vivere']),
#  (['tw',
#    'alimento',
#    'odio',
#    'sinti',
#    'rom',
#    'grazie',
#    '#hatespeech',
#    '#violenza'],
#   ['#razzismo', '#odio'],
#   ['chiediamo', 'eliminar']),
#  (['stranieri', 'idea'], ['ottima'], ['sfruttare', '']),
#  (['#dimartedì', 'ragione', 'rom', 'salute'],
#   [],
#   ['ha', 'basta', 'fare', 'pesare', 'vedere']),
#  (['giro', 'mazzette', 'appalti', 'campi', 'rom', 'a...'],
#   [],
#   ['pilotare', '']),
#  (['ok', 'figli', 'garantito', 'rom'],
#   [],
#   ['', 'fare', 'fai', 'concepisci', 'mandi', 'elemosinare']),
#  (['fenomeno', 'migranti', 'paesi'], [], ['Paragonare', 'trasportati']),
#  (['#immigrati', 'diritto', '#italiani', 'errore'],
#   ['#clandestini'],
#   ['#dallavostraparte', 'hanno', 'spiegate']),
#  (['Inclusione', 'rom', 'scetticismo', 'case', 'italiani'], [], ['regna']),
#  (['diversità', 'pd', 'invasoone', 'immigrati'],
#   [],
#   ['è', 'firmato', 'autirizzare']),
#  (['neurone', 'rom'], ['clandestini', 'iussoli'], ['dotato', 'sa']),
#  (['controlli', '#polizia', 'campo'], ['nomadi'], []),
#  (['Senadid', 'carcere', 'aggravato', 'resistenza', 'pubblico'],
#   ['nomade', 'liberato', 'furto', 'ufficiale'],
#   ['accusadi']),
#  (['abilità',
#    'amici',
#    'jihādisti',
#    'vittime',
#    'terrorismo',
#    'testimonial',
#    'amore'],
#   ['islamico'],
#   ['consiste', 'trasformare']),
#  (['base', 'terrorismo.', 'realtà'], ['sicura'], ['', 'usata', '...sembra']),
#  (['sapienza', 'situazione', 'rom', 'gente'],
#   [],
#   ['fai', 'tor', 'arrabbiati', 'è', 'fa']),
#  (['Bici', 'ciclisti', 'campo'], ['nomadi'], ['rubate', 'trovate']),
#  (['fondo', 'po', 'po'], ['nomadi', 'stranieri'], ['pensando']),
#  (['vita', 'campi', 'profughi'], ['ita', 'insostenibile'], []),
#  (['fine', 'fuggitivo', 'revisione'], [], ['', 'fare', 'terrorizzato']),
#  (['reddito', 'cittadinanza', 'più', 'immigrati', 'rom', 'coperture'],
#   [],
#   ['costa']),
#  (['aumento', 'povertà', 'aumento', 'immigrati'], ['etc.etc'], ['']),
#  (['importanza', 'momenti', 'attentati', 'immigrazione'],
#   ['difficili', 'tragedia'],
#   ['ricorda']),
#  (['via', 'incontro', '…le', 'proposte', 'realtà'],
#   ['politiche', 'europee', 'locali'],
#   []),
#  (['#Ok', 'decreto', 'novità', 'testo', 'via'], ['libera', 'definitivo'], []),
#  (['nomadi', 'gabbiotto', 'addetti'], [], ['rinchiudono', 'denunciati']),
#  (['piano', 'migranti', 'blocco'], ['navale'], ['bloccare']),
#  (['vertici',
#    'accordi',
#    'ambiente',
#    'parigi',
#    '.quelli',
#    'roma',
#    'migranti',
#    'vienna'],
#   ['internazionali'],
#   ['parate', 'vanificati']),
#  (['Ministro', 'Esteri'], [], ['collaborare']),
#  (['vittime', 'ebree', 'musulmane', 'parte', 'umanità'],
#   ['uguali', 'stessa'],
#   []),
#  (['dito', 'fede', 'caccia', 'rom'], [], ['spezzano', 'rubar']),
#  (['polizia', 'rom', 'camper', 'gente'],
#   ['arresta', 'ladri'],
#   ['sgombera', 'applaude']),
#  (['go', 'pray', 'church', 'bisogno', '#Cristi'],
#   ['go', 'd'],
#   ['Fidanzato', 'dice', 'significa', 'ha']),
#  (['errore', 'migranti'],
#   ['catastrofico', 'grande'],
#   ['commesso', 'scegliendo', 'accogliere', 'ho']),
#  (['studenti', 'scuole', 'battenti', 'docenti'],
#   ['stranieri'],
#   ['chiuderebbero', 'perderebbero']),
#  (['reportage', 'traffico', 'migranti'], [], ['fatto', 'descrive']),
#  (['Via', 'campo', 'censimento'], [], ['maxirissa', 'nomadi']),
#  (['', 'disordine', 'rom', 'terra...', '#pdioti'],
#   [],
#   ['crea', 'frugano', 'lasciano', 'fotografato']),
#  (['giunta', 'euro', 'nomadi', 'scuola'], [], ['trasportare']),
#  (['paese', '#invasione'], [], []),
#  (['ragazzi', 'gente', 'paura', '#migranti'],
#   ['tali'],
#   ['è', 'muore', 'aiutar', 'fa', 'odia']),
#  (['news', 'Dicembre', 'terrorismi'], ['PTV'], ['colpiscono', '']),
#  (['allerta', 'terrorismo', 'rischio', 'Concertone'], ['massima'], []),
#  (['80enne', 'casa', 'botte', 'rapina', 'ascensore', 'rom'],
#   [],
#   ['Seguono', 'arrestati']),
#  (['terroristi', 'base', 'pace'],
#   ['logistica'],
#   ['', 'hanno', 'pianificare', 'copre']),
#  (['politica', 'famiglia', 'culi', 'vita'],
#   ['filo', 'musulmana', 'neri', 'bella'],
#   ['portato', 'fare']),
#  (['', 'rom', 'cazzate'],
#   ['varie'],
#   ['intervenuto', 'continua', 'occupar', 'pare']),
#  (['invasione', 'illuso', 'lavori', 'gratis'],
#   ['grandi'],
#   ['pagare', 'fare', 'bloccano']),
#  (['nomadi', 'agenti', 'Polizia', 'possesso', 'di...'],
#   ['minorenni'],
#   ['denunciate']),
#  (['inchiesta', 'campi', 'rom', 'pressi', 'università'],
#   ['importanti', 'connessi'],
#   ['perdetevi']),
#  (['ladri', 'rame', 'deposito', 'Ferrovie', 'Stato', 'banda', 'nomadi'],
#   [],
#   ['presa']),
#  (['bici', 'campo'], ['nomadi'], ['#Milano', 'Ritrovate']),
#  (['affanculo', 'terrorista', 'partito', 'momento', 'valigie'],
#   [],
#   ['va', 'perso', 'fare']),
#  (['legalità', 'illegalità', 'sistema', 'diffusione', 'peste'],
#   [],
#   ['Parliamo', 'porta']),
#  (['appello', 'chiesa', 'Azione', 'lobby', 'immigrazione'],
#   ['politica'],
#   ['Vaticano', 'far', 'cambiare']),
#  (['segreto', 'terrorismo', 'religione', 'provenienza', 'ideologia'],
#   [],
#   ['approfitto', 'svelare', 'ha', 'ha', 'ha']),
#  (['straniera.', 'italia'], [], ['', 'credo', 'stai', 'parlando']),
#  (['nomade', 'posto', 'elemosina', 'asilo', 'coop'],
#   ['utente'],
#   ['subappalta', 'richiedente']),
#  (['Signore', 'preghiere', 'morti', 'feriti', 'attacco'],
#   ['terribile', 'terroristico'],
#   ['#stoccolma']),
#  (['Video', 'rom', 'gabbiotto', 'boomerang'], ['ultima'], []),
#  (['nomadi', '#news'],
#   ['cinese', '#ansa'],
#   ['morta', 'condannati', 'derubarono']),
#  (['islamici', 'razzisti'], [], ['dire', 'temiamo', 'sennò']),
#  (['sti', 'pizza'],
#   ['stranieri'],
#   ['scusa', 'tacere', 'pensavo', 'sapere', 'fare']),
#  (['battesimo', 'bimbo', 'rom', 'famiglie'], [], ['sono']),
#  (['..peggio', 'mafia...si', 'criminali', 'rom'],
#   ['sempre..associazioni', 'immigrati'],
#   ['dico', 'arricchiscono']),
#  (['sera', 'puntata', 'video', 'donne', 'rom'],
#   [],
#   ['capito', 'parlerete', 'fate']),
#  (['migranti', 'sostengo', 'sindaco'], [], ['Magliano', 'arrivano']),
#  (['Strage', 'ufficiali', 'omicidio'], ['militare', 'colposo'], ['indagati']),
#  (['tangenti', 'campi', '#rom', 'funzionari', 'processo'], [], ['rischiano']),
#  (['migranti', 'giorno'], ['#clandestini'], ['soccorsi', 'Chiamate']),
#  (['rom', 'resto'], ['approvo', 'ke'], ['dice', 'dice', 'apprezzerà']),
#  (['Mortacci', 'coop', '#migranti'], ['vostri'], ['accorgono', 'lucrano']),
#  (['esercizio', 'immigrati', 'malattie', 'inferno'],
#   ['.....si'],
#   ['pensa', 'fatto', 'portano', 'scatenato']),
#  (['Operazione', 'Polizia', 'quartiere', 'rom', 'grammi', 'cocaina'],
#   [],
#   ['sequestrati']),
#  (['solco', 'buono', 'bar', 'sud', 'mafia', 'rom', 'casa'],
#   ['gentista'],
#   ['fatto', 'hanno', 'entrano']),
#  (['dubbio', '#rom'], ['#zingari'], ['era']),
#  (['comunità', 'rom'], [], ['dice', 'discriminate']),
#  (['assalto', 'metro'], [], []),
#  (['scuola', 'borseggio', 'metro', 'nomadi'], [], ['arrestate']),
#  (['legge', 'riconoscimento', 'cittadinanza', 'bambini'],
#   ['stranieri'],
#   ['nati', 'aspettare']),
#  (['minorenne', 'rom', 'furto'], [], ['Torre', 'arrestato']),
#  (['barbarie', 'imposizione', 'violenza', 'riconversioni', 'odi'],
#   ['islamiche', 'razziali'],
#   ['rischiano', 'fomentare']),
#  (['casa', 'gola', 'consigliere', 'rom'], ['ex'], ['ferito', 'arrestata']),
#  (['incendio', 'campo', 'colonna', 'fumo', 'problemi', 'traffico'],
#   ['nomadi', 'alta'],
#   ['scoppia']),
#  (['Provvedimento',
#    'immigrazione',
#    'difesa',
#    'identità',
#    'tradizione',
#    'governo'],
#   ['nuovi'],
#   ['aspettiamo', 'vediamo', 'dice']),
#  (['#rom', 'classe', 'genitori', 'problema', 'discriminazione', 'tutela'],
#   ['preoccupati'],
#   []),
#  (['Gentiloni', 'conti', '#notizie'], ['rigida', 'flessibile'], []),
#  (['designer', 'ladre', 'rom', 'colpo', '#designer'],
#   ['incinte'],
#   ['#Milano', 'circondato', 'sventato']),
#  (['sedia', 'madre'], ['spacca'], ['immigrato', 'arrestato']),
#  (['tragedia', 'migranti', 'grazie'],
#   ['bella', 'soli'],
#   ['lascia', 'costringendo', 'indebitar', 'salvar', 'assister']),
#  (['masochisti', 'giornalisti', 'italiani', 'fama...'],
#   ['soliti', 'stranieri'],
#   ['precisiamo', 'ridevano']),
#  (['Operazione', 'terrorismo'], ['black'], []),
#  (['Salvini', 'rom', 'ruspe'], [], ['fare']),
#  (['migranti', 'salvataggio', 'Giornale'], ['piccolo'], ['nato']),
#  (['campo', 'rom'], ['sgombero'], []),
#  (['giro', 'vite', 'carabinieri', 'procura', 'nomadi', 'piemontesi...'],
#   ['Stretto', 'sinti'],
#   []),
#  (['Guerra', 'terrorismo', 'religione', 'fondamentalisti', 'Guerra'],
#   [],
#   ['centrano', 'abbiamo']),
#  (['aiuti', 'rom'], [], ['Fiaccolata']),
#  (['giro', 'mazzette', 'appalti', 'campi', 'rom', 'procura'],
#   [],
#   ['pilotare', '']),
#  (['italiano', 'magistratura', 'vittima', '#rom'], [], ['muore', 'dorme']),
#  (['stirpe', 'rom', 'stronza'], [], ['credo', 'discenda']),
#  (['', 'numero', 'campagna'],
#   ['maggior'],
#   ['sembra', 'contare', 'proviene', 'è,a', 'fare']),
#  (['ricordo', 'strage'], [], []),
#  (['Bambini', 'rom', 'scuola', 'ruspa', 'Costituzione'],
#   [],
#   ['abbattere', '']),
#  (['uscita', 'migranti', 'soluzione'], ['illegale'], []),
#  (['strategia', 'campi', 'rom'], ['nuova'], ['imbonir', 'chiudere']),
#  (['piedi', 'cimitero', 'stranieri', 'anni', 'settembre', 'novembre'], [], []),
#  (['immigrata', 'accesso'], ['studentessa'], ['accoglie', 'negato', '']),
#  (['problema', 'fatto', 'nascita', 'islam', 'crociate', 'storia'],
#   [],
#   ['studi', 'riguarda']),
#  (['campo', 'rom'], ['nuovo'], ['nascerà']),
#  (['Sfruttamento',
#    '#prostituzione',
#    'favoreggiamento',
#    '#immigrazione',
#    '#nigeriani'],
#   ['clandestina', 'agrigentini'],
#   ['arrestati']),
#  (['Nazioni', 'casa', 'rom'], ['Unite'], ['dare']),
#  (['immigrati'], ['gnocche', 'felice'], ['sostituire', 'mantenere', 'dire']),
#  (['#Multiculturalismo', 'arresti', 'rom', 'mistero', 'ragazza'],
#   ['cinese'],
#   ['risorsa', 'risolto']),
#  (['scemenze', 'twitter', 'spirito', 'odio', 'migranti'], [], ['scritte']),
#  (['Ambasciatore', 'cambi', 'approccio', 'lotta', 'terrorismo'],
#   [],
#   ['spera']),
#  (['donne', 'rom', 'ragazza'], [], ['tentato', 'rapire', 'fatto']),
#  (['comunita', 'bene.'], ['islamica'], ['pagato']),
#  (['euro', 'terrorista', 'lavoro', '10mo', 'cifra'],
#   ['ucciso', 'stesso'],
#   ['faceva']),
#  (['Attacco', 'moschea', 'terroristi', 'arabo'], [], ['presi']),
#  (['polizia', 'campo', 'borse', 'controllo'],
#   [],
#   ['nomadi:trovate', 'rubate']),
#  (['Ragazza', 'rom', '16enne', 'uomo'],
#   ['cinese', 'morta', 'terzo'],
#   ['Fermato', 'denunciato', 'cerca']),
#  (['famiglia', 'rom', 'area', 'persone', 'terremoto', 'come...'],
#   [],
#   ['erano', 'colpite']),
#  (['Studentessa', 'nomadi', 'grazie', 'depenalizzazioni'],
#   ['cinese', 'liberi'],
#   ['morta', 'condannati', 'condannati', 'rimanere']),
#  (['stampa', 'parlamentare', 'fin', 'vita', 'via', '#migranti'],
#   ['serissima'],
#   ['dice']),
#  (['scuola', 'suore', 'cristiane', 'maggioranza'],
#   ['francescane', 'bambine'],
#   ['Andiamo', 'studiano']),
#  (['islam'], ['evidente'], ['fare']),
#  (['bastoni', 'campo', 'rom', 'bosniaco', 'omicidio'],
#   ['tentato'],
#   ['Rissa', 'fermato', 'accusato']),
#  (['marzo', 'immigrati', 'rom', 'preferita'],
#   ['islamici', 'comitiva'],
#   ['incontrerà']),
#  (['rom', 'ladri.'], ['....so', 'sportivi'], []),
#  (['rom', 'anni'], ['....le', 'problematiche'], ['esistono']),
#  (['Zuckerberg', 'big', 'ban'], [], ['rifugiati', 'immigrati']),
#  (['ragazzone', 'mano...', 'softair', 'legione', 'mamma'],
#   ['straniera'],
#   ['#chilhavisto', 'fatto', 'prendere', 'passando']),
#  (['rom', 'sinti', 'popolazione', 'territorio...'],
#   ['presente'],
#   ['vivono', 'rappresentano']),
#  (['condizioni', '#migrante', 'palle', '#razzisti', '#9febbraio'],
#   ['piccola'],
#   ['visto', 'stanno', 'sanno', 'parlano']),
#  (['scuola', 'video', 'rom', 'articolo', ''], [], ['imparato', 'parlando']),
#  (['rom', 'ok', 'disonesti'], ['disonesti', 'italiani'], ['vogliamo']),
#  (['Studentessa'], ['cinese'], ['morta', 'fermato']),
#  (['immigrati'], ['prigionieri'], []),
#  (['ruspe...', 'campi', 'rom', 'palazzi', 'anno'], ['buon'], ['vogliono']),
#  (['villa', 'nomadi', 'caccia', 'mesi'], [], ['Rapina', 'presi', 'durata']),
#  (['studentessa', 'treno', 'nomade'], ['cinese'], ['uccisa', 'fermato']),
#  (['stabilimento', '#museo', '#streetart', 'rom'],
#   ['ex'],
#   ['diventa', 'gestito']),
#  (['lavastrade'], ['immigrati', 'organizzati'], []),
#  (['rom', 'delinquenti', 'ragazza'],
#   ['italiani', 'cinese'],
#   ['fare', 'ucciso', 'studiava', 'so']),
#  (['dato', 'fatto', 'punto', 'snodo', 'passaggio', 'terroristi'], [], []),
#  (['rom', 'figli', 'testa', 'rom', 'rom'], [], ['fanno', 'togliere']),
#  (['casse', 'mandarini', 'attrezzi', 'nomadi', 'furti'],
#   [],
#   ['arrestati', 'colpito']),
#  (['sindaco', 'scuola', 'arti', 'stranieri', 'ideologo'],
#   ['leghista'],
#   ['crea', 'fare']),
#  (['condizioni', 'rom'], [], ['#dallavostraparte', 'fare', 'migliorare']),
#  (['chiusura', 'transitati', 'via'], [], []),
#  (['avviso', 'problema', 'costi', 'rom'],
#   ['buonista', 'approfittano.'],
#   ['sanno']),
#  (['tweet', 'vicinanza', '#donna', 'amico'], ['#immigrato'], ['malmenata']),
#  (['modi', 'popoli', 'fisici', 'margini', 'società', '#rom'],
#   ['interi', '#genocidi', 'morali'],
#   ['sono', 'distruggere', 'lasciando']),
#  (['imprendittore',
#    'azienda',
#    'tempo',
#    'supermercato',
#    'scarpe',
#    'islam',
#    'combatto'],
#   [],
#   ['sto', 'perdo', 'rifletto', 'fa']),
#  (['immigrati', 'stipendi', 'persone'],
#   ['belle'],
#   ['dice', 'vogliamo', 'diminuire']),
#  (['censimento', 'campi', 'rom', 'lavoro', 'superamento', 'villaggi'],
#   ['Concluso'],
#   []),
#  (['lega', 'destra', 'lavoratori', 'rom'],
#   ['stranieri'],
#   ['', 'sfrutta', 'contestano', 'guadagnato']),
#  (['fuoco', 'baracca', '18enne', 'rom', 'Foto'], [], ['ustionata']),
#  (['leggi', 'rom'], ['speciali'], []),
#  (['#dallavostraparte',
#    'dignità',
#    'illegalita',
#    'affermazione',
#    'sig',
#    'nero',
#    'livello',
#    'rom'],
#   [],
#   ['Riacquistare', 'è']),
#  (['buonista', 'razzista', 'poliziotto', 'terrorista', 'terrorista'],
#   ['ke', 'fascista', 'francese', 'ke', 'caro'],
#   ['sentire', 'sparato']),
#  (['anni', 'giro', 'rapine', 'banda'], [], ['fare', 'presa']),
#  (['donne',
#    'rom',
#    'paura',
#    'sberleffo',
#    'cittadini',
#    'vittime',
#    'anni',
#    'rom'],
#   [],
#   ['#biancoenero', 'hanno', 'ridicoli']),
#  (['esempio', 'immigration'], ['iraniana'], ['prendiamo', 'namo']),
#  (['case', 'rom'],
#   [],
#   ['Visto', 'difendete', 'hai', 'dire', 'dare', 'stanziato']),
#  (['immigrazione', 'Presentazione', 'gennaio', 'libreria'], [], []),
#  (['Giornata', 'rom'], [], ['commemorano']),
#  (['Ordine', 'ebrei', 'cattolici', 'cristiani'], ['islamici'], ['revocato']),
#  (['Foto'], [], ['ospiterei']),
#  (['', 'serie', 'gente', 'opportunità'], ['brava'], []),
#  (['autorità', 'raid', 'stati', 'stato', 'allerta'],
#   ['tedesche', 'antiterrorismo'],
#   ['effettuato']),
#  (['', 'terrorista', 'colpa', 'pd', 'alfano', 'soldi', 'coperative'],
#   ['rosse'],
#   ['fatto', 'passare', 'fatte']),
#  (['verità', 'immigrazione'], ['clandestini'], []),
#  (['campo', 'raggi', 'persone', 'precedenti', 'ricercato'],
#   ['nomadi', 'controllate'],
#   ['è']),
#  (['proteste', 'compagnie', 'misure', 'ambito'], [], ['schierano']),
#  (['rom', 'complotti'], [], ['uncino']),
#  (['trovata', 'ore', 'banditi', 'campo', 'rom'],
#   ['cinese', 'morta'],
#   ['contate', 'scippata', 'Vengono']),
#  (['Giornata',
#    'diritti',
#    'adolescenza',
#    'Associazione',
#    'luglio',
#    'rom',
#    'povertà'],
#   ['Internazionale', 'infanzia', 'minori', 'assoluta'],
#   ['vivono']),
#  (['Gb', 'barriere', 'castello', 'cambio', 'guardia', 'meta', 'turisti'],
#   ['nuove', 'tradizionale'],
#   ['antiterrorismo']),
#  (['via', 'arrivo', 'nigeriani', 'zona', 'nomadi', 'problema'],
#   ['casalombroso', 'problematica'],
#   ['previsto', 'innestando']),
#  (['caso', 'attacco'], ['terroristico'], ['fare']),
#  (['sequestratori', 'donna', '#rom', '#rom', 'sorella', 'figlia'],
#   ['bianconero'],
#   ['vedere']),
#  (['futura', 'roma', 'rom', 'caminanti', 'accesso', 'servizi'],
#   ['Politica', 'sinti'],
#   ['spera']),
#  (['stampa', 'parte', '#ribelli', 'civili', '#terroristi'],
#   ['gran', '#siriani', 'inermi'],
#   ['Tanta', 'ignorato']),
#  (['media', 'giornalisti', 'rosa', 'partite', 'nazionale'],
#   ['Italiani', 'stranieri'],
#   ['spero', 'accontenti', 'vedremo', 'rilassati']),
#  (['', 'sindaco', 'sindaco', 'ordinanze', 'rom', 'auguri'],
#   ['uguale'],
#   ['è', 'mette', 'fioriere', 'è', 'fa']),
#  (['immigrati'], ['restante'], ['rifugiati', 'mettere']),
#  (['indagati', 'favori', 'migranti', 'viceprefetto'], [], ['arrestato']),
#  (['chiusura', 'campo', 'rom', 'sinistra', 'sinistra'], [], ['boccia']),
#  (['musulmano', 'donna', 'proni', 'volontà'],
#   ['inferiore'],
#   ['considera', 'è']),
#  (['stadio', 'testa', 'saviano', 'xo', 'paesi'],
#   ['roma,lidl,rom,la'],
#   ['vede', 'parlare', 'sono', 'terremotati', 'fatto']),
#  (['aggressione', 'rapina', 'dettagli', 'arresto', 'rom', 'web'], [], []),
#  (['genere', 'velo'],
#   ['favorevole', 'islamico'],
#   ['immagino', 'accaduto', 'avessero']),
#  (['campo', 'rom', 'arresti', 'ombra', 'racket'], [], ['rapina']),
#  (['boom', '#italiani', '#turisti', 'crisi', 'terrorismo'],
#   [],
#   ['Capodanno', '']),
#  (['', 'nn', 'litro', 'latte', 'rom', 'prostitute'],
#   [],
#   ['sa', 'costa', 'figuriamo', 'parlare', 'parla']),
#  (['dibattito', 'sicurezza', 'immigrazione', 'omicidio', 'piazzale', ''],
#   ['Loreto'],
#   ['riaccende']),
#  (['case', 'rom', 'rabbia', 'residenti'], ['popolari'], ['assegnate']),
#  ([], ['immigrati'], []),
#  (['Studentessa', 'ventenne', 'nomade', 'campo', 'via'],
#   ['cinese'],
#   ['morta', 'fermato', '']),
#  (['negozio', 'terroristi', 'protesta', 'clienti'], [], ['colpito', 'scatta']),
#  (['cu', '#terrorismo'], ['nuove'], []),
#  (['Podisti', 'video', 'campo', 'rom'], ['marsicani'], ['derubati']),
#  (['mittente', 'immigrazione'], [], ['Rimando', 'accusa']),
#  (['scuola', 'rom', 'tempo'], ['bambina'], ['andata', 'giocato', 'speso']),
#  (['carabinieri', 'albergo', 'profuga', 'bambina'], [], ['pagano']),
#  (['campo', 'censimento', 'arresti'], [], ['rissa', 'nomadi']),
#  (['bello', 'nomadismo'], ['differentispossible'], ['sentire', '', 'parlare']),
#  (['stupro', 'campo', 'rom', 'pm', 'insediamento'], [], []),
#  (['fase', 'strillo', 'canzone', 'mente', 'campo', 'rom'],
#   [],
#   ['Grillo', 'stai', 'venuto']),
#  (['reazione', 'migrante'], ['forte'], ['entra']),
#  (['Bilancio', 'salvadanaio', 'migranti', 'oneri', 'onori'], ['stessi'], []),
#  (['#immigrati', 'Imprenditori'],
#   ['pseudo'],
#   ['campano', 'arricchiscono', '']),
#  (['tweet', 'condanna', 'gesto', 'rom...'], [], ['', 'vedo']),
#  (['italy', 'animali', 'barconi', 'rom', 'vergogna', 'governo'],
#   ['ecc'],
#   ['fanno', 'morire', 'arriva', 'danno']),
#  (['donna', 'ladre', 'rom'], [], ['picchiata', 'denunciato', '']),
#  (['uomini', 'aspetto'], [], ['avuto']),
#  (['islamici'], [], ['Rimangono']),
#  (['centinaia',
#    'casi',
#    'mesi',
#    'casi',
#    '#morte..tranquilli',
#    'norma',
#    '#immigrazione'],
#   ['primi'],
#   ['#meningite', 'incide']),
#  (['occasione', 'rom'], [], ['perdete', 'fare']),
#  (['sopravvive', 'immigrati'],
#   ['concordo'],
#   ['penso', 'disposte', 'calpestare']),
#  (['rom', 'italiani.....'], [], ['fare', 'so']),
#  (['profughi', 'arrestato', 'accuse', 'vittima'], [], ['respinge']),
#  (['forza',
#    'immigrati',
#    'governo',
#    'città',
#    'favelas,violenze',
#    'sporcizia,furti',
#    'degrado'],
#   [],
#   ['sembra', 'goda', 'avere']),
#  (['intesa', 'petrolio', 'terrorismo'], [], ['raggiunta']),
#  (['', 'rom', 'casa', 'leggi'],
#   ['illegali', 'europee'],
#   ['vengono', 'applichiamo']),
#  (['Questione', 'rom', 'piano', 'lavoro'], [], ['bluffa']),
#  (['lite', 'rom', 'Intervento'], ['#MunicipioIII', 'ennesima'], []),
#  (['anziani', 'pranzo'], [], ['accompagnano']),
#  (['rom', 'sentenze', 'tribunale', 'disastro'],
#   ['ambientale'],
#   ['madama', 'sgombra']),
#  (['', 'straniero', 'milioni', 'pezzi'],
#   [],
#   ['restanti', 'risparmiati', 'inizia', 'comprar', ',figo,no']),
#  (['testa', 'servizi', 'gente'],
#   ['americani'],
#   ['toglie', 'seguono', 'sanno', 'stanno', 'fare']),
#  (['agente', 'cella', 'picchia', 'agente', '|...'],
#   [],
#   ['tocca', 'finisce', 'torna']),
#  (['bacchettata', 'situazione', 'rom'], [], []),
#  (['simpatia', 'dipendenti', 'rom'], [], ['spiace', 'provo']),
#  (['migranti', 'estero', 'paesi'],
#   ['stessi', 'esteri'],
#   ['andare', 'vogliono']),
#  (['studentessa', 'condanna', 'patteggiamento', 'rom'], ['cinese'], ['morta']),
#  (['profughi'], [], ['destinati']),
#  (['campagna', 'racconto', 'legge', 'immigrazione', 'obiettivi'],
#   [],
#   ['Lanciata', 'cambiare']),
#  (['rom', ',assassini', 'cazzo', 'etnia'],
#   [],
#   ['delinquenti', 'ladri', 'entra']),
#  (['#rom', 'stereotipi', 'discriminazioni', 'persone'],
#   [],
#   ['visto', 'lavora', 'colpiscono', 'appartenenti']),
#  (['Allaccio', 'campo', 'rom', 'mesi'], ['regolare'], ['cambiato']),
#  (['musulmani', 'terroristi', 'paese'], [], ['attacca', 'accolga']),
#  (['scuola', 'alunni'], ['stranieri'], []),
#  (['Giornale', 'rom', 'diritti'], [], ['fondano']),
#  (['nomadi', 'asilo'], ['politico'], ['chiedono']),
#  (['banda',
#    'rom',
#    'pizzo',
#    'anni',
#    'ristoratore',
#    'colpi',
#    'mitra',
#    'permaloso..'],
#   ['esausto'],
#   ['chiedeva', 'uccide']),
#  (['stupidità', 'donna', 'islamico'], ['incredibile', 'critica'], ['', 'sta']),
#  (['crisi',
#    'salute',
#    'migranti',
#    'tragedie',
#    'migranti',
#    'rifugiati',
#    'riversano...'],
#   ['mentale'],
#   []),
#  (['valanga', 'voti', 'immigrazione', 'virata'],
#   [],
#   ['perdendo', 'accorti', 'tentato', 'crede']),
#  (['#dallavostraparte', 'visita', 'rom', 'cosa', '#lodi'],
#   ['#cimbro', 'ricevi', 'predica', '#legittimadifesa'],
#   ['Speriamo', 'vediamo']),
#  (['amore', 'immigrati', 'schifo'], ['Strano'], ['fanno']),
#  (['rom', 'minoranze', 'gen.,ma', 'dissidenti', 'nonno'],
#   ['ebrei'],
#   ['pestato']),
#  (['terroristi', 'tratte'], ['stesse'], ['facciamo', 'prendo']),
#  (['amico', 'dittatore', 'terroristi', 'bombe'],
#   [],
#   ['Visto', 'vede', 'fanno']),
#  (['coprifuoco', 'compagni', '#nave', '#migranti'],
#   [],
#   ['dicono', 'utilizzata', 'lasciare']),
#  (['#migranti', 'anno'], [], ['servono']),
#  (['storia', 'campi', 'rom'], [], []),
#  (['Capo', 'decreto', 'immigrazione'], [], ['licenzia']),
#  (['giro', 'mazzette', 'appalti', 'campi', 'rom', 'procura', 'inchiesta'],
#   ['nuova'],
#   ['pilotare', 'chiude']),
#  (['#dallavostraparte', 'nero...'],
#   ['fottiti', ''],
#   ['principessina', 'nomadano', 'sbattono']),
#  (['ricorso', 'appello', 'ok', 'sospensione', 'politica', 'migranti'],
#   [],
#   ['Respinto']),
#  (['dito', 'fede', 'caccia', 'rom'], [], ['spezzano', 'rubar']),
#  (['contratto', 'case', 'case.Solo'],
#   ['immigrati'],
#   ['DIRITTOOO.Hanno', 'pagato.Guardate', 'danno', 'pagano']),
#  (['accordo', 'migranti'], [], ['saltato']),
#  (['#rom',
#    'sapere',
#    'borseggio',
#    'fondi',
#    'assegnazione',
#    'case',
#    'esenzioni',
#    'romani'],
#   [],
#   ['tramandano', 'Raggi']),
#  (['nomadi', 'asilo'], ['politico'], ['chiedono']),
#  (['arresti', 'rom', 'mistero', 'ragazza'], ['cinese'], ['risolto']),
#  (['Papa',
#    'studenti',
#    'risposta',
#    'paura',
#    'accoglienza',
#    'accompagnamento',
#    'migranti'],
#   [],
#   []),
#  (['parte', 'immigrati', 'carica', 'conti'],
#   [],
#   ['accettare', 'risulta', 'fatto']),
#  (['colombiana', 'metro', 'rom'], [], ['becca', 'rubare', 'riducono']),
#  (['migliaia', 'cinesi', 'rom'], [], ['votarono']),
#  (['cinese', 'ore', 'campo', 'rom'],
#   ['morta'],
#   ['contate', 'scippata', 'Vengono']),
#  (['', 'processo', 'codice', 'rom'],
#   ['penale', 'clandestini', 'caro'],
#   ['difende']),
#  (['diventati', 'cittadinanze', 'complici'], ['italiani', 'Ong'], []),
#  (['', 'guerra', 'migranti', 'richiedenti', 'asilo', 'diritti'],
#   ['difficile'],
#   ['scappano', 'distinguere']),
#  (['rom', 'correttore', 'telefono'], [], []),
#  (['stragi', 'terrorismo', 'vedi'], ['/atti'], ['fare']),
#  (['spalle', '#rom'],
#   [],
#   ['divisa', 'guarda', 'fida', 'disprezza', 'vissuto']),
#  (['corno', 'euro', 'euro', 'rom'], [], ['', 'voglio', 'capire', 'parlare']),
#  (['dito', '80enne', 'fede', 'Caccia', 'rom'], [], ['spezzano', 'rubar']),
#  (['fatto', 'indicazione'], ['straniero'], ['so', 'fornisce']),
#  ([], [], ['scritto']),
#  (['domiciliari', 'furto', 'nomadi', 'treno'],
#   ['libero'],
#   ['condannati', 'scipparono', 'morta']),
#  (['#padova', 'ladre', 'grondaia', 'nomadi', 'incinta', 'mese'],
#   ['acrobate'],
#   ['arrampicano', 'fermate']),
#  (['anni', 'immigrati', 'rom....'],
#   [],
#   ['Riprender', 'cominciando', 'occupato']),
#  (['', 'donna', 'campo', 'rom', 'via'], ['trovata'], ['morta']),
#  (['Caos', 'migranti', 'via'], ['sgombero'], []),
#  (['rom...', 'turisti', 'decine', 'ragazzi'],
#   ['romani'],
#   ['controlla', 'lavorare']),
#  (['milioni', 'campi', 'rom'], [], ['spende']),
#  (['conferma', 'immigrati', 'scelti.', 'sapevo', 'conferma'],
#   [],
#   ['avuto', '....avere']),
#  (['Malattie', 'diritto', 'studio', 'fine', 'famiglie', 'rom', 'via'],
#   ['negato'],
#   ['fatto', 'sgomberate']),
#  (['MILIONI', 'famiglie', '#rom', 'cittadinanza'],
#   ['insediate'],
#   ['RISORSE', 'Sequestrati']),
#  (['campi', 'milioni', 'anno'], ['nomadi'], ['finanziava']),
#  (['fonte', 'mainstream', 'immagini', 'strage', 'gas', 'terrorista'], [], []),
#  (['pista'], ['valuta'], ['islamista\\nFerito']),
#  (['campo', 'schifo', 'rom'], [], ['smantellato']),
#  (['media', 'attacco'], ['terroristico'], ['cercato', 'dire']),
#  (['', 'momento', 'terrorismo', 'fenomeno', 'feriti'],
#   ['locale'],
#   ['sa', 'tratta', 'morti']),
#  (['guida',
#    'gommone',
#    'migranti',
#    'polizia',
#    'finanza',
#    '#blogsicilianotizie'],
#   [],
#   []),
#  (['Top', '#news', 'campo', 'rom'],
#   ['nuovo', 'see', 'more'],
#   ['esposto', 'Bando']),
#  (['argentina', 'muro'], ['anti', '-immigrati'], ['vogliamo']),
#  (['#demagogia', 'problema', 'migranti', 'barconi'],
#   ['confusionaria'],
#   ['Solita', 'sposta', 'arrivano']),
#  (['problema', 'cultura', 'legalità', 'rom', 'bambini'],
#   ['#biancoenero'],
#   ['è', 'vanno', 'rubare', 'è', 'spinge']),
#  (['Domenica', 'fede', 'cristiani', 'profughi'], ['iracheni'], []),
#  (['messaggero', 'acqua', '#rom'], ['calda'], ['scoperto']),
#  (['campi', 'rom'], [], ['lavorando', 'chiudere']),
#  (['scontro', 'migranti', 'Pronti', 'veto', 'quote', 'causa'], [], ['fare']),
#  (['migranti', 'passaporti'], [], ['Fermati', 'rubati']),
#  (['strilli', 'sbraiti', 'rom', 'minoranza', 'stolti'],
#   [],
#   ['Basta', 'mobilitare', 'abituati', 'difendere']),
#  (['campo', 'rom'], ['nuovo'], ['nascerà', '']),
#  (['scatenata', 'statua', 'libertà', 'immigrazione'],
#   ['anacronistica'],
#   ['Incita']),
#  (['grazie', 'stasera', '#convergenze'],
#   ['bravo', 'migranti', '#migrationNocrime'],
#   ['nominato', 'parla']),
#  (['rom', 'mirino', 'coop', 'politici'], [], []),
#  (['#ultimenotizie',
#    'notizie',
#    'foto',
#    'blitz',
#    'arresto',
#    'terrorista',
#    'strage'],
#   [],
#   ['portato']),
#  (['roma', 'campi', 'italiani', 'abitazioni', 'gente', 'boldrini'],
#   ['nuovi', 'nomadi'],
#   ['abbandonano', 'abbiamo', 'difende']),
#  (['setaccio', 'carabinieri', 'campo', 'nomadi', 'Via', '#news'],
#   [],
#   ['Passato']),
#  (['incubo', 'rom', 'lezione'],
#   [],
#   ['svegliato', 'culona', 'siede', 'soffocando', 'detto']),
#  (['cazzo', 'rom'], ['merda'], ['sa', 'entrino']),
#  (['tunisini', 'rom'], [], ['', 'metti', 'cavano']),
#  (['anziani', 'nomadi', 'fatto'], ['sinti', 'assolti'], ['commesso']),
#  (['fatto', 'palle', 'religioni', 'attentato', 'stampo'],
#   ['islamico'],
#   ['guarda', 'stiano', 'entra']),
#  (['Papa', 'migrante', 'terra'], ['lontana'], []),
#  (['poliziotto', 'terrorista', 'località'],
#   ['segreta'],
#   ['uccise', 'trasferito']),
#  (['gemello', 'terroristi', 'dubbio', 'alleanza'],
#   ['piccolo', 'palese'],
#   ['viavai', 'aveva']),
#  (['accordo', 'migranti'], [], []),
#  (['rom', 'voto', 'associazioni'], [], ['passo', 'slitta', 'Ascoltiamo']),
#  (['lavoro', 'immigrati'], [], ['hanno', 'sono']),
#  (['banda', 'rom', 'circonda', 'rapina', 'via'], ['turista'], ['incinte']),
#  (['rom', 'macchinoni', 'oro', 'cianfe', '#schifo'],
#   [],
#   ['dite', 'hanno', 'lavorano']),
#  (['giunta', 'euro', 'nomadi', 'scuola'], [], ['trasportare', '']),
#  (['Giornata', '#migrante', '#sindacati', 'appello'],
#   ['#internazionale', '#pensionati'],
#   ['firmano']),
#  (['Messaggio', 'ufficiali', 'islamisti'],
#   ['chiaro'],
#   ['detiene', 'dirigevano']),
#  (['Associazioni', 'derubati'], ['vero'], ['pensate', 'inventato']),
#  (['giornata', 'memoria', 'accordo', '#profughisiria'], [], ['mette']),
#  (['can', 'can', 'giorni', 'elezioni', 'vittoria', 'antislamista'],
#   [],
#   ['sancire']),
#  (['rapine', 'turisti', 'nomadi'], [], ['pubblicato', 'fermate']),
#  (['ragazza', 'notte', 'ai...'], ['immigrato'], ['sequestrata', 'stuprata']),
#  (['nomadi', 'aree', 'lavoro', 'superamento', 'campi'], ['attrezzate'], []),
#  (['chiesa', 'persone', 'operazioni'],
#   ['copta', 'altre', 'terroristiche'],
#   ['Attentato', 'Arrestati', 'sospettati', 'progettare']),
#  (['immigrati', 'canale', 'introiti'], [], ['rendono', 'diceva', 'trovato']),
#  (['ambulante', 'sputi', 'agenti', 'rom'], [], ['botte', 'arrestati']),
#  (['Caos', 'furto', 'bordo', 'nave', 'immigrati'], [], ['identificati']),
#  (['', 'parte', 'stupidità', 'dipendenti', 'nomade'],
#   [],
#   ['recita', 'invita']),
#  (['linciaggio', 'bar', 'piazza', 'ragazzini', 'nonno'],
#   ['extracomunitario', 'infuriato'],
#   ['Bojano', '#bojano']),
#  (['terrorista', 'giudici'], [], ['interrogato', 'rifiuta', 'rispondere']),
#  (['IL', 'individuo', 'volonta', 'vero', 'creatore'],
#   ['musulmano', 'unico'],
#   ['sottomette']),
#  (['Secessionisti', 'pm', 'rinvii', 'giudizio', 'terrorismo'], [], ['chiede']),
#  (['colpe', 'islam', 'guerrafondaie', 'territori'],
#   ['politiche'],
#   ['riconoscere']),
#  (['#sud', 'Allarme', 'povertà', 'centri...'],
#   ['#andria', 'italiani', 'stranieri'],
#   []),
#  (['ministro', 'ingiustizia', 'sntenze', 'favore', 'rom', 'marcia', 'favore'],
#   ['tutte'],
#   ['fa', 'vedere']),
#  (['parte', 'storia', '#islam'], ['#10aprile'], ['racconta', '#cassimatis']),
#  (['minaccia', 'terrorismo', 'diffusione', 'cultura', 'primitiva.'],
#   ['vera', 'barbara'],
#   []),
#  (['mario', 'cipriani', '', 'negozi', 'stranieri', '6°mun...'],
#   ['fascista'],
#   []),
#  (['senno', 'rom', 'rame'], [], ['uscendo', 'disegna', 'vestiti', 'rubano']),
#  (['rom'], ['illegale'], ['adattare', 'dire', 'rubare']),
#  (['#dallavostraparte', 'rom', 'lavoro', 'rom', 'tasse', 'italia', 'case'],
#   [],
#   ['esiste', 'cerca', 'pagano', 'pretendono']),
#  (['attentatore', 'cibo', 'migranti...'], [], ['era', 'portava']),
#  (['esplosione', 'terrorismo'], ['pronta'], ['collaborare']),
#  (['farmacisti', 'terrorismo', 'sos', 'congresso', 'missi......'],
#   ['migranti'],
#   ['parla']),
#  (['bonifica', 'campi', 'rom', 'rinvii', 'giudizio'],
#   [],
#   ['mazzette', 'chiesti', '']),
#  (['mesi', 'nomade', 'inseguimento'], [], ['ricercata', 'arrestata']),
#  (['', 'Grazie', 'arroganza', 'volta', 'eh...'],
#   ['islamisti', 'buona'],
#   ['sveglia', 'vediamo']),
#  (['soluzione', 'terroristi.', 'loro...'],
#   ['..basta'],
#   ['', 'far', 'diventare', 'fare', 'vogliono']),
#  (['immigrazione', 'governo', 'magia'], [], ['ricorre']),
#  (['campo', 'rom'], ['nuovo'], ['nascerà']),
#  (['Yao,i', 'rom', 'vicenda', 'bottino'], [], ['accusano']),
#  (['profugo', 'mozione', 'banchi', 'sala'], [], ['Adotta', 'approda']),
#  (['indagini', 'sull‘ideologia', 'estremisti'],
#   ['islamici', 'illegittima'],
#   ['dici']),
#  (['', 'parte', 'fatto', 'controllo', 'immigrazione'],
#   ['preventivo'],
#   ['stavo', 'parlando', 'giustifica']),
#  (['favore', 'bicchiere', 'acqua', 'nomadi', 'soldi'], [], ['rubano']),
#  (['rom', 'webitalia360...'], [], ['circondata', 'derubata']),
#  (['#dallavostraparte', 'signora', 'figlio', 'campi', 'rom', 'giorno'],
#   [],
#   ['lasci', 'vediamo', 'pensa']),
#  (['voti'], ['islamici'], ['eletti']),
#  (['euro', 'rom', 'volta', 'vittima...'],
#   [],
#   ['condannato', 'risarcire', 'cercò', 'uccider']),
#  (['donne', 'rom', 'volto', 'miseria', 'gabbia'], [], ['filmate', 'derise']),
#  (['casa', 'rom'], [], ['dare']),
#  (['responsabili', 'situazione', 'vigliacco', 'rom', 'migranti', '#bravo'],
#   ['faticoso', 'rischioso'],
#   ['Prender', 'prendi']),
#  (['incremento', 'reati', 'aumento', 'presenza', 'immigrati'],
#   [],
#   ['stato', '']),
#  (['ladri', 'rom', 'balcone'], ['acrobati'], ['arrestati', 'arrampicavano']),
#  (['rom', 'accoglienza', 'discriminazione', 'marzo'], ['convegno'], []),
#  (['rom....parmi'], ['strano'], ['sbagliati']),
#  (['ragazza', 'donne', 'rom'],
#   [],
#   ['tentano', 'rapire', 'far', 'prostituire', 'arrestate']),
#  (['Studentessa', 'rom'], ['cinese', 'terzo'], ['morta', 'fermato']),
#  (['massacri', 'cristiani', 'azizi', 'gole'],
#   ['musulmani', 'tagliate'],
#   ['Piazzapulita', 'fermata', 'dimenticato']),
#  (['#notizie', 'carovana', 'nomadi', 'settimana', 'ca...'],
#   [],
#   ['sgomberata']),
#  (['ok', 'campo', 'rom', 'Misure', 'Obiettivo', 'villaggi'],
#   ['comune', 'nuovo', 'temporanee'],
#   ['superare']),
#  (['ragazza', 'centro', 'accoglienza', 'profughi', 'operatori'],
#   [],
#   ['Muore', 'rivolta', 'bloccano']),
#  (['mesi', 'muro'], ['anti', 'migranti'], ['finito', 'finanziato']),
#  (['scuola', 'figlio', 'elemosina'],
#   [],
#   ['manda', 'far', 'chiedere', 'arrestata']),
#  (['rom', 'interno', 'forbice', 'unità'],
#   ['presenti', 'ampia', 'controversa', 'compresa'],
#   ['mantengono']),
#  (['scuola', 'zingari', 'figli', 'rom', 'euro'], [], ['spingono', 'bastano']),
#  (['palme', 'cammelli', 'tetto', 'rom'],
#   [],
#   ['#Milano', 'cacciano', 'taglieggiati']),
#  (['Maltempo', 'fiume', 'piena'], [], ['arrivato', 'disperso', 'sfigati']),
#  (['cristiano', 'anti-islam', 'squadra'], [], []),
#  (['scuola,arrestato', 'rom', 'pc', 'monitor'],
#   [],
#   ['Ruba', 'computer', 'preso', 'impossessato']),
#  (['ragazza', 'rom'],
#   [],
#   ['Cercano', 'rapire', 'far', 'prostituire', 'arrestate']),
#  (['negri', 'rom', 'risorse'], ['islamici', 'clandestini'], ['dimostra']),
#  (['numeri', 'migrante', 'abitanti', 'invasione'], [], ['spaventosi']),
#  (['#cristiani', '#terroristi'], [], ['#libera']),
#  (['campo', 'residenti', 'blitz'],
#   ['nomadi', 'abusivo', 'pregiudicati', 'maxi'],
#   ['Sgomberato']),
#  (['nomadi', 'furto', 'coppia'], [], ['arrestati']),
#  (['bambini', 'ospedali', 'terroristi'],
#   ['civili'],
#   ['sanno', 'nascondono', '']),
#  (['Italiani', 'stranieri', 'Paese'], ['integrati'], ['aiutano']),
#  (['podisti', 'rom'], [], ['perseguitati']),
#  (['#dallavostraparte', 'condoni', 'passato', 'governo', 'cosa', 'rom'],
#   [],
#   ['stai', 'facendo', 'basta']),
#  (['tensione', 'capitale', 'fuga', 'capi', 'lire', '#Terrorismo'],
#   ['terroristi', 'siriane'],
#   ['portando']),
#  (['Governo', 'comunità', 'vittima', 'terrorismo'],
#   ['musulmana'],
#   ['Attentato']),
#  (['#terrorismo', 'vittima', 'strada'], [], []),
#  (['Psicosi', 'leggende', 'Attenzione', 'furgone', 'rom'],
#   ['pieno'],
#   ['galoppano']),
#  (['giocatori', 'straniero'],
#   ['italiani', 'brocchi'],
#   ['temo', 'oriundo', 'andrebbe']),
#  (['programmi', 'battute', 'immigrazione', 'cosa', 'coglioni'],
#   ['seria', 'albanese', '#domenicalive'],
#   ['cazzeggia']),
#  (['giro', 'vite', 'tagli', 'welfare', 'stranieri', 'sussidi', 'anni'],
#   [],
#   []),
#  (['#nomadi', '#strada', '#frigorifero', 'automobilisti'],
#   [],
#   ['bloccano', '#rapinare']),
#  (['sparatoria', 'pressi', 'centro'], ['islamico'], ['Attentato']),
#  (['furto', 'appartamento', 'rom', 'via', '#news'],
#   ['minorenni'],
#   ['denunciati']),
#  (['donne', 'inseguimento'], ['nomadi', 'pericoloso'], ['retata']),
#  (['migranti', 'punti', '#news'], ['salienti', '#ansa'], []),
#  (['cuccioli', 'vendita', 'indagini', 'campo', 'rom'], [], ['sequestrati']),
#  (['tempo',
#    'guerre',
#    'popoli',
#    'fuga',
#    'terrorismo',
#    'violenze',
#    'semi',
#    'bontà',
#    'bellezza'],
#   [],
#   ['fatto', 'spargere']),
#  (['donne', 'spazzatura', 'sequestri', 'torturi', 'stranieri'],
#   ['incivili'],
#   ['', 'vedi', 'frugare', 'dici']),
#  (['registro', '#confini', '#profughi', '#immigrazione'],
#   [],
#   ['cambia', 'chiude']),
#  (['persone', 'cena', 'profughi'], [], ['preparata']),
#  (['invasione', 'rom', 'ospedale', 'capofamiglia', 'moglie'],
#   ['quotidiano'],
#   ['dona']),
#  (['miliardo', 'Musulmani', 'terroristi', 'fondamentalisti'],
#   [],
#   ['credo', 'credo']),
#  (['Bambini', 'rom', 'scuola', 'ruspa', 'Costituzione'], [], ['abbattere']),
#  (['domenica', 'rom', 'campi', 'torre', 'fumi'],
#   ['antismog', 'abusivi', 'spaccata', 'tossici'],
#   ['', 'smettere', 'emanare']),
#  (['trombati', 'rom', 'politica'], [',i'], ['#portaaporta']),
#  (['paese', 'tombe', 'migranti'], [], ['ospitare', 'morti']),
#  (['legge', 'minori'], ['stranieri'], ['accompagnati']),
#  (['business', 'profughi'], ['falsi'], []),
#  (['', 'negozi', 'carrefour', 'tedesca'],
#   ['stranieri', 'francesi', 'lidl'],
#   ['intendono']),
#  (['campo', 'rom', 'procura', 'sequestro'], [], ['convalida']),
#  (['lavori', 'esima', 'accoglienza'], [], ['Aperti', 'Parliamo']),
#  (['#PrimariePD', 'coscrizione', 'nomadi', 'farsa', 'inizio'],
#   ['pronti'],
#   ['abbia']),
#  (['campo', 'rom', 'procura', 'sequestro', 'Giornale'], [], ['convalida']),
#  (['scommesse', 'tipo', 'lavoro', 'rom'],
#   [],
#   ['Accettiamo', 'andando', 'fare']),
#  (['Grazie', 'evoluzione', 'prox', 'gabbia', '#rom'],
#   ['chiaro', 'inciampa'],
#   ['spero']),
#  (['Centinaia', 'terroristi', 'profughi'], [], ['avverte', 'arrivando']),
#  (['Borse', 'minaccia', 'mirino'], ['terroristica'], ['caute']),
#  (['Ventenne', 'morte'], ['nomade', 'minore'], ['fermato', 'denunciato']),
#  (['Giornata', 'rom', 'sinti', 'inclusione'],
#   ['internazionale', 'lontana'],
#   ['è']),
#  (['sgomberi', 'campi', 'rom', 'zingari', 'diritto', 'casa', 'via'],
#   [''],
#   ['annulla', 'hanno']),
#  (['Giornata', 'i#nfanzia', '#rom', 'baraccopoli'], [], ['discuterà']),
#  (['storia', 'guardia', 'immigrazione', '#storia'],
#   ['nazionale', '#la'],
#   ['contrastare']),
#  (['problemi', 'elezioni', 'merkel', 'terrorismo', 'pazzi'],
#   ['psichici'],
#   ['camuffa', '....fessi']),
#  (['campo', 'nomadi', 'via', 'casa', 'Giorno'], [], ['dotata']),
#  (['',
#    'mercoledì',
#    'prefetto',
#    'Sindaci',
#    'piano',
#    'distribuzione',
#    'profughi'],
#   [],
#   ['convocato', 'annunciar']),
#  (['campi', 'rom', 'gennaio', 'piano', 'Paese'], [], ['chiudere']),
#  (['bici', 'macchina', 'fisica', 'bici', 'macchina', 'rom'],
#   ['grande', 'ladri'],
#   ['caricare', 'accorti', 'sembravamo']),
#  (['immigrati'], [], ['', 'accolti', 'fare']),
#  (['Eredita', 'rom'],
#   ['masseria', 'disperato'],
#   ['occupata', 'Pensionato', 'distruggendo']),
#  (['famo', 'paragone', 'ab.su', 'profugo'],
#   ['mattè,se', 'cor', 'siriano'],
#   []),
#  (['Pil', 'immigrati', 'miliardi'], [], ['vale', 'pesa']),
#  (['Studentessa', 'scippo', 'condanna', 'rom', 'carcere'],
#   ['cinese'],
#   ['morta', 'patteggiano']),
#  (['Raggi', 'rom', 'roma', 'nord'],
#   [],
#   ['so', 'promesso', 'promesso', 'aprir', '...e', 'aprendi']),
#  (['società', 'multirazziale..', '#profughi', '#rom'], [], []),
#  (['bambini', 'scuola', 'rom', 'scuola'],
#   [],
#   ['vanno', 'integrano', 'insegno', 'avuto', 'fare']),
#  (['#dallavostraparte', 'rapinatori', '#rom', 'morte', 'domiciliari'],
#   ['seriali', 'cinese'],
#   ['provocato']),
#  (['bombe', 'attentato', 'terroristi'], [], ['', 'fatto']),
#  (['vicenda', 'nomadi', 'residenza', 'cancellazione...'],
#   [],
#   ['Continua', 'far', 'discutere']),
#  (['campo', 'parcheggio', 'ospedale', '#italia'], ['nomadi', '#bhive'], []),
#  (['torchio', 'rom', 'campo', 'nomadi'], ['cinese'], ['morta']),
#  (['rom', 'gabbia'], [], ['difende']),
#  (['stella', 'musica', '#rom'], [], ['morta', '#esmaredzepova']),
#  (['paesi', 'negozi', 'buttafuori', 'clienti', 'fan', 'pare'],
#   ['rom/ladri'],
#   ['Sapete', 'sono', 'controllano+tutelano']),
#  (['alleato', '', 'favore', '#austerità', 'amico'], ['nuovo'], []),
#  (['#campo', '#rom', 'portafogli', 'donne', 'trasfe...'],
#   [],
#   ['rubare', 'arrestate']),
#  (['profugo', 'bono', 'profugo', 'fatto', ',ma'],
#   ['bono,no', 'ricco', 'nera'],
#   ['lasciamo', 'stare']),
#  (['rom', 'comunità', 'vittima', 'pratiche', 'base'],
#   ['sola', 'istituzionali', 'etnica'],
#   ['pensate', 'realizzate']),
#  (['bar', 'sport', 'maxirata', 'finanziamento'],
#   [],
#   ['terrorizzati', 'portato']),
#  (['Articolo', '#nomadi', 'mezzo', 'nomadare...'],
#   ['razzista', 'populista', 'poveri'],
#   ['Accusati', 'cercavano']),
#  (['Fondamentalismo', 'religione', 'islamica.....'], ['islamico'], []),
#  (['stereotipi', 'migranti'], ['diffusi'], ['elenca']),
#  (['', 'stregua', 'terroristi'], [], ['trattati']),
#  (['vetri', 'campi', 'rom', 'ciglio', 'ferrovia', 'decoro'],
#   ['disegnati', 'spero'],
#   ['', 'decidano', 'dar', 'merita']),
#  (['polizia', 'fuoco', 'nomade'], ['latitante'], ['apre']),
#  (['Meglio', 'islamico...'], ['morto'], []),
#  (['insediamenti', 'nomadi', 'quartieri', 'uffici', 'questura'],
#   ['abusivi'],
#   ['#chilhavisto', 'degradati']),
# ...
#  (['problema',
#    'sicurezza',
#    'campo',
#    'nomadi',
#    'profughi',
#    'online',
#    'provincia'],
#   [],
#   ['Quotidiano']),
#  (['Ragazza', 'anni', 'nomadi'], [], ['stuprata']),
#  (['genitori', 'studentessa', 'campo', 'rom', 'polizia'],
#   ['cinese'],
#   ['dice', 'scippata', 'trovata', 'morta', 'entrare']),
#  (['migranti', 'rischio', 'salute', 'grazie'],
#   ['pubblica'],
#   ['rappresentano']),
#  (['ing', 'forza', 'gentiloni', 'dogi', 'errori', 'incidenti', 'rom'],
#   ['biban', 'italia', 'padovan', 'italiani', 'libera'],
#   ['Viva', 'sono', 'uscita']),
#  (['commissione', 'periferie', 'campo', 'rom', 'immondizia'], [], []),
#  (['ordinanza', 'camper', 'rom', 'Controlli'],
#   ['nuovo', 'sgombero'],
#   ['Prorogata']),
#  (['cena', 'amicizia', 'famiglia', '#rom', 'casa', 'anni', 'baracche'],
#   [],
#   ['incontrar']),
#  (['vittime', 'terroristi'], ['uccisi'], ['ATTENTATI']),
#  (['benvenuto', 'profughi', 'link'], [], ['festa', 'dare']),
#  (['avances', 'rom'], ['anziano'], ['rifiuta', 'rapina']),
#  (['voto', 'islamici', 'pari', 'rom'], [], ['', 'assicura']),
#  (['polizia', 'rom', 'camper', 'gente'],
#   ['arresta', 'ladri'],
#   ['sgombera', 'applaude']),
#  (['bello', 'democrazia', 'opinione', 'paesi'],
#   ['islamici'],
#   ['abituati', 'hai']),
#  (['blitz', 'scuola', 'campo', 'sequestri', 'denunce'],
#   ['nuovo', 'ex', '#napoli'],
#   ['sgomberato']),
#  (['intervento', 'problemi', 'via', 'questioni', 'rom'],
#   ['altre'],
#   ['Nuovo', 'mercatino']),
#  (['incassi', 'multe', 'pattuglie', 'rom'], ['asfalti', 'anti'], []),
#  (['rivendicazione', 'isis..al', 'musulmani', 'milione'],
#   ['quaeda', 'estremisti'],
#   ['...sono']),
#  (['leghisti', 'fascisti', 'uomo', 'rom', 'gabbiotto'], [], ['chiuso']),
#  (['Irruzione', 'casa', 'minacce', 'profughi'], ['disoccupato'], ['ha']),
#  (['pazzo', 'akbar'],
#   ['kossovaro,musulmano', 'allah'],
#   ['ordina', 'dire', 'tratta', 'grida', '#terror']),
#  (['tata', 'sicurezza', 'rom', 'fronte', 'auto'], [], ['esprime']),
#  (['messa', 'immigrati', 'struttura', 'di...'], ['ospiti'], []),
#  (['Accoglienza', '#profughi', 'sostegno', 'Croce'], ['Rossa'], []),
#  (['storia', 'chiusura', 'campi', 'rom', 'abitazioni'],
#   ['vera'],
#   ['', 'sembra', 'diano']),
#  (['agricoltura', 'grazie', 'giovani', 'stranieri'], ['lombarda'], ['cresce']),
#  (['lavoro', 'costo', 'caporali', 'immigrazione', 'broker', 'nome'],
#   ['basso', 'uguale'],
#   ['gestito', 'cambia', 'risultato']),
#  (['favola', 'migrante', 'calciatore'], [], []),
#  (['masseria', '#rom', 'bonifica'],
#   [],
#   ['Liberata', 'occupata', 'andar', 'devastato', 'paga']),
#  (['profughi', 'somalo', 'processo', 'rito'], ['immediato'], ['#Milano']),
#  (['proposta', 'assessore', 'casa', 'rom'], ['Danese', 'fruibili'], []),
#  (['stadio',
#    'blocco',
#    'olimpiadi',
#    'insediamenti',
#    'campi',
#    '#rom',
#    'incapacità'],
#   ['continui'],
#   []),
#  (['casino', 'rom', 'diritto'],
#   ['pari'],
#   ['difendo', 'fa', 'incita', 'bruciare', 'perde', 'considerato']),
#  (['via', 'seta', 'nomadi'], [], ['Internazionale', 'disegnata']),
#  (['rom', 'gabbia', 'dipendenti', 'polemica'],
#   ['chiuse'],
#   ['diventa', 'accende']),
#  (['italia', 'fesso', 'terrorista'], [], ['far', 'prendere']),
#  (['difensore', 'cristianità', 'islam'], ['imbecille', 'inadatto'], []),
#  (['fatto', 'crimini', 'guerra', 'propaganda'],
#   ['antyi'],
#   ['sarà', 'esistono']),
#  (['Controlli', 'campo', 'lavoro', 'Polizia', 'Stato'], ['nomadi'], []),
#  (['vittime', '#terrorismo', 'vittime', 'turisti', 'religione'],
#   ['stranieri', '#islamica'],
#   ['fare', 'ammazzato']),
#  (['', 'terroristi', 'affitti'], ['clandestini'], ['sa', 'dietro,a']),
#  (['fermata', 'disperati', 'cantiere', 'rifugio', '#rom'],
#   ['bloccato'],
#   ['metrò']),
#  (['euro', 'giorno', 'guardiania', 'campo', 'rom'], ['Mille'], ['']),
#  (['Minaccia', 'flessibilità', 'migranti', 'terremoto'], ['populista'], []),
#  (['peggio', 'onda', 'Punto', 'rom', 'fuoco', 'sua...'],
#   ['Politico'],
#   ['derubò', 'dà']),
#  (['indagini',
#    'terroristi',
#    'proselitismo',
#    'carcere',
#    'campo',
#    'applicazione',
#    'bis'],
#   ['monche'],
#   ['Uffa', 'fanno']),
#  (['controllo', 'droga', 'africani', 'rom', 'figli'], ['futuro'], ['Andiamo']),
#  (['straniero', '', 'ambito', 'operazione'],
#   ['misterioso'],
#   ['#riscopriamo', '', 'edito']),
#  (['Nomadi', 'fatto', 'carabinieri', 'rom', 'cacciavite'],
#   [],
#   ['colti', 'aggrediscono', 'tenta']),
#  (['incremento', 'reati', 'aumento', 'presenza', 'immigrati'], [], ['stato']),
#  (['immigrato', 'semplice', 'dipendente'],
#   ['italiano', 'ex', 'licenziato'],
#   ['richiedente']),
#  (['terrorista'], [], ['preoccupato', 'stava']),
#  (['campo', 'rom', 'via', 'appello', '#news'], ['sgombero'], ['Fermate']),
#  (['rom...', '#dallavostraparte'], ['filo'], ['far', 'mancare']),
#  (['cordoglio', 'morte', 'terra', 'amore', 'terrorismo'], [], ['passerà']),
#  (['opinione', 'rom', 'una...'], [], ['è', 'capito', 'chiuse']),
#  (['intervento', 'Guardia', 'stretta', 'immigrati'],
#   ['Nazionale'],
#   ['nega', 'chiederà']),
#  (['italiani', 'nomadi', 'termine', 'politicallycorrect', 'mondo'],
#   ['soliti'],
#   ['razzisti', 'benvisti']),
#  (['campo'], ['bici', 'nomadi'], ['pubblicato', 'trovate']),
#  (['via', 'camper', 'nomadi'], [], []),
#  (['camere', 'gas', '#rom', '#furbettidelcartellino', 'capire...'], [], []),
#  (['#terrorismo',
#    'venezia',
#    'appartamento',
#    'centro',
#    'preghiera',
#    'allentamenti'],
#   ['clandestino'],
#   ['preparavano', 'video']),
#  (['', 'terroristi', 'musulmani'], [], []),
#  (['trucchi', 'ladruncole', 'rom', 'fine'], ['infallibili', 'sociale'], []),
#  (['Malattie', 'diritto', 'studio', 'fine', 'famiglie', 'rom'],
#   ['negato'],
#   ['fatto']),
#  (['patto', 'flussi', 'migranti'], [], ['Firmato', 'Fermeremo']),
#  (['Insegnante', 'choc', 'migranti', 'profugo'],
#   [],
#   ['vivi', 'Dispiace', 'sentire']),
#  (['modernità', 'velo'], ['islamico'], ['amnantano', 'conoscere', 'mette']),
#  (['Giorno', 'rom', 'porrajmos', 'genocidio'], [], ['ricordano']),
#  (['rom', 'gabbia', 'supermercato', 'dipendente', 'Giornale'],
#   ['iscritto'],
#   ['messe']),
#  (['rom', 'casa', 'grazie', 'sindaco'], ['leghista'], ['tornano']),
#  (['terrorismo', 'paura', 'black', 'allerta', '#terrorismo', '#ma'],
#   ['allerta', 'bloc'],
#   ['scatta', 'fanno', '#scatta']),
#  (['west', 'poliziotti', 'trentina', '#nomadi', '#invasione'],
#   ['#repubblica'],
#   ['far', 'aggrediti', 'Votare', 'fermare']),
#  (['anno', 'case', 'rom', 'Contenti'],
#   ['romani'],
#   ['comincia', 'far', 'comincia', 'dare', 'votata', '']),
#  (['mld', 'rimesse'], ['terza'], []),
#  (['rifugio', 'terroristi', 'accoglienza', '#buonisti'], ['sicuro'], []),
#  (['legge', 'rom', 'italiani'],
#   ['frittata!La', 'giusto'],
#   ['rigiriamo', 'rispettare', '']),
#  (['commissaria', 'stop', 'immigrati'], ['comunale'], ['dice', 'basta']),
#  (['Festa', 'animali', 'margini', 'strada'],
#   ['islamica'],
#   ['sacrificati', 'Arrivano']),
#  (['#terrorismo', 'modo', 'inizio', 'anno...', '#rip'],
#   ['infame', 'spiace'],
#   ['trova', '#paceintutteleterre']),
#  (['rom', 'turisti', 'furto'],
#   ['colombiana', 'quotidiano'],
#   ['picchiata', 'avvertito']),
#  (['rom', 'sala', 'immigrazione'],
#   ['uniti'],
#   ['uniti', 'confermato', 'votato', 'capito']),
#  (['fatto', 'razzisti', 'rom', 'maledetti', 'parola'],
#   ['buonisti', 'baaastaaaa'],
#   ['fa', 'rider', 'inventato']),
#  (['italiani', '#rom'], ['italiani'], ['vivono']),
#  (['comunità'], ['principali', 'straniere'], []),
#  (['campo', 'rom', 'macchinista', 'treno...'], [], ['indagato']),
#  (['#dallavostraparte', 'politici', 'sinistra', 'immigrati'],
#   ['Inutile', 'ke'],
#   ['parlare', 'derubano']),
#  (['estero', 'parole', 'eh'],
#   ['straniere', 'italiane', 'tranquilli'],
#   ['crediamo', 'vivete', 'mischiate']),
#  (['attivisti'], ['sgombero'], ['arriva', 'fermiamo', '']),
#  (['Grazie'], ['migranti'], ['facendo', 'vedere', 'diventati']),
#  (['rom', 'metà', 'cittadinanza'], ['italiana'], ['sono']),
#  (['rom', 'offerta'], [], ['capito', 'successo', 'erano']),
#  (['ue', 'm.', 'italia', 'migranti'], ['lontani'], ['discrimina']),
#  (['', 'rom', 'suite', 'centro', 'caviale', 'champagne'], [], ['trasferiti']),
#  (['Uomo', 'amico', 'impero', 'centri', 'profughi'],
#   ['‘ndrangheta'],
#   ['creato']),
#  (['presepe'], ['musulmano'], ['incendia', 'fatto']),
#  (['studentessa', 'condanna', 'patteggiamento', 'rom'], ['cinese'], ['morta']),
#  (['Libertà', 'immigrata'], [], ['ditelo']),
#  (['#scuola', '#islam', '#migrazioni', 'radicalizzazioni'], ['violente'], []),
#  (['commedia', 'accordo', 'flessibilità', 'bilancio', 'cambio', 'migranti'],
#   ['ottiene'],
#   [',sono', 'tiene']),
#  (['autore', 'sparatoria', 'centro', '#20dicembre'],
#   ['morto', 'presunto', 'islamico'],
#   ['trovato']),
#  (['storia', 'patente', 'immigrati'],
#   ['laggente'],
#   ['gratis', 'fa', 'infuriare', '']),
#  (['pro', 'soni'],
#   ['c.sociali', 'antagonisti', 'clandestini'],
#   ['dichiarato', 'pro', 'pro', 'pro']),
#  (['nomi', 'fotografie', 'agenti', 'terrorista', 'iniziati...'],
#   [],
#   ['diffuso', 'aggrediti']),
#  (['nomadi', 'aree'], ['attrezzate'], []),
#  (['ricovero'], [], ['Saviano', 'ripartire', 'riempie']),
#  (['carcere', 'rom', 'ragazza'], ['cinese'], ['derubato', '']),
#  (['imbarbarimento', 'rom', ',schippano,ti', 'casa'],
#   [':rubano'],
#   ['avvenuto', 'concesso', 'entrano', 'arrestano']),
#  (['proposta', 'impiego', '#migranti', '#Stato'],
#   ['interessante'],
#   ['attiva', '#leiene']),
#  (['rapper', 'vita', 'profugo'], ['comoda'], ['canta', 'casca']),
#  (['rom', 'mirino', 'coop', 'politici'], [], ['']),
#  (['muro', 'soluzione', 'immigrants', 'overstayers', 'immigrants'],
#   ['illegal'],
#   ['guarda', 'spaccia']),
#  (['nomade', 'nellappartamento', '#di'],
#   ['incinta', 'svaligiato'],
#   ['#Milano', 'rischia', 'partorire']),
#  (['bilancio', 'rom', 'giorni', 'fotofinish'], [], []),
#  (['zona', 'immigrati'], ['franca', 'Liberi'], ['fare', 'vogliono']),
#  (['Reinserimento', 'solidarietà', 'colpa', 'politica'], ['nomadi'], []),
#  (['inizio', 'mondializzazione'], ['islamica'], []),
#  (['rom', 'gabbia'], ['simpatico'], []),
#  (['Cronaca', 'campo', 'borsoni', 'maratona'],
#   ['nomadi'],
#   ['Ritrovati', 'rubati']),
#  (['Ragazza', 'inquirenti', 'leader', 'rom', 'ragazzi'],
#   ['cinese'],
#   ['morta', 'Consegnate', 'rapinato']),
#  (['intervento', 'bisogno', '#immigrati'], ['Grande'], ['ha']),
#  (['Liste'], ['stranieri', 'retorica'], ['Speriamo', 'dice']),
#  (['#vigili', 'campi', 'straordinari'], ['#nomadi'], ['inchiesta']),
#  (['rom', 'delinquenti', 'posto'], ["piu'"], ['difende', 'voglio', 'andate']),
#  (['#LAltraFaenza', '#fiaccolata', 'protesta', '', 'fallimento', '#rom'],
#   [],
#   []),
#  (['immigrati', 'aziende', 'punti', 'dito', 'partite', 'immigrati'],
#   ['irregolari', ',alle', 'grandi'],
#   ['servono', '']),
#  (['bambini', '#rom', 'campo', 'pastore'], [], ['bastona']),
#  (['profughi', 'casa'], ['falsi'], ['mandiamo']),
#  (['cultura', 'rom', '#dallavostraparte'], [], []),
#  (['campo', 'rom', 'contraddizione'], [], ['farà']),
#  (['mai...', 'popolo', 'pro', 'rom'],
#   ['italiano', 'clandestini', 'iussoli'],
#   ['appoggiato', '', 'frega']),
#  (['vari', 'calciatori', 'veline', 'prenditori', 'umanità'],
#   [],
#   ['è', 'Billionaire', 'spettacolume', 'varia', 'fa']),
#  (['migranti',
#    'punti',
#    'controllo',
#    'confini',
#    'finanziamento',
#    'centri',
#    'accoglienza'],
#   ['salienti', 'libici'],
#   []),
#  (['Reinserimento', 'business', 'solidarietà', 'colpa', 'politica'],
#   ['nomadi'],
#   []),
#  (['west', 'poliziotti', 'trentina', 'nomadi', 'fermi'],
#   [],
#   ['far', 'aggrediti']),
#  (['#paolodeldebbio', '#ghettorom'], ['mito', '#camponomadi'], ['#roma']),
#  (['borseggiatore', 'campo', 'rom'],
#   ['cinese', 'morta', 'terzo'],
#   ['fermato']),
#  (['migranti', 'casa', '', '', 'accoglienti.'],
#   ['buoni', '...............prrrrrrrrrrrrrrr'],
#   ['sembrano']),
#  (['cita', 'unificazione', 'laboratorio', 'immigrazione'], ['attuale'], ['']),
#  (['anno', 'avvenimenti', 'terremoti', 'terrorismo,...'],
#   ['luttuosi'],
#   ['chiude', 'contraddistinto']),
#  (['Boldrini', 'Politica', 'terroristi', 'paladinba', 'Strategia'],
#   ['pericolosa', '90°'],
#   ['rafforza']),
#  (['ventenne', 'nomade', 'campo', 'via'], ['Cinese'], ['morta', 'fermato']),
#  (['vicenda', 'nomadi', 'residenza', 'cancellazione...'],
#   [],
#   ['Continua', 'far', 'discutere']),
#  (['banda', 'rom', 'pizzo', 'anni', 'ristoratore', 'colpi', 'mitra', 'via'],
#   ['esausto'],
#   ['chiedeva', 'uccide']),
#  (['#ultimenotizie', 'notizie', 'appalti', 'campi', 'processo', 'funzionari'],
#   ['nomadi'],
#   []),
#  (['Campo', 'persone', 'baracche'], ['nomadi', 'abusivo'], ['vivono']),
#  (['soccorso', 'campo'], ['pronto', 'cellulare', 'nomadi'], ['ritrovato']),
#  (['orrore', 'somalo', 'omicidi', 'stupri', '#campoprofughi'],
#   ['simile', 'colpevole'],
#   ['visto']),
#  (['paladina', 'piffero', 'rom', 'manco', '#biancoenero'],
#   [],
#   ['Scusate', 'sta', 'permesso', 'scende']),
#  (['vicinanze', 'uomo', 'rom', 'zona'],
#   ['mendicante'],
#   ['accaduto', 'frequenta']),
#  (["po'", 'soldi', 'rom'], [], ['', 'fanno']),
#  (['strada', 'mano', 'stranieri', 'Giornale'], [], ['aggredito']),
#  (['rt', 'Sindaci', 'Provincia', 'tema'], ['comuni_anci'], []),
#  (['atto', 'terrorismo'], ['necessario'], ['definito']),
#  (['problema', 'immigrati,vero'], [], ['commentare']),
#  (['fisionomia', 'immigrazione', 'comunità', 'anni'],
#   ['islamica'],
#   ['cambiata']),
#  (['scandalo', 'rischio', 'progetti', 'casa-accoglienza', 'profughi'],
#   ['transessuali'],
#   []),
#  (['Paolini', '#profughi', 'provincia', 'Presidio', 'ore'], ['Altri'], []),
#  (['cittadino', 'rom', 'fuga...'], ['pronto'], ['investiti', 'fermato']),
#  (['tavola', '', 'bambini', 'dimora', 'rom', 'famiglie', 'paese'],
#   ['anziani'],
#   []),
#  (['Avramopoulos', 'piano', 'migranti'], ['Ottimo'], []),
#  (['#Istituzioni', 'bambini', 'ragazzi', '#rom', 'giro', 'elemosine'],
#   [],
#   ['permettono', 'stiano', 'rubare', 'chiedere']),
#  (['musulmano'], [], ['ripeterà', 'dipende']),
#  (['migranti'], [], ['annegati']),
#  (['attentati', 'matrice'], ['islamica'], ['avvenuti', 'Basta', 'informar']),
#  (['Spostamento', 'campo', 'mistero', 'Comune'], ['nomadi'], ['spendere']),
#  (['Podisti', 'rom', 'chiavi', 'casa', 'portafogli', 'telefonini'],
#   [],
#   ['derubati', 'sfidano', 'recuperare']),
#  (['rom', 'monnezza'], [], ['vada', 'esasperati']),
#  (['campi', 'rom', 'nomadi', 'abitazioni', 'aiuti'],
#   ['altri'],
#   ['fornire', 'chiedono', 'diminuire']),
#  (['Donne',
#    'mamma',
#    'rischio',
#    'accesso',
#    'terapie',
#    'diagnosi',
#    'Difficoltà',
#    'linguisti...'],
#   ['straniere'],
#   ['Mancato']),
#  (['Giornale', 'rom', 'turista', 'volte', 'anni', 'carabinieri'],
#   [],
#   ['arrestata']),
#  (['Bomba', 'metro', 'terrorismo'], [], ['escludo']),
#  (['Accampamento', 'rom', 'denunce', 'allaccio', 'rete'],
#   ['improvvisato', 'abusivo', 'elettrica'],
#   []),
#  ([], [], []),
#  (['legge', 'terra', 'stranieri'], ['possibile'], ['Domandiamo', 'venga']),
#  (['inseguimento', 'nomadi', 'manette'], [], ['Arrestati', 'riconoscete']),
#  (['cultura', 'rom', 'pazza', 'nome', ''],
#   ['famosa', 'scatenata'],
#   ['apprezzata']),
#  (['#ultimenotizie', 'notizie', 'caos', 'dimissioni', 'caccia', 'terrorista'],
#   [],
#   []),
#  (['freno', 'esodo', 'insegnanti', 'nord', 'simpatia', 'rom'],
#   ['vero', 'meridionali', 'certa'],
#   ['porre', 'nutre']),
#  (['campo', 'rom', 'nomade', 'vigile'], [], ['tentato', 'investire']),
#  (['governatore', 'hotel', 'migranti', 'povero'],
#   ['altro', 'italiano'],
#   ['cerca', 'uccide', '']),
#  (['scippatori', 'campo', 'rom'], ['cinese'], ['trovata', 'morta']),
#  (['rom', 'anziani', 'accordo'], ['italiani'], ['credo', 'stati', 'sareste']),
#  (['righe', 'accordo', 'turca', 'tenerveli', '#immigrazione'],
#   [''],
#   ['Par', 'capire', 'vorrebbe', 'volete']),
#  (['gente', 'qualità', 'vita', 'schifo', 'sl', 'feccia', 'paese'],
#   ['clandestini', 'qst'],
#   ['va', 'fa']),
#  (['ville', 'nomadi', 'giorno', 'rom'],
#   ['abusive'],
#   ['#Milano', 'costruisco', 'demoliscono', 'costruiscono', 'succede']),
#  (['palmeti', 'bananalandia', 'campi', 'rom', 'nomi', 'vie', 'arabo'],
#   [],
#   ['', 'fare', 'andate']),
#  (['governo', 'terremotati', 'esseri'], ['umani'], []),
#  (['rom', 'Censimento', 'lavoro', '#roma'], ['concluso'], ['chiudere']),
#  (['#rom', '#sinti', 'storia', 'città', 'lotta'], [], ['cancellati']),
#  ...]

# %%
nouns_list = [word[0] for word in categorized_words]
adjectives_list = [word[1] for word in categorized_words]
verbs_list = [word[2] for word in categorized_words]

nouns_vector = np.array([word[0] for word in categorized_words], dtype=object)
adjectives_vector = np.array([word[1]
                             for word in categorized_words], dtype=object)
verbs_vector = np.array([word[2] for word in categorized_words], dtype=object)

# %%
def calculate_embeddings(words_list, dictionary, embedding_size=128):
    if not words_list:
        return np.zeros(embedding_size)
    embeddings = [dictionary[word]
                  for word in words_list if word in dictionary]
    if not embeddings:
        return np.zeros(embedding_size)
    return np.mean(embeddings, axis=0)


embeddings_train = []
for words_set in categorized_words[:6839]:
    nouns_embedding = calculate_embeddings(words_set[0], dizionario)
    adjectives_embedding = calculate_embeddings(words_set[1], dizionario)
    verbs_embedding = calculate_embeddings(words_set[2], dizionario)
    combined_embedding = np.concatenate(
        [nouns_embedding, adjectives_embedding, verbs_embedding])
    embeddings_train.append(combined_embedding)

embeddings_test = []
for words_set in categorized_words[6839:]:
    nouns_embedding = calculate_embeddings(words_set[0], dizionario)
    adjectives_embedding = calculate_embeddings(words_set[1], dizionario)
    verbs_embedding = calculate_embeddings(words_set[2], dizionario)
    combined_embedding = np.concatenate(
        [nouns_embedding, adjectives_embedding, verbs_embedding])
    embeddings_test.append(combined_embedding)

print(len(embeddings_test[0]))
# Out:
# 384

# %%
clf = LinearSVC()
clf.fit(embeddings_train, y_train_hs)
y_pred = clf.predict(embeddings_test)

print(classification_report(y_test_hs, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.71      0.91      0.80       319
#            1       0.69      0.34      0.46       181
#
#     accuracy                           0.71       500
#    macro avg       0.70      0.63      0.63       500
# weighted avg       0.70      0.71      0.67       500

# %%
scores = cross_val_score(clf, embeddings_test, y_test_hs, cv=5)
print(scores)
print('media:', np.mean(scores))
# Out:
# [0.76 0.63 0.75 0.66 0.75]
# media: 0.7100000000000001

# %% [markdown]
# # Word Embeddings con Word2Vec

# %%
from gensim.models import Word2Vec


def conllu_sentences_to_strings(sentences):
    return [' '.join([token["form"] for token in sentence]) for sentence in sentences]


sentence_strings = conllu_sentences_to_strings(sentences)
testo_addestramento = pd.Series(sentence_strings)

# Addestramento del modello Word2Vec con CBOW con un contesto di parole pari a 5
word2vec_model = Word2Vec(sentences=testo_addestramento,
                          vector_size=128, window=5, min_count=1, workers=8)

# Calcolo degli embedding delle frasi come media degli embedding delle parole
embeddings_train = []
for text in testo_addestramento[:6839]:
    text_embedding = np.mean([word2vec_model.wv[word]
                             for word in text], axis=0)
    embeddings_train.append(text_embedding)

embeddings_test = []
for text in testo_addestramento[6839:]:
    text_embedding = np.mean([word2vec_model.wv[word]
                             for word in text], axis=0)
    embeddings_test.append(text_embedding)

train_size = 6839
clf = LinearSVC()
clf.fit(embeddings_train, y_train_hs)
y_pred = clf.predict(embeddings_test)

print(classification_report(y_test_hs, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.66      0.94      0.78       319
#            1       0.58      0.15      0.24       181
#
#     accuracy                           0.65       500
#    macro avg       0.62      0.55      0.51       500
# weighted avg       0.63      0.65      0.58       500

# %%
scores = cross_val_score(clf, embeddings_test, y_test_hs, cv=5)
print(scores)
print('media:', np.mean(scores))
# Out:
# [0.72 0.76 0.8  0.69 0.73]
# media: 0.74
